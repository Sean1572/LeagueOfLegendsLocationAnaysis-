# %%
# %load_ext autoreload
# %autoreload 2

import requests
import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#!pip install python-dotenv

# %% [markdown]
# # Api Key

# %%
#Hi yall, so for this we need riot api keys. They have 24 hour refreshes but to be extra safe put them in a .env file

import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv('riot_api_key')

if api_key == None:
    raise Exception(
        "Go to https://developer.riotgames.com/ and get an api key set up"
    )
else:
    print("looking good")
# Out:
# looking good

# %% [markdown]
# Read https://developer.riotgames.com/docs/portal#web-apis_api-keys for key info on api keys
#
# # Riotwatcher
#
# Using riotwatcher for a library to handle the api, see https://github.com/pseudonym117/Riot-Watcher

# %%
# !pip install riotwatcher
# Out:
# Requirement already satisfied: riotwatcher in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (3.2.5)
# Requirement already satisfied: requests in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from riotwatcher) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\seanh\appdata\roaming\python\python38\site-packages (from requests->riotwatcher) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from requests->riotwatcher) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from requests->riotwatcher) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from requests->riotwatcher) (2023.11.17)

# %%
# Example code from https://github.com/pseudonym117/Riot-Watcher for debugging purporses
from riotwatcher import LolWatcher, ApiError

lol_watcher = LolWatcher(api_key)

my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'pseudonym117')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise
# Out:
# {'id': 'dD3xFaEaFlbon9FZ6ljyBU7pXSbLV3FD36RwtK8kaC8h_-Y', 'accountId': '2AmPLTJbOTz48G33AO-dPUcXUEtRh5FdJ3LTMB9Jr9Xt2w', 'puuid': 'A6VIZHINPBHNzS1W3Yw0LltoZbJOrDIJgUEaZT7Pi2aC3TJYbv_TRQM4ywJnQflgwZbYCESO66ZAAg', 'name': 'pseudonym117', 'profileIconId': 539, 'revisionDate': 1707204724257, 'summonerLevel': 190}
# []
# {'type': 'champion', 'format': 'standAloneComplex', 'version': '14.3.1', 'data': {'Aatrox': {'version': '14.3.1', 'id': 'Aatrox', 'key': '266', 'name': 'Aatrox', 'title': 'the Darkin Blade', 'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...', 'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}, 'image': {'full': 'Aatrox.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 0, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Fighter', 'Tank'], 'partype': 'Blood Well', 'stats': {'hp': 650, 'hpperlevel': 114, 'mp': 0, 'mpperlevel': 0, 'movespeed': 345, 'armor': 38, 'armorperlevel': 4.45, 'spellblock': 32, 'spellblockperlevel': 2.05, 'attackrange': 175, 'hpregen': 3, 'hpregenperlevel': 1, 'mpregen': 0, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 60, 'attackdamageperlevel': 5, 'attackspeedperlevel': 2.5, 'attackspeed': 0.651}}, 'Ahri': {'version': '14.3.1', 'id': 'Ahri', 'key': '103', 'name': 'Ahri', 'title': 'the Nine-Tailed Fox', 'blurb': "Innately connected to the magic of the spirit realm, Ahri is a fox-like vastaya who can manipulate her prey's emotions and consume their essence—receiving flashes of their memory and insight from each soul she consumes. Once a powerful yet wayward...", 'info': {'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 5}, 'image': {'full': 'Ahri.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 48, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Mage', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 590, 'hpperlevel': 96, 'mp': 418, 'mpperlevel': 25, 'movespeed': 330, 'armor': 21, 'armorperlevel': 4.7, 'spellblock': 30, 'spellblockperlevel': 1.3, 'attackrange': 550, 'hpregen': 2.5, 'hpregenperlevel': 0.6, 'mpregen': 8, 'mpregenperlevel': 0.8, 'crit': 0, 'critperlevel': 0, 'attackdamage': 53, 'attackdamageperlevel': 3, 'attackspeedperlevel': 2.2, 'attackspeed': 0.668}}, 'Akali': {'version': '14.3.1', 'id': 'Akali', 'key': '84', 'name': 'Akali', 'title': 'the Rogue Assassin', 'blurb': 'Abandoning the Kinkou Order and her title of the Fist of Shadow, Akali now strikes alone, ready to be the deadly weapon her people need. Though she holds onto all she learned from her master Shen, she has pledged to defend Ionia from its enemies, one...', 'info': {'attack': 5, 'defense': 3, 'magic': 8, 'difficulty': 7}, 'image': {'full': 'Akali.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 96, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Assassin'], 'partype': 'Energy', 'stats': {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpperlevel': 0, 'movespeed': 345, 'armor': 23, 'armorperlevel': 4.7, 'spellblock': 37, 'spellblockperlevel': 2.05, 'attackrange': 125, 'hpregen': 9, 'hpregenperlevel': 0.9, 'mpregen': 50, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 62, 'attackdamageperlevel': 3.3, 'attackspeedperlevel': 3.2, 'attackspeed': 0.625}}, 'Akshan': {'version': '14.3.1', 'id': 'Akshan', 'key': '166', 'name': 'Akshan', 'title': 'the Rogue Sentinel', 'blurb': 'Raising an eyebrow in the face of danger, Akshan fights evil with dashing charisma, righteous vengeance, and a conspicuous lack of shirts. He is highly skilled in the art of stealth combat, able to evade the eyes of his enemies and reappear when they...', 'info': {'attack': 0, 'defense': 0, 'magic': 0, 'difficulty': 0}, 'image': {'full': 'Akshan.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 144, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Marksman', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 630, 'hpperlevel': 107, 'mp': 350, 'mpperlevel': 40, 'movespeed': 330, 'armor': 26, 'armorperlevel': 4.7, 'spellblock': 30, 'spellblockperlevel': 1.3, 'attackrange': 500, 'hpregen': 3.75, 'hpregenperlevel': 0.65, 'mpregen': 8.2, 'mpregenperlevel': 0.7, 'crit': 0, 'critperlevel': 0, 'attackdamage': 52, 'attac ...
# Summoner with that ridiculous name not found.

# %% [markdown]
# Above should show some of the example codes with the last value should be "Summoner with that ridiculous name not found". If you got an error, **refresh the api key**.
#
# If above looks good move on to the next step
#
# # Exploration of an example timeline!
#
# Goal is to find the last game of the player **listed in our enviorment file** last game and the key events of that last game.

# %%
player = os.getenv('player_name')

if player == None:
    raise Exception(
        "Add your riot account name to enviroment file"
    )
else:
    print("looking good")
# Out:
# looking good

# %%
# Get player name
player_data = lol_watcher.summoner.by_name(my_region, player)
print(player_data.keys())
match_ids = lol_watcher.match.matchlist_by_puuid(my_region, player_data['puuid'])
match_ids
# Out:
# dict_keys(['id', 'accountId', 'puuid', 'name', 'profileIconId', 'revisionDate', 'summonerLevel'])
# ['NA1_4913902543',
#  'NA1_4913883766',
#  'NA1_4913080900',
#  'NA1_4913051913',
#  'NA1_4909089736',
#  'NA1_4909066231',
#  'NA1_4909027717',
#  'NA1_4908999551',
#  'NA1_4907368584',
#  'NA1_4907360146',
#  'NA1_4907346997',
#  'NA1_4907326575',
#  'NA1_4907312646',
#  'NA1_4907293384',
#  'NA1_4906520978',
#  'NA1_4906502148',
#  'NA1_4906497820',
#  'NA1_4906460448',
#  'NA1_4906432595',
#  'NA1_4906408509']

# %% [markdown]
# Notes
# - Riot only saves last twenty games
# - If we want to go through random matches, we can follow a simliar approch found at https://github.com/christophM/LolCrawler for slowing opening up diffrent matches to study
# - Some matches may be just ARAM, maybe some are rift matches
# - We will need to keep this in mind
#
# How do we know if a match is an aram match or a rift match?

# %%
match_meta = lol_watcher.match.by_id(my_region, match_ids[0])
match_meta
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4913902543',
#   'participants': ['_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#    'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#    '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#    'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#    'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#    '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#    '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#    'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#    'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#    'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA']},
#  'info': {'gameCreation': 1707196778641,
#   'gameDuration': 1033,
#   'gameEndTimestamp': 1707197833369,
#   'gameId': 4913902543,
#   'gameMode': 'ARAM',
#   'gameName': 'teambuilder-match-4913902543',
#   'gameStartTimestamp': 1707196800138,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '14.2.556.3141',
#   'mapId': 12,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 32,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 163,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 525,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1053.515525832343,
#      'damageTakenOnTeamPercentage': 0.18642356532731957,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 5,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 8,
#      'gameLength': 1033.3860817,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 701.3123920263364,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 4,
#      'killAfterHiddenWithAlly': 6,
#      'killParticipation': 0.6666666666666666,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 41,
#      'laneMinionsFirst10Minutes': 20,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3116, 4645, 6653],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 12,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 25,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 19.76653540000001,
#      'skillshotsDodged': 28,
#      'skillshotsHit': 71,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 36,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 30,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.13023063497888593,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 18913,
#     'champLevel': 18,
#     'championId': 74,
#     'championName': 'Heimerdinger',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 2025,
#     'damageDealtToObjectives': 2025,
#     'damageDealtToTurrets': 2025,
#     'damageSelfMitigated': 9385,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12078,
#     'goldSpent': 11250,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6653,
#     'item1': 3116,
#     'item2': 3020,
#     'item3': 4645,
#     'item4': 1058,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 17,
#     'killingSprees': 0,
#     'kills': 4,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 214,
#     'magicDamageDealt': 43109,
#     'magicDamageDealtToChampions': 16884,
#     'magicDamageTaken': 10766,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1321, 'var2': 22, 'var3': 0},
#         {'perk': 8126, 'var1': 823, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 409, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 2321, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 1923,
#     'physicalDamageDealtToChampions': 460,
#     'physicalDamageTaken': 12098,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 1381,
#     'pushPings': 0,
#     'puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#     'quadraKills': 0,
#     'riotIdGameName': 'Stara',
#     'riotIdTagline': 'NA1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 58,
#     'spell2Casts': 52,
#     'spell3Casts': 43,
#     'spell4Casts': 10,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 13,
#     'summonerId': 'YRSFR2tgZBJlTHd3TYkIDhw0edXByouxdGpZGVLSPmGdGvM',
#     'summonerLevel': 93,
#     'summonerName': 'Stara',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 17,
#     'timePlayed': 1033,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 45833,
#     'totalDamageDealtToChampions': 18144,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23293,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1000,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 40,
#     'totalTimeCCDealt': 201,
#     'totalTimeSpentDead': 210,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 800,
#     'trueDamageDealtToChampions': 800,
#     'trueDamageTaken': 428,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 24,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 129,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 750,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1656.3427675397152,
#      'damageTakenOnTeamPercentage': 0.17581237516107787,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 11,
#      'dodgeSkillShotsSmallWindow': 2,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 8,
#      'gameLength': 1033.3860817,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 817.8724891326356,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 3.1666666666666665,
#      'killAfterHiddenWithAlly': 7,
#      'killParticipation': 0.7037037037037037,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 4,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 23,
#      'laneMinionsFirst10Minutes': 28,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6676, 6696, 3004, 3036],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 12,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 24,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 40,
#      'skillshotsHit': 102,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 38,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 31,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.20474930370766076,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 18663,
#     'champLevel': 18,
#     'championId': 21,
#     'championName': 'MissFortune',
#     'championTransform': 0,
#     'commandPings': 2,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 3575,
#     'damageDealtToObjectives': 3575,
#     'damageDealtToTurrets': 3575,
#     'damageSelfMitigated': 8734,
#     'dangerPings': 0,
#     'deaths': 12,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 14086,
#     'goldSpent': 13100,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3042,
#     'item1': 6676,
#     'item2': 6696,
#     'item3': 3006,
#     'item4': 3036,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 20,
#     'killingSprees': 4,
#     'kills': 14,
#     'lane': 'NONE',
#     'largestCriticalStrike': 828,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 117,
#     'magicDamageDealt': 6919,
#     'magicDamageDealtToChampions': 2264,
#     'magicDamageTaken': 8984,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1806, 'var2': 30, 'var3': 0},
#         {'perk': 8126, 'var1': 1212, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 722, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 3505, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 61215,
#     'physicalDamageDealtToChampions': 24518,
#     'physicalDamageTaken': 10228,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 10,
#     'pushPings': 0,
#     'puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'drakocruz',
#     'riotIdTagline': 'NA1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 43,
#     'spell2Casts': 32,
#     'spell3Casts': 45,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 6,
#     'summonerId': 'GfuPMZqBIFuqwW6Vol0K-sYfVYtfN-dMOQSWu3gqMq-ubB4',
#     'summonerLevel': 314,
#     'summonerName': 'drakocruz',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 12,
#     'timePlayed': 1033,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 69878,
#     'totalDamageDealtToChampions': 28527,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 21967,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 498,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 51,
#     'totalTimeCCDealt': 170,
#     'totalTimeSpentDead': 260,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1743,
#     'trueDamageDealtToChampions': 1743,
#     'trueDamageTaken': 2754,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 20,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 3,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 89,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 2624.664078756578,
#      'damageTakenOnTeamPercentage': 0.27621233022332553,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 14,
#      'dodgeSkillShotsSmallWindow': 6,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 8,
#      'gameLength': 1033.3860817,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 833.9709617118604,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 2.7142857142857144,
#      'killAfterHiddenWithAlly': 12,
#      'killParticipation': 0.7037037037037037,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 19,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3177, 3153, 3091, 6665],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 12,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 5,
#      'multikillsAfterAggressiveFlash': 1,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 10,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 21,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 16.39339670000004,
#      'skillshotsDodged': 84,
#      'skillshotsHit': 0,
#      'snowballsHit': 11,
#      'soloBaronKills': 0,
#      'soloKills': 5,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 38,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 27,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.32444863051514045,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 1,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 19992,
#     'champLevel': 18,
#     'championId': 11,
#     'championName': 'MasterYi',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 878,
#     'damageDealtToObjectives': 878,
#     'damageDealtToTurrets': 878,
#     'damageSelfMitigated': 43435,
#     'dangerPings': 0,
#     'deaths': 14,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 4,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 14363,
#     'goldSpent': 12760,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3177,
#     'item1': 6665,
#     'item2': 3153,
#     'item3': 3111,
#     'item4': 3091,
#     'item5': 1038,
#     'item6': 2052,
#     'itemsPurchased': 22,
#     'killingSprees': 6,
#     'kills': 18,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 89,
#     'magicDamageDealt': 8932,
#     'magicDamageDealtToChampions': 5393,
#     'magicDamageTaken': 9088,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 58, 'var2': 14, 'var3': 0},
#         {'perk': 9111, 'var1': 1815, 'var2': 380, 'var3': 0},
#         {'perk': 9104, 'var1': 7, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 1210, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 47774,
#     'physicalDamageDealtToChampions': 28954,
#     'physicalDamageTaken': 24654,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6298,
#     'pushPings': 0,
#     'puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'connection369',
#     'riotIdTagline': 'NA1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 33,
#     'spell2Casts': 18,
#     'spell3Casts': 29,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 26,
#     'summoner2Id': 32,
#     'summonerId': '5OTe6kX97pKIaGP3bPskH-QleUh_ES5FukhUkVaFtO3a7T9HZZVCc01NCA',
#     'summonerLevel': 49,
#     'summonerName': 'connection369',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 2,
#     'timePlayed': 1033,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 69186,
#     'totalDamageDealtToChampions': 45204,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 34511,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 7048,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 32,
#     'totalTimeCCDealt': 16,
#     'totalTimeSpentDead': 312,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 12479,
#     'trueDamageDealtToChampions': 10856,
#     'trueDamageTaken': 769,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 18,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 95,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 525,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1223.690760301054,
#      'damageTakenOnTeamPercentage': 0.20271290655296942,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 12,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 445,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 12,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 8,
#      'gameLength': 1033.3860817,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 720.7266668666224,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 2,
#      'kda': 2.25,
#      'killAfterHiddenWithAlly': 7,
#      'killParticipation': 0.5,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 25,
#      'laneMinionsFirst10Minutes': 27,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6672, 3085, 3036],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 12,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 1,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 21,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 16.39339670000004,
#      'skillshotsDodged': 30,
#      'skillshotsHit': 44,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 27,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 22,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1512668971877714,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 16140,
#     'champLevel': 16,
#     'championId': 222,
#     'championName': 'Jinx',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 1502,
#     'damageDealtToObjectives': 1502,
#     'damageDealtToTurrets': 1502,
#     'damageSelfMitigated': 10175,
#     'dangerPings': 0,
#     'deaths': 12,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12413,
#     'goldSpent': 11550,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6672,
#     'item1': 3085,
#     'item2': 3006,
#     'item3': 3036,
#     'item4': 1036,
#     'item5': 1038,
#     'item6': 2052,
#     'itemsPurchased': 18,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'NONE',
#     'largestCriticalStrike': 419,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 127,
#     'magicDamageDealt': 3884,
#     'magicDamageDealtToChampions': 1514,
#     'magicDamageTaken': 12206,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 16, 'var2': 6, 'var3': 0},
#         {'perk': 8009, 'var1': 1708, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 10, 'var2': 40, 'var3': 0},
#         {'perk': 8014, 'var1': 639, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 789, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 320, 'var2': 4, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 46870,
#     'physicalDamageDealtToChampions': 19561,
#     'physicalDamageTaken': 12445,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6270,
#     'pushPings': 0,
#     'puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#     'quadraKills': 0,
#     'riotIdGameName': 'xiangyuejiuba',
#     'riotIdTagline': 'NA1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 12,
#     'spell2Casts': 54,
#     'spell3Casts': 18,
#     'spell4Casts': 11,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 7,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'ks7ExnXdsge1s4abn7VeEXBIrFf1Mw6ygFQK7TWWimVp5mzWcL5l6twJPA',
#     'summonerLevel': 272,
#     'summonerName': 'xiangyuejiuba',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 26,
#     'timePlayed': 1033,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 50754,
#     'totalDamageDealtToChampions': 21075,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25328,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3347,
#     'totalHealsOnTeammates': 445,
#     'totalMinionsKilled': 46,
#     'totalTimeCCDealt': 74,
#     'totalTimeSpentDead': 296,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 676,
#     'turretKills': 2,
#     'turretTakedowns': 2,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 24,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 97,
#      'acesBefore15Minutes': 1,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 1350,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1531.4005441307272,
#      'damageTakenOnTeamPercentage': 0.15883882273530758,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 24,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 8,
#      'gameLength': 1033.3860817,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 760.9097970977638,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 3.6666666666666665,
#      'killAfterHiddenWithAlly': 8,
#      'killParticipation': 0.6111111111111112,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 25,
#      'laneMinionsFirst10Minutes': 14,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [4633, 3115, 4646],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 12,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 3,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 5,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 22,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 19.76653540000001,
#      'skillshotsDodged': 30,
#      'skillshotsHit': 74,
#      'snowballsHit': 4,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 33,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 30,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.18930453361054145,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17385,
#     'champLevel': 17,
#     'championId': 110,
#     'championName': 'Varus',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 3417,
#     'damageDealtToObjectives': 3417,
#     'damageDealtToTurrets': 3417,
#     'damageSelfMitigated': 8691,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 3,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13105,
#     'goldSpent': 12450,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 4633,
#     'item1': 3115,
#     'item2': 3020,
#     'item3': 4646,
#     'item4': 1058,
#     'item5': 3145,
#     'item6': 2052,
#     'itemsPurchased': 20,
#     'killingSprees': 3,
#     'kills': 9,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 126,
#     'magicDamageDealt': 25953,
#     'magicDamageDealtToChampions': 16198,
#     'magicDamageTaken': 8255,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1683, 'var2': 26, 'var3': 0},
#         {'perk': 8126, 'var1': 824, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8236, 'var1': 24, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 51, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 21008,
#     'physicalDamageDealtToChampions': 9125,
#     'physicalDamageTaken': 11107,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 16,
#     'pushPings': 0,
#     'puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#     'quadraKills': 0,
#     'riotIdGameName': 'Hallelujer',
#     'riotIdTagline': 'NA1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 36,
#     'spell2Casts': 18,
#     'spell3Casts': 34,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 7,
#     'summoner2Id': 32,
#     'summonerId': 'oaVFSL-3O65LuPoV8XeX8qepKzEtuxhbZOIK-jg0bT3npmY',
#     'summonerLevel': 366,
#     'summonerName': 'Hallelujer',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 25,
#     'timePlayed': 1033,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 48013,
#     'totalDamageDealtToChampions': 26375,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19846,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1986,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 30,
#     'totalTimeCCDealt': 200,
#     'totalTimeSpentDead': 226,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1051,
#     'trueDamageDealtToChampions': 1051,
#     'trueDamageTaken': 482,
#     'turretKills': 0,
#     'turretTakedowns': 3,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 23,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 152,
#      'acesBefore15Minutes': 4,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1685.7153357042357,
#      'damageTakenOnTeamPercentage': 0.20395681901478283,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 15,
#      'dodgeSkillShotsSmallWindow': 30,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 684.4873073,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 5,
#      'gameLength': 1033.3860817,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 666.6059857541529,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.2,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.6,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 26,
#      'laneMinionsFirst10Minutes': 12,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6676, 6696, 3814],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 6,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 29,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 11.13765479999995,
#      'skillshotsDodged': 208,
#      'skillshotsHit': 51,
#      'snowballsHit': 7,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 33,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 30,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2544327894487486,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17094,
#     'champLevel': 17,
#     'championId': 238,
#     'championName': 'Zed',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 21,
#     'damageDealtToObjectives': 21,
#     'damageDealtToTurrets': 21,
#     'damageSelfMitigated': 17605,
#     'dangerPings': 0,
#     'deaths': 15,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11481,
#     'goldSpent': 10600,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6676,
#     'item1': 3158,
#     'item2': 6696,
#     'item3': 3814,
#     'item4': 1036,
#     'item5': 1036,
#     'item6': 2052,
#     'itemsPurchased': 24,
#     'killingSprees': 2,
#     'kills': 10,
#     'lane': 'NONE',
#     'largestCriticalStrike': 443,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 107,
#     'magicDamageDealt': 2678,
#     'magicDamageDealtToChampions': 1794,
#     'magicDamageTaken': 9024,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
# ...
#      'kda': 3.3333333333333335,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.5454545454545454,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 19,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6653, 3116, 3157],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 24,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 11.13765479999995,
#      'skillshotsDodged': 194,
#      'skillshotsHit': 6,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 30,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 27,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.06195466909579873,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17256,
#     'champLevel': 17,
#     'championId': 25,
#     'championName': 'Morgana',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 280,
#     'damageDealtToObjectives': 280,
#     'damageDealtToTurrets': 280,
#     'damageSelfMitigated': 16544,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10927,
#     'goldSpent': 10350,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6653,
#     'item1': 3020,
#     'item2': 3157,
#     'item3': 3116,
#     'item4': 1052,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 14,
#     'killingSprees': 0,
#     'kills': 4,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 228,
#     'magicDamageDealt': 25824,
#     'magicDamageDealtToChampions': 6266,
#     'magicDamageTaken': 4900,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 509, 'var2': 12, 'var3': 0},
#         {'perk': 8126, 'var1': 415, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 289, 'var3': 0},
#         {'perk': 8210, 'var1': 30, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 4628,
#     'physicalDamageDealtToChampions': 390,
#     'physicalDamageTaken': 17893,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6446,
#     'pushPings': 0,
#     'puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#     'quadraKills': 0,
#     'riotIdGameName': 'NightRaidRin',
#     'riotIdTagline': '1006',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 20,
#     'spell2Casts': 37,
#     'spell3Casts': 23,
#     'spell4Casts': 5,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 7,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'eZFkRa_HSBOsBUUjCD9BzHIpr9IqCTOU4hxupO4Ib-j2Zho',
#     'summonerLevel': 173,
#     'summonerName': 'NightRaidRin',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 16,
#     'timePlayed': 1033,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 30865,
#     'totalDamageDealtToChampions': 7069,
#     'totalDamageShieldedOnTeammates': 688,
#     'totalDamageTaken': 26978,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 4080,
#     'totalHealsOnTeammates': 328,
#     'totalMinionsKilled': 27,
#     'totalTimeCCDealt': 95,
#     'totalTimeSpentDead': 220,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 411,
#     'trueDamageDealtToChampions': 411,
#     'trueDamageTaken': 4183,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 2,
#     'assistMePings': 0,
#     'assists': 14,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 86,
#      'acesBefore15Minutes': 4,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 825,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 843.9109973995405,
#      'damageTakenOnTeamPercentage': 0.26811064589242395,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 51,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 25,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 684.4873073,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 5,
#      'gameLength': 1033.3860817,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 713.3327209672541,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 10,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.4444444444444446,
#      'killAfterHiddenWithAlly': 6,
#      'killParticipation': 0.4,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 8,
#      'landSkillShotsEarlyGame': 10,
#      'laneMinionsFirst10Minutes': 19,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3084, 3748, 3075],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 17,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 22.975897200000077,
#      'skillshotsDodged': 337,
#      'skillshotsHit': 13,
#      'snowballsHit': 6,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 1,
#      'takedownsFirstXMinutes': 22,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.12737537861049264,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17354,
#     'champLevel': 17,
#     'championId': 6,
#     'championName': 'Urgot',
#     'championTransform': 0,
#     'commandPings': 2,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 67,
#     'damageDealtToObjectives': 67,
#     'damageDealtToTurrets': 67,
#     'damageSelfMitigated': 35715,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12285,
#     'goldSpent': 11650,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3084,
#     'item1': 3111,
#     'item2': 3748,
#     'item3': 3075,
#     'item4': 2019,
#     'item5': 1036,
#     'item6': 2052,
#     'itemsPurchased': 20,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 206,
#     'magicDamageDealt': 1315,
#     'magicDamageDealtToChampions': 231,
#     'magicDamageTaken': 14760,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 247, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 1391, 'var2': 220, 'var3': 0},
#         {'perk': 9105, 'var1': 5, 'var2': 50, 'var3': 0},
#         {'perk': 8299, 'var1': 621, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8429, 'var1': 53, 'var2': 14, 'var3': 11},
#         {'perk': 8451, 'var1': 315, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 57030,
#     'physicalDamageDealtToChampions': 13543,
#     'physicalDamageTaken': 20608,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5451,
#     'pushPings': 0,
#     'puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#     'quadraKills': 0,
#     'riotIdGameName': 'SilouxV2',
#     'riotIdTagline': 'NA1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 29,
#     'spell2Casts': 32,
#     'spell3Casts': 19,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 15,
#     'summoner1Id': 32,
#     'summoner2Casts': 1,
#     'summoner2Id': 4,
#     'summonerId': 'rFZda_meq1oprRAGtywvV4x05Udlte6zfZBF2MLPvGzPvHLo',
#     'summonerLevel': 34,
#     'summonerName': 'SilouxV2',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 21,
#     'timePlayed': 1033,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 59105,
#     'totalDamageDealtToChampions': 14534,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 38625,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 4363,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 46,
#     'totalTimeCCDealt': 139,
#     'totalTimeSpentDead': 204,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 759,
#     'trueDamageDealtToChampions': 759,
#     'trueDamageTaken': 3257,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False}],
#   'platformId': 'NA1',
#   'queueId': 450,
#   'teams': [{'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 54},
#      'dragon': {'first': False, 'kills': 0},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 4}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 56},
#      'dragon': {'first': False, 'kills': 0},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 1}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
match_meta["info"]["gameMode"]
# Out:
# 'ARAM'

# %% [markdown]
# :)
#
# ### Time for timeline

# %%
timeline = lol_watcher.match.timeline_by_match(my_region, match_ids[0])
timeline
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4913902543',
#   'participants': ['_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#    'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#    '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#    'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#    'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#    '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#    '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#    'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#    'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#    'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA']},
#  'info': {'frameInterval': 60000,
#   'frames': [{'events': [{'realTimestamp': 1707196800096,
#       'timestamp': 0,
#       'type': 'PAUSE_END'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 19,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 558,
#        'healthMax': 558,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 385,
#        'powerMax': 385,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 1096, 'y': 1180},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 28,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 640,
#        'healthMax': 640,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 325,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 300,
#        'powerMax': 300,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 1135, 'y': 1063},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 33,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 669,
#        'healthMax': 669,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 355,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 251,
#        'powerMax': 251,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 1099, 'y': 944},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 26,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 630,
#        'healthMax': 630,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 325,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 260,
#        'powerMax': 260,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 1000, 'y': 870},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 27,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 600,
#        'healthMax': 600,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 360,
#        'powerMax': 360,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 877, 'y': 868},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 654,
#        'healthMax': 654,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 29,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 200,
#        'powerMax': 200,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 12020, 'y': 11716},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 26,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 640,
#        'healthMax': 640,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 325,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 280,
#        'powerMax': 280,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 12059, 'y': 11599},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 21,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 580,
#        'healthMax': 580,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 480,
#        'powerMax': 480,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 12023, 'y': 11480},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 25,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 630,
#        'healthMax': 630,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 340,
#        'powerMax': 340,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 11924, 'y': 11406},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 36,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 655,
#        'healthMax': 655,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 340,
#        'powerMax': 340,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1400,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 11801, 'y': 11404},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1400,
#       'xp': 660}},
#     'timestamp': 0},
#    {'events': [{'level': 2,
#       'participantId': 1,
#       'timestamp': 526,
#       'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 1, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 2, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 2, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 3, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 3, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 4, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 4, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 5, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 5, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 6, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 6, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 7, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 7, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 8, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 8, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 9, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 9, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 2, 'participantId': 10, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'level': 3, 'participantId': 10, 'timestamp': 526, 'type': 'LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 1,
#       'timestamp': 1491,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 2,
#       'timestamp': 1860,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 1,
#       'timestamp': 2232,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 3,
#       'timestamp': 2299,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 2,
#       'timestamp': 2635,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 3,
#       'timestamp': 3033,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 1,
#       'timestamp': 5173,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 2,
#       'timestamp': 5438,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 3,
#       'timestamp': 5671,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 1011,
#       'participantId': 10,
#       'timestamp': 6336,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1028,
#       'participantId': 10,
#       'timestamp': 6336,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 10,
#       'timestamp': 6336,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 10,
#       'timestamp': 6336,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3134,
#       'participantId': 5,
#       'timestamp': 7199,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3070,
#       'participantId': 5,
#       'timestamp': 7199,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 3070,
#       'goldGain': 400,
#       'participantId': 5,
#       'timestamp': 8400,
#       'type': 'ITEM_UNDO'},
#      {'afterId': 0,
#       'beforeId': 3134,
#       'goldGain': 1000,
#       'participantId': 5,
#       'timestamp': 8568,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 3177,
#       'participantId': 3,
#       'timestamp': 10499,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3147,
#       'participantId': 9,
#       'timestamp': 11302,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3070,
#       'participantId': 3,
#       'timestamp': 11435,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 1,
#       'skillSlot': 1,
#       'timestamp': 12169,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 1,
#       'skillSlot': 2,
#       'timestamp': 12302,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 1,
#       'skillSlot': 3,
#       'timestamp': 12533,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 3070,
#       'participantId': 2,
#       'timestamp': 12770,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1036,
#       'participantId': 2,
#       'timestamp': 12770,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1036,
#       'participantId': 2,
#       'timestamp': 12770,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1001,
#       'participantId': 2,
#       'timestamp': 12770,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3077,
#       'participantId': 6,
#       'timestamp': 13502,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2031,
#       'participantId': 6,
#       'timestamp': 13502,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 3070,
#       'goldGain': 400,
#       'participantId': 3,
#       'timestamp': 13668,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 3802,
#       'participantId': 1,
#       'timestamp': 14233,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2031,
#       'participantId': 1,
#       'timestamp': 14233,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1042,
#       'participantId': 3,
#       'timestamp': 14601,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 2031,
#       'goldGain': 150,
#       'participantId': 6,
#       'timestamp': 15004,
#       'type': 'ITEM_UNDO'},
#      {'afterId': 0,
#       'beforeId': 3077,
#       'goldGain': 1200,
#       'participantId': 6,
#       'timestamp': 15139,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 2031,
#       'participantId': 3,
#       'timestamp': 15404,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3134,
#       'participantId': 6,
#       'timestamp': 16072,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1001,
#       'participantId': 6,
#       'timestamp': 16072,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 16072,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 16072,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3802,
#       'participantId': 8,
#       'timestamp': 19571,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 1,
#       'timestamp': 19571,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 2,
#       'timestamp': 19803,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 3,
#       'timestamp': 20037,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 2031,
#       'participantId': 8,
#       'timestamp': 20469,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 1,
#       'timestamp': 20503,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 2,
#       'timestamp': 20637,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 3,
#       'timestamp': 20711,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 4,
#       'skillSlot': 1,
#       'timestamp': 21311,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 4,
#       'skillSlot': 2,
#       'timestamp': 21545,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 4,
#       'skillSlot': 3,
#       'timestamp': 21778,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 1,
#       'timestamp': 22778,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 2,
#       'timestamp': 23043,
#       'type': 'SKILL_LEVEL_UP'},
#      {'afterId': 0,
#       'beforeId': 2031,
#       'goldGain': 150,
#       'participantId': 1,
#       'timestamp': 23142,
#       'type': 'ITEM_UNDO'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 3,
#       'timestamp': 23209,
#       'type': 'SKILL_LEVEL_UP'},
#      {'afterId': 0,
#       'beforeId': 3802,
#       'goldGain': 1200,
#       'participantId': 1,
#       'timestamp': 23309,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 3147,
#       'participantId': 1,
#       'timestamp': 24643,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 24643,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 24643,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 6670,
#       'participantId': 4,
#       'timestamp': 26650,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3108,
#       'participantId': 5,
#       'timestamp': 35114,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1052,
#       'participantId': 5,
#       'timestamp': 37247,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 1,
#       'timestamp': 39484,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 2,
#       'timestamp': 39984,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 3,
#       'timestamp': 40518,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 1043,
#       'participantId': 7,
#       'timestamp': 41185,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1036,
#       'participantId': 7,
#       'timestamp': 42654,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1001,
#       'participantId': 7,
#       'timestamp': 44157,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 7,
#       'timestamp': 45353,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 10,
#       'timestamp': 55415,
#       'type': 'ITEM_DESTROYED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 1,
#       'timestamp': 58116,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 2,
#       'timestamp': 58514,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 3,
#       'timestamp': 58681,
#       'type': 'SKILL_LEVEL_UP'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 53,
#        'armor': 25,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 59,
#        'attackSpeed': 102,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 781,
#        'healthMax': 936,
#        'healthRegen': 15,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 31,
#        'movementSpeed': 408,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 359,
#        'powerMax': 414,
#        'powerRegen': 24,
#        'spellVamp': 0},
#       'currentGold': 3,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 180,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 180,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 5695, 'y': 5793},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1403,
#       'xp': 960},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 34,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 86,
#        'attackSpeed': 104,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 821,
#        'healthMax': 821,
#        'healthRegen': 9,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 31,
#        'movementSpeed': 405,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 520,
#        'powerMax': 617,
#        'powerRegen': 27,
#        'spellVamp': 0},
#       'currentGold': 3,
#       'damageStats': {'magicDamageDone': 99,
#        'magicDamageDoneToChampions': 99,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 125,
#        'totalDamageDoneToChampions': 125,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 26,
#        'trueDamageDoneToChampions': 26,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 6850, 'y': 5956},
#       'timeEnemySpentControlled': 5096,
#       'totalGold': 1403,
#       'xp': 960},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 39,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 103,
#        'attackSpeed': 127,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 849,
#        'healthMax': 996,
#        'healthRegen': 100,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 50,
#        'movementSpeed': 355,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 232,
#        'powerMax': 312,
#        'powerRegen': 20,
#        'spellVamp': 0},
#       'currentGold': 3,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 239,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 49,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 302,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 13},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 6076, 'y': 5967},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1403,
#       'xp': 960},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 99,
#        'attackSpeed': 126,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 814,
#        'healthMax': 814,
#        'healthRegen': 8,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 31,
#        'movementSpeed': 325,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 96,
#        'powerMax': 333,
#        'powerRegen': 21,
#        'spellVamp': 0},
#       'currentGold': 103,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 96,
#        'physicalDamageDoneToChampions': 96,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 96,
#        'totalDamageDoneToChampions': 96,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 5904, 'y': 6479},
#       'timeEnemySpentControlled': 2032,
#       'totalGold': 1403,
#       'xp': 960},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 73,
#        'armor': 33,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 67,
#        'attackSpeed': 105,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 784,
#        'healthMax': 784,
#        'healthRegen': 8,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 31,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 343,
#        'powerMax': 419,
#        'powerRegen': 24,
#        'spellVamp': 0},
#       'currentGold': 103,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 25,
#        'totalDamageDoneToChampions': 25,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 25,
#        'trueDamageDoneToChampions': 25,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 6023, 'y': 6114},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1403,
#       'xp': 960},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 103,
#        'attackSpeed': 104,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 19,
#        'cooldownReduction': 0,
#        'health': 821,
#        'healthMax': 830,
#        'healthRegen': 15,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 47,
#        'movementSpeed': 370,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 200,
#        'powerMax': 200,
#        'powerRegen': 120,
#        'spellVamp': 0},
#       'currentGold': 3,
#       'damageStats': {'magicDamageDone': 14,
#        'magicDamageDoneToChampions': 14,
#        'magicDamageTaken': 61,
#        'physicalDamageDone': 246,
#        'physicalDamageDoneToChampions': 49,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 261,
#        'totalDamageDoneToChampions': 63,
#        'totalDamageTaken': 73,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 12},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 7394, 'y': 6488},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1403,
#       'xp': 960},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 78,
#        'attackSpeed': 133,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 818,
#        'healthMax': 818,
#        'healthRegen': 8,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 31,
#        'movementSpeed': 350,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 331,
#        'powerMax': 331,
#        'powerRegen': 20,
#        'spellVamp': 0},
#       'currentGold': 3,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 7250, 'y': 6975},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1403,
#       'xp': 960},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 58,
#        'armor': 27,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 58,
#        'attackSpeed': 103,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 770,
#        'healthMax': 770,
#        'healthRegen': 12,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 31,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 796,
#        'powerMax': 849,
#        'powerRegen': 29,
#        'spellVamp': 0},
#       'currentGold': 53,
#       'damageStats': {'magicDamageDone': 454,
#        'magicDamageDoneToChampions': 406,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 467,
#        'totalDamageDoneToChampions': 419,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 13,
#        'trueDamageDoneToChampions': 13,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 6798, 'y': 7538},
#       'timeEnemySpentControlled': 4933,
#       'totalGold': 1403,
#       'xp': 960},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 53,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 61,
#        'attackSpeed': 102,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 1013,
#        'healthMax': 1013,
#        'healthRegen': 12,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 31,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 428,
#        'powerMax': 428,
#        'powerRegen': 29,
#        'spellVamp': 0},
#       'currentGold': 103,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 7356, 'y': 7394},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1403,
#       'xp': 960},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 44,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 79,
#        'attackSpeed': 105,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 5,
#        'cooldownReduction': 0,
#        'health': 1257,
#        'healthMax': 1335,
#        'healthRegen': 97,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 35,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 406,
#        'powerMax': 406,
#        'powerRegen': 22,
#        'spellVamp': 0},
#       'currentGold': 3,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 38,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 96,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 174,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 38},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 3,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 6510, 'y': 7309},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 1403,
#       'xp': 960}},
#     'timestamp': 60019},
#    {'events': [{'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 63354,
#       'type': 'ITEM_DESTROYED'},
#      {'itemId': 2003,
#       'participantId': 1,
#       'timestamp': 82120,
#       'type': 'ITEM_DESTROYED'},
#      {'level': 4, 'participantId': 1, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 2, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 3, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 4, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 5, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 6, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 7, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 8, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 9, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'level': 4, 'participantId': 10, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#      {'assistingParticipantIds': [6, 8, 9, 10],
#       'bounty': 270,
#       'killStreakLength': 0,
#       'killerId': 7,
#       'position': {'x': 6906, 'y': 5944},
#       'shutdownBounty': 0,
#       'timestamp': 85594,
#       'type': 'CHAMPION_KILL',
#       'victimDamageDealt': [{'basic': False,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 6,
#         'physicalDamage': 69,
#         'spellName': 'alphastrike',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 6,
#         'physicalDamage': 0,
#         'spellName': 'wujustyle',
#         'spellSlot': 2,
#         'trueDamage': 113,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 6,
#         'physicalDamage': 70,
#         'spellName': 'masteryibasicattack2',
#         'spellSlot': 65,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 6,
#         'physicalDamage': 70,
#         'spellName': 'masteryibasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 9,
#         'physicalDamage': 64,
#         'spellName': 'alphastrike',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': 'wujustyle',
#         'spellSlot': 2,
#         'trueDamage': 31,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 10,
#         'physicalDamage': 62,
#         'spellName': 'alphastrike',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'MasterYi',
#         'participantId': 10,
#         'physicalDamage': 0,
#         'spellName': 'wujustyle',
#         'spellSlot': 2,
#         'trueDamage': 33,
#         'type': 'OTHER'}],
#       'victimDamageReceived': [{'basic': False,
#         'magicDamage': 89,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'hweipassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 11,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'hweiqe',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 24,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'hweiqe',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 67,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'hweiee',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 70,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'hweiwe',
#         'spellSlot': 1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 23,
#         'spellName': 'hweibasicattack',
#         'spellSlot': 52,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 13,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Hwei',
#         'participantId': 8,
#         'physicalDamage': 22,
#         'spellName': 'hweibasicattack2',
#         'spellSlot': 52,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 38,
#         'name': 'Zed',
#         'participantId': 6,
#         'physicalDamage': 0,
#         'spellName': 'zedpassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Zed',
#         'participantId': 6,
#         'physicalDamage': 102,
#         'spellName': 'zede',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Zed',
#         'participantId': 6,
#         'physicalDamage': 82,
#         'spellName': 'zedq',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Zed',
#         'participantId': 6,
#         'physicalDamage': 128,
#         'spellName': 'zedbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Urgot',
#         'participantId': 10,
#         'physicalDamage': 148,
#         'spellName': 'urgotw',
#         'spellSlot': 1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Urgot',
#         'participantId': 10,
#         'physicalDamage': 77,
#         'spellName': 'urgotpassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Ashe',
#         'participantId': 7,
#         'physicalDamage': 81,
#         'spellName': 'asheq',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Ashe',
#         'participantId': 7,
#         'physicalDamage': 74,
#         'spellName': 'volley',
#         'spellSlot': 1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 17,
#         'name': 'Ashe',
#         'participantId': 7,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Morgana',
#         'participantId': 9,
#         'physicalDamage': 22,
#         'spellName': 'morganabasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 9,
#         'name': 'Morgana',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 12,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Morgana',
#         'participantId': 9,
#         'physicalDamage': 21,
#         'spellName': 'morganabasicattack2',
#         'spellSlot': 65,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimId': 3},
#      {'killType': 'KILL_FIRST_BLOOD',
#       'killerId': 7,
#       'position': {'x': 6748, 'y': 6258},
#       'timestamp': 85594,
#       'type': 'CHAMPION_SPECIAL_KILL'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 4,
#       'skillSlot': 1,
#       'timestamp': 85824,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 1,
#       'timestamp': 85891,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 1,
#       'timestamp': 86554,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 1,
#       'timestamp': 86954,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 1,
#       'timestamp': 87357,
# ...
#         'magicDamage': 0,
#         'name': 'HA_AP_ChaosTurretShrine',
#         'participantId': 0,
#         'physicalDamage': 0,
#         'spellName': 'ha_ap_chaosturretshrinebasicattack',
#         'spellSlot': 64,
#         'trueDamage': 2000,
#         'type': 'TOWER'}],
#       'victimId': 2},
#      {'level': 17,
#       'participantId': 6,
#       'timestamp': 1028403,
#       'type': 'LEVEL_UP'},
#      {'gameId': 4913902543,
#       'realTimestamp': 1707197833541,
#       'timestamp': 1033386,
#       'type': 'GAME_END',
#       'winningTeam': 100}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 403,
#        'armor': 90,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 101,
#        'attackSpeed': 123,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 3155,
#        'healthRegen': 32,
#        'lifesteal': 0,
#        'magicPen': 30,
#        'magicPenPercent': 0,
#        'magicResist': 52,
#        'movementSpeed': 385,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 725,
#        'powerMax': 725,
#        'powerRegen': 53,
#        'spellVamp': 0},
#       'currentGold': 828,
#       'damageStats': {'magicDamageDone': 43109,
#        'magicDamageDoneToChampions': 16884,
#        'magicDamageTaken': 10766,
#        'physicalDamageDone': 1923,
#        'physicalDamageDoneToChampions': 460,
#        'physicalDamageTaken': 12098,
#        'totalDamageDone': 45833,
#        'totalDamageDoneToChampions': 18144,
#        'totalDamageTaken': 23293,
#        'trueDamageDone': 800,
#        'trueDamageDoneToChampions': 800,
#        'trueDamageTaken': 428},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 18,
#       'minionsKilled': 40,
#       'participantId': 1,
#       'position': {'x': 11120, 'y': 9911},
#       'timeEnemySpentControlled': 201274,
#       'totalGold': 12078,
#       'xp': 18913},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 99,
#        'armorPen': 0,
#        'armorPenPercent': 30,
#        'attackDamage': 357,
#        'attackSpeed': 186,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2571,
#        'healthRegen': 29,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 52,
#        'movementSpeed': 370,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1743,
#        'powerMax': 1840,
#        'powerRegen': 69,
#        'spellVamp': 0},
#       'currentGold': 986,
#       'damageStats': {'magicDamageDone': 6919,
#        'magicDamageDoneToChampions': 2264,
#        'magicDamageTaken': 8984,
#        'physicalDamageDone': 61215,
#        'physicalDamageDoneToChampions': 24518,
#        'physicalDamageTaken': 10228,
#        'totalDamageDone': 69878,
#        'totalDamageDoneToChampions': 28527,
#        'totalDamageTaken': 21967,
#        'trueDamageDone': 1743,
#        'trueDamageDoneToChampions': 1743,
#        'trueDamageTaken': 2754},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 18,
#       'minionsKilled': 51,
#       'participantId': 2,
#       'position': {'x': 11581, 'y': 10822},
#       'timeEnemySpentControlled': 170770,
#       'totalGold': 14086,
#       'xp': 18663},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 154,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 235,
#        'attackSpeed': 287,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 44,
#        'cooldownReduction': 0,
#        'health': 1206,
#        'healthMax': 2999,
#        'healthRegen': 37,
#        'lifesteal': 8,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 206,
#        'movementSpeed': 540,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 804,
#        'powerMax': 965,
#        'powerRegen': 43,
#        'spellVamp': 0},
#       'currentGold': 1723,
#       'damageStats': {'magicDamageDone': 8932,
#        'magicDamageDoneToChampions': 5393,
#        'magicDamageTaken': 9088,
#        'physicalDamageDone': 47774,
#        'physicalDamageDoneToChampions': 28954,
#        'physicalDamageTaken': 24654,
#        'totalDamageDone': 69186,
#        'totalDamageDoneToChampions': 45204,
#        'totalDamageTaken': 34511,
#        'trueDamageDone': 12479,
#        'trueDamageDoneToChampions': 10856,
#        'trueDamageTaken': 769},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 18,
#       'minionsKilled': 32,
#       'participantId': 3,
#       'position': {'x': 10507, 'y': 10286},
#       'timeEnemySpentControlled': 16490,
#       'totalGold': 14363,
#       'xp': 19992},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 94,
#        'armorPen': 0,
#        'armorPenPercent': 30,
#        'attackDamage': 239,
#        'attackSpeed': 331,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 2377,
#        'healthMax': 2394,
#        'healthRegen': 21,
#        'lifesteal': 5,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 48,
#        'movementSpeed': 395,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 983,
#        'powerMax': 983,
#        'powerRegen': 56,
#        'spellVamp': 0},
#       'currentGold': 863,
#       'damageStats': {'magicDamageDone': 3884,
#        'magicDamageDoneToChampions': 1514,
#        'magicDamageTaken': 12206,
#        'physicalDamageDone': 46870,
#        'physicalDamageDoneToChampions': 19561,
#        'physicalDamageTaken': 12445,
#        'totalDamageDone': 50754,
#        'totalDamageDoneToChampions': 21075,
#        'totalDamageTaken': 25328,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 676},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 16,
#       'minionsKilled': 46,
#       'participantId': 4,
#       'position': {'x': 10623, 'y': 9917},
#       'timeEnemySpentControlled': 74603,
#       'totalGold': 12413,
#       'xp': 16140},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 462,
#        'armor': 99,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 115,
#        'attackSpeed': 212,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 2770,
#        'healthMax': 2770,
#        'healthRegen': 24,
#        'lifesteal': 0,
#        'magicPen': 28,
#        'magicPenPercent': 0,
#        'magicResist': 50,
#        'movementSpeed': 393,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 988,
#        'powerMax': 988,
#        'powerRegen': 55,
#        'spellVamp': 0},
#       'currentGold': 655,
#       'damageStats': {'magicDamageDone': 25953,
#        'magicDamageDoneToChampions': 16198,
#        'magicDamageTaken': 8255,
#        'physicalDamageDone': 21008,
#        'physicalDamageDoneToChampions': 9125,
#        'physicalDamageTaken': 11107,
#        'totalDamageDone': 48013,
#        'totalDamageDoneToChampions': 26375,
#        'totalDamageTaken': 19846,
#        'trueDamageDone': 1051,
#        'trueDamageDoneToChampions': 1051,
#        'trueDamageTaken': 482},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 17,
#       'minionsKilled': 30,
#       'participantId': 5,
#       'position': {'x': 10751, 'y': 10236},
#       'timeEnemySpentControlled': 200000,
#       'totalGold': 13105,
#       'xp': 17385},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 105,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 330,
#        'attackSpeed': 151,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 19,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2630,
#        'healthRegen': 34,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 76,
#        'movementSpeed': 390,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 141,
#        'powerMax': 200,
#        'powerRegen': 120,
#        'spellVamp': 0},
#       'currentGold': 881,
#       'damageStats': {'magicDamageDone': 2678,
#        'magicDamageDoneToChampions': 1794,
#        'magicDamageTaken': 9024,
#        'physicalDamageDone': 43362,
#        'physicalDamageDoneToChampions': 26440,
#        'physicalDamageTaken': 18311,
#        'totalDamageDone': 49369,
#        'totalDamageDoneToChampions': 29033,
#        'totalDamageTaken': 29383,
#        'trueDamageDone': 3328,
#        'trueDamageDoneToChampions': 798,
#        'trueDamageTaken': 2047},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 17,
#       'minionsKilled': 18,
#       'participantId': 6,
#       'position': {'x': 11212, 'y': 9918},
#       'timeEnemySpentControlled': 98466,
#       'totalGold': 11481,
#       'xp': 17094},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 92,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 227,
#        'attackSpeed': 331,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2346,
#        'healthRegen': 22,
#        'lifesteal': 13,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 48,
#        'movementSpeed': 395,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 867,
#        'powerMax': 906,
#        'powerRegen': 45,
#        'spellVamp': 0},
#       'currentGold': 592,
#       'damageStats': {'magicDamageDone': 4208,
#        'magicDamageDoneToChampions': 2532,
#        'magicDamageTaken': 7039,
#        'physicalDamageDone': 54118,
#        'physicalDamageDoneToChampions': 20963,
#        'physicalDamageTaken': 18217,
#        'totalDamageDone': 58326,
#        'totalDamageDoneToChampions': 23495,
#        'totalDamageTaken': 28167,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 2911},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 16,
#       'minionsKilled': 62,
#       'participantId': 7,
#       'position': {'x': 9247, 'y': 9141},
#       'timeEnemySpentControlled': 308648,
#       'totalGold': 13742,
#       'xp': 15388},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 512,
#        'armor': 100,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 110,
#        'attackSpeed': 142,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 2913,
#        'healthRegen': 29,
#        'lifesteal': 0,
#        'magicPen': 30,
#        'magicPenPercent': 0,
#        'magicResist': 52,
#        'movementSpeed': 375,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1490,
#        'powerMax': 1840,
#        'powerRegen': 66,
#        'spellVamp': 0},
#       'currentGold': 698,
#       'damageStats': {'magicDamageDone': 83365,
#        'magicDamageDoneToChampions': 38476,
#        'magicDamageTaken': 6532,
#        'physicalDamageDone': 2449,
#        'physicalDamageDoneToChampions': 358,
#        'physicalDamageTaken': 12326,
#        'totalDamageDone': 87253,
#        'totalDamageDoneToChampions': 39976,
#        'totalDamageTaken': 20910,
#        'trueDamageDone': 1439,
#        'trueDamageDoneToChampions': 1141,
#        'trueDamageTaken': 2052},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 18,
#       'minionsKilled': 48,
#       'participantId': 8,
#       'position': {'x': 7245, 'y': 6916},
#       'timeEnemySpentControlled': 364706,
#       'totalGold': 13588,
#       'xp': 19638},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 353,
#        'armor': 153,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 111,
#        'attackSpeed': 124,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 3134,
#        'healthRegen': 23,
#        'lifesteal': 0,
#        'magicPen': 18,
#        'magicPenPercent': 0,
#        'magicResist': 50,
#        'movementSpeed': 380,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1296,
#        'powerMax': 1533,
#        'powerRegen': 56,
#        'spellVamp': 0},
#       'currentGold': 577,
#       'damageStats': {'magicDamageDone': 25824,
#        'magicDamageDoneToChampions': 6266,
#        'magicDamageTaken': 4900,
#        'physicalDamageDone': 4628,
#        'physicalDamageDoneToChampions': 390,
#        'physicalDamageTaken': 17893,
#        'totalDamageDone': 30865,
#        'totalDamageDoneToChampions': 7069,
#        'totalDamageTaken': 26978,
#        'trueDamageDone': 411,
#        'trueDamageDoneToChampions': 411,
#        'trueDamageTaken': 4183},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 17,
#       'minionsKilled': 27,
#       'participantId': 9,
#       'position': {'x': 7426, 'y': 8130},
#       'timeEnemySpentControlled': 95757,
#       'totalGold': 10927,
#       'xp': 17256},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 236,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 211,
#        'attackSpeed': 158,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 44,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 4609,
#        'healthRegen': 111,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 100,
#        'movementSpeed': 375,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 931,
#        'powerMax': 1047,
#        'powerRegen': 54,
#        'spellVamp': 0},
#       'currentGold': 635,
#       'damageStats': {'magicDamageDone': 1315,
#        'magicDamageDoneToChampions': 231,
#        'magicDamageTaken': 14760,
#        'physicalDamageDone': 57030,
#        'physicalDamageDoneToChampions': 13543,
#        'physicalDamageTaken': 20608,
#        'totalDamageDone': 59105,
#        'totalDamageDoneToChampions': 14534,
#        'totalDamageTaken': 38625,
#        'trueDamageDone': 759,
#        'trueDamageDoneToChampions': 759,
#        'trueDamageTaken': 3257},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 17,
#       'minionsKilled': 46,
#       'participantId': 10,
#       'position': {'x': 7324, 'y': 7579},
#       'timeEnemySpentControlled': 139156,
#       'totalGold': 12285,
#       'xp': 17354}},
#     'timestamp': 1033386}],
#   'gameId': 4913902543,
#   'participants': [{'participantId': 1,
#     'puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw'},
#    {'participantId': 2,
#     'puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ'},
#    {'participantId': 3,
#     'puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ'},
#    {'participantId': 4,
#     'puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA'},
#    {'participantId': 5,
#     'puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w'},
#    {'participantId': 6,
#     'puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg'},
#    {'participantId': 7,
#     'puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q'},
#    {'participantId': 8,
#     'puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ'},
#    {'participantId': 9,
#     'puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w'},
#    {'participantId': 10,
#     'puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA'}]}}

# %% [markdown]
# ### This is a lot, gotta study the keys

# %%
timeline.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
timeline["metadata"]
# Out:
# {'dataVersion': '2',
#  'matchId': 'NA1_4913902543',
#  'participants': ['_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA']}

# %% [markdown]
# Metadata gives us particpants, looking at `player_data` this looks like they are `puuid`. So we could find a new match by selecting a random puuid and randomly selecting a match we haven't seen before simliar to the crawl idea in https://github.com/christophM/LolCrawler. Note I am repeating this github link because when we do write about the data collection process, we should cite this for giving us the idea behind it

# %%
player_data["puuid"], player_data["puuid"] in timeline["metadata"]["participants"]
# Out:
# ('GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#  True)

# %% [markdown]
# Now for info

# %%
timeline["info"].keys()
# Out:
# dict_keys(['frameInterval', 'frames', 'gameId', 'participants'])

# %% [markdown]
# According to https://www.doranslab.gg/tools/jungle-tool.html, we get updates every minute, probably what below is saying

# %%
timeline["info"]["frameInterval"]
# Out:
# 60000

# %% [markdown]
# So gameID gives us a new id type for the match, for partipants it looks like they have a unique id interally for the game... sure I guess that helps save space in the frames

# %%
timeline["info"]["gameId"], timeline["info"]["participants"]
# Out:
# (4913902543,
#  [{'participantId': 1,
#    'puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw'},
#   {'participantId': 2,
#    'puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ'},
#   {'participantId': 3,
#    'puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ'},
#   {'participantId': 4,
#    'puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA'},
#   {'participantId': 5,
#    'puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w'},
#   {'participantId': 6,
#    'puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg'},
#   {'participantId': 7,
#    'puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q'},
#   {'participantId': 8,
#    'puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ'},
#   {'participantId': 9,
#    'puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w'},
#   {'participantId': 10,
#    'puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA'}])

# %% [markdown]
# Frames is where the data we care about lies, it is a list

# %%
type(timeline["info"]["frames"]), len(timeline["info"]["frames"])
# Out:
# (list, 19)

# %% [markdown]
# So above was around a 20 minute game, that explains alot I was playing aram.
#
# lets look at the frist point

# %%
timeline["info"]["frames"][0]
# Out:
# {'events': [{'realTimestamp': 1707196800096,
#    'timestamp': 0,
#    'type': 'PAUSE_END'}],
#  'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 19,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 558,
#     'healthMax': 558,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 340,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 385,
#     'powerMax': 385,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 1,
#    'position': {'x': 1096, 'y': 1180},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '2': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 28,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 640,
#     'healthMax': 640,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 325,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 300,
#     'powerMax': 300,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 2,
#    'position': {'x': 1135, 'y': 1063},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '3': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 33,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 669,
#     'healthMax': 669,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 32,
#     'movementSpeed': 355,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 251,
#     'powerMax': 251,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 3,
#    'position': {'x': 1099, 'y': 944},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '4': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 26,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 630,
#     'healthMax': 630,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 325,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 260,
#     'powerMax': 260,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 4,
#    'position': {'x': 1000, 'y': 870},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '5': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 27,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 600,
#     'healthMax': 600,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 330,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 360,
#     'powerMax': 360,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 5,
#    'position': {'x': 877, 'y': 868},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '6': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 32,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 654,
#     'healthMax': 654,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 29,
#     'movementSpeed': 345,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 200,
#     'powerMax': 200,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 6,
#    'position': {'x': 12020, 'y': 11716},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '7': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 26,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 640,
#     'healthMax': 640,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 325,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 280,
#     'powerMax': 280,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 7,
#    'position': {'x': 12059, 'y': 11599},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '8': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 21,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 580,
#     'healthMax': 580,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 330,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 480,
#     'powerMax': 480,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 8,
#    'position': {'x': 12023, 'y': 11480},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '9': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 25,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 630,
#     'healthMax': 630,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 30,
#     'movementSpeed': 335,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 340,
#     'powerMax': 340,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 9,
#    'position': {'x': 11924, 'y': 11406},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660},
#   '10': {'championStats': {'abilityHaste': 0,
#     'abilityPower': 0,
#     'armor': 36,
#     'armorPen': 0,
#     'armorPenPercent': 0,
#     'attackDamage': 25,
#     'attackSpeed': 100,
#     'bonusArmorPenPercent': 0,
#     'bonusMagicPenPercent': 0,
#     'ccReduction': 0,
#     'cooldownReduction': 0,
#     'health': 655,
#     'healthMax': 655,
#     'healthRegen': 0,
#     'lifesteal': 0,
#     'magicPen': 0,
#     'magicPenPercent': 0,
#     'magicResist': 32,
#     'movementSpeed': 330,
#     'omnivamp': 0,
#     'physicalVamp': 0,
#     'power': 340,
#     'powerMax': 340,
#     'powerRegen': 0,
#     'spellVamp': 0},
#    'currentGold': 1400,
#    'damageStats': {'magicDamageDone': 0,
#     'magicDamageDoneToChampions': 0,
#     'magicDamageTaken': 0,
#     'physicalDamageDone': 0,
#     'physicalDamageDoneToChampions': 0,
#     'physicalDamageTaken': 0,
#     'totalDamageDone': 0,
#     'totalDamageDoneToChampions': 0,
#     'totalDamageTaken': 0,
#     'trueDamageDone': 0,
#     'trueDamageDoneToChampions': 0,
#     'trueDamageTaken': 0},
#    'goldPerSecond': 0,
#    'jungleMinionsKilled': 0,
#    'level': 1,
#    'minionsKilled': 0,
#    'participantId': 10,
#    'position': {'x': 11801, 'y': 11404},
#    'timeEnemySpentControlled': 0,
#    'totalGold': 1400,
#    'xp': 660}},
#  'timestamp': 0}

# %%
timeline["info"]["frames"][0].keys()
# Out:
# dict_keys(['events', 'participantFrames', 'timestamp'])

# %%
timeline["info"]["frames"][0]["participantFrames"]["1"]
# Out:
# {'championStats': {'abilityHaste': 0,
#   'abilityPower': 0,
#   'armor': 19,
#   'armorPen': 0,
#   'armorPenPercent': 0,
#   'attackDamage': 25,
#   'attackSpeed': 100,
#   'bonusArmorPenPercent': 0,
#   'bonusMagicPenPercent': 0,
#   'ccReduction': 0,
#   'cooldownReduction': 0,
#   'health': 558,
#   'healthMax': 558,
#   'healthRegen': 0,
#   'lifesteal': 0,
#   'magicPen': 0,
#   'magicPenPercent': 0,
#   'magicResist': 30,
#   'movementSpeed': 340,
#   'omnivamp': 0,
#   'physicalVamp': 0,
#   'power': 385,
#   'powerMax': 385,
#   'powerRegen': 0,
#   'spellVamp': 0},
#  'currentGold': 1400,
#  'damageStats': {'magicDamageDone': 0,
#   'magicDamageDoneToChampions': 0,
#   'magicDamageTaken': 0,
#   'physicalDamageDone': 0,
#   'physicalDamageDoneToChampions': 0,
#   'physicalDamageTaken': 0,
#   'totalDamageDone': 0,
#   'totalDamageDoneToChampions': 0,
#   'totalDamageTaken': 0,
#   'trueDamageDone': 0,
#   'trueDamageDoneToChampions': 0,
#   'trueDamageTaken': 0},
#  'goldPerSecond': 0,
#  'jungleMinionsKilled': 0,
#  'level': 1,
#  'minionsKilled': 0,
#  'participantId': 1,
#  'position': {'x': 1096, 'y': 1180},
#  'timeEnemySpentControlled': 0,
#  'totalGold': 1400,
#  'xp': 660}

# %%
timeline["info"]["frames"][0]["participantFrames"]["1"].keys()
# Out:
# dict_keys(['championStats', 'currentGold', 'damageStats', 'goldPerSecond', 'jungleMinionsKilled', 'level', 'minionsKilled', 'participantId', 'position', 'timeEnemySpentControlled', 'totalGold', 'xp'])

# %% [markdown]
# Wait, that is really cool we get the following data:
#
# ['championStats', 'currentGold', 'damageStats', 'goldPerSecond', 'jungleMinionsKilled', 'level', 'minionsKilled', 'participantId', 'position', 'timeEnemySpentControlled', 'totalGold', 'xp']
#
# And under chamption stats we get
# ['abilityHaste', 'abilityPower', 'armor', 'armorPen', 'armorPenPercent', 'attackDamage', 'attackSpeed', 'bonusArmorPenPercent', 'bonusMagicPenPercent', 'ccReduction', 'cooldownReduction', 'health', 'healthMax', 'healthRegen', 'lifesteal', 'magicPen', 'magicPenPercent', 'magicResist', 'movementSpeed', 'omnivamp', 'physicalVamp', 'power', 'powerMax', 'powerRegen', 'spellVamp']
#
# Wow... that is a lot of data

# %%
timeline["info"]["frames"][0]["participantFrames"]["1"]["championStats"].keys()
# Out:
# dict_keys(['abilityHaste', 'abilityPower', 'armor', 'armorPen', 'armorPenPercent', 'attackDamage', 'attackSpeed', 'bonusArmorPenPercent', 'bonusMagicPenPercent', 'ccReduction', 'cooldownReduction', 'health', 'healthMax', 'healthRegen', 'lifesteal', 'magicPen', 'magicPenPercent', 'magicResist', 'movementSpeed', 'omnivamp', 'physicalVamp', 'power', 'powerMax', 'powerRegen', 'spellVamp'])

# %% [markdown]
# What does events actually mean?|

# %%
timeline["info"]["frames"][1]["events"]
# Out:
# [{'level': 2, 'participantId': 1, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 1, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 2, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 2, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 3, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 3, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 4, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 4, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 5, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 5, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 6, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 6, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 7, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 7, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 8, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 8, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 9, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 9, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 10, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'level': 3, 'participantId': 10, 'timestamp': 526, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 3,
#   'skillSlot': 1,
#   'timestamp': 1491,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 3,
#   'skillSlot': 2,
#   'timestamp': 1860,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 1,
#   'timestamp': 2232,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 3,
#   'skillSlot': 3,
#   'timestamp': 2299,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 2,
#   'timestamp': 2635,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 3,
#   'timestamp': 3033,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 9,
#   'skillSlot': 1,
#   'timestamp': 5173,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 9,
#   'skillSlot': 2,
#   'timestamp': 5438,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 9,
#   'skillSlot': 3,
#   'timestamp': 5671,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1011,
#   'participantId': 10,
#   'timestamp': 6336,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1028,
#   'participantId': 10,
#   'timestamp': 6336,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 10,
#   'timestamp': 6336,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 10,
#   'timestamp': 6336,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3134,
#   'participantId': 5,
#   'timestamp': 7199,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3070,
#   'participantId': 5,
#   'timestamp': 7199,
#   'type': 'ITEM_PURCHASED'},
#  {'afterId': 0,
#   'beforeId': 3070,
#   'goldGain': 400,
#   'participantId': 5,
#   'timestamp': 8400,
#   'type': 'ITEM_UNDO'},
#  {'afterId': 0,
#   'beforeId': 3134,
#   'goldGain': 1000,
#   'participantId': 5,
#   'timestamp': 8568,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 3177,
#   'participantId': 3,
#   'timestamp': 10499,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3147,
#   'participantId': 9,
#   'timestamp': 11302,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3070,
#   'participantId': 3,
#   'timestamp': 11435,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 1,
#   'timestamp': 12169,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 2,
#   'timestamp': 12302,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 3,
#   'timestamp': 12533,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 3070,
#   'participantId': 2,
#   'timestamp': 12770,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1036,
#   'participantId': 2,
#   'timestamp': 12770,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1036,
#   'participantId': 2,
#   'timestamp': 12770,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1001,
#   'participantId': 2,
#   'timestamp': 12770,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3077,
#   'participantId': 6,
#   'timestamp': 13502,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2031,
#   'participantId': 6,
#   'timestamp': 13502,
#   'type': 'ITEM_PURCHASED'},
#  {'afterId': 0,
#   'beforeId': 3070,
#   'goldGain': 400,
#   'participantId': 3,
#   'timestamp': 13668,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 3802,
#   'participantId': 1,
#   'timestamp': 14233,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2031,
#   'participantId': 1,
#   'timestamp': 14233,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1042,
#   'participantId': 3,
#   'timestamp': 14601,
#   'type': 'ITEM_PURCHASED'},
#  {'afterId': 0,
#   'beforeId': 2031,
#   'goldGain': 150,
#   'participantId': 6,
#   'timestamp': 15004,
#   'type': 'ITEM_UNDO'},
#  {'afterId': 0,
#   'beforeId': 3077,
#   'goldGain': 1200,
#   'participantId': 6,
#   'timestamp': 15139,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 2031,
#   'participantId': 3,
#   'timestamp': 15404,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3134,
#   'participantId': 6,
#   'timestamp': 16072,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1001,
#   'participantId': 6,
#   'timestamp': 16072,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 16072,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 16072,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3802,
#   'participantId': 8,
#   'timestamp': 19571,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 2,
#   'skillSlot': 1,
#   'timestamp': 19571,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 2,
#   'skillSlot': 2,
#   'timestamp': 19803,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 2,
#   'skillSlot': 3,
#   'timestamp': 20037,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 2031,
#   'participantId': 8,
#   'timestamp': 20469,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 1,
#   'timestamp': 20503,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 2,
#   'timestamp': 20637,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 3,
#   'timestamp': 20711,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 1,
#   'timestamp': 21311,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 2,
#   'timestamp': 21545,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 3,
#   'timestamp': 21778,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 8,
#   'skillSlot': 1,
#   'timestamp': 22778,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 8,
#   'skillSlot': 2,
#   'timestamp': 23043,
#   'type': 'SKILL_LEVEL_UP'},
#  {'afterId': 0,
#   'beforeId': 2031,
#   'goldGain': 150,
#   'participantId': 1,
#   'timestamp': 23142,
#   'type': 'ITEM_UNDO'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 8,
#   'skillSlot': 3,
#   'timestamp': 23209,
#   'type': 'SKILL_LEVEL_UP'},
#  {'afterId': 0,
#   'beforeId': 3802,
#   'goldGain': 1200,
#   'participantId': 1,
#   'timestamp': 23309,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 3147,
#   'participantId': 1,
#   'timestamp': 24643,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 1,
#   'timestamp': 24643,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 1,
#   'timestamp': 24643,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 6670,
#   'participantId': 4,
#   'timestamp': 26650,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3108,
#   'participantId': 5,
#   'timestamp': 35114,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1052,
#   'participantId': 5,
#   'timestamp': 37247,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 5,
#   'skillSlot': 1,
#   'timestamp': 39484,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 5,
#   'skillSlot': 2,
#   'timestamp': 39984,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 5,
#   'skillSlot': 3,
#   'timestamp': 40518,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1043,
#   'participantId': 7,
#   'timestamp': 41185,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1036,
#   'participantId': 7,
#   'timestamp': 42654,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1001,
#   'participantId': 7,
#   'timestamp': 44157,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 7,
#   'timestamp': 45353,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 10,
#   'timestamp': 55415,
#   'type': 'ITEM_DESTROYED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 1,
#   'timestamp': 58116,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 2,
#   'timestamp': 58514,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 3,
#   'timestamp': 58681,
#   'type': 'SKILL_LEVEL_UP'}]

# %% [markdown]
# ### Okay that is interesting
#
# So events tell us even more things that happened during that time. This is after the frist minute so naturally players are buying thier frist items.

# %%
timeline["info"]["frames"][2]["events"]
# Out:
# [{'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 63354,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 2003,
#   'participantId': 1,
#   'timestamp': 82120,
#   'type': 'ITEM_DESTROYED'},
#  {'level': 4, 'participantId': 1, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 2, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 3, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 4, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 5, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 6, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 7, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 8, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 9, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'level': 4, 'participantId': 10, 'timestamp': 84527, 'type': 'LEVEL_UP'},
#  {'assistingParticipantIds': [6, 8, 9, 10],
#   'bounty': 270,
#   'killStreakLength': 0,
#   'killerId': 7,
#   'position': {'x': 6906, 'y': 5944},
#   'shutdownBounty': 0,
#   'timestamp': 85594,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 6,
#     'physicalDamage': 69,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 113,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 6,
#     'physicalDamage': 70,
#     'spellName': 'masteryibasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 6,
#     'physicalDamage': 70,
#     'spellName': 'masteryibasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 9,
#     'physicalDamage': 64,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 31,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 10,
#     'physicalDamage': 62,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 33,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 89,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweipassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 11,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiqe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 24,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiqe',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 67,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiee',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 70,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiwe',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 23,
#     'spellName': 'hweibasicattack',
#     'spellSlot': 52,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 13,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 22,
#     'spellName': 'hweibasicattack2',
#     'spellSlot': 52,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 38,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'zedpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 102,
#     'spellName': 'zede',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 82,
#     'spellName': 'zedq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 128,
#     'spellName': 'zedbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Urgot',
#     'participantId': 10,
#     'physicalDamage': 148,
#     'spellName': 'urgotw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Urgot',
#     'participantId': 10,
#     'physicalDamage': 77,
#     'spellName': 'urgotpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 81,
#     'spellName': 'asheq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 74,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 17,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 22,
#     'spellName': 'morganabasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 9,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 12,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 21,
#     'spellName': 'morganabasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 3},
#  {'killType': 'KILL_FIRST_BLOOD',
#   'killerId': 7,
#   'position': {'x': 6748, 'y': 6258},
#   'timestamp': 85594,
#   'type': 'CHAMPION_SPECIAL_KILL'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 1,
#   'timestamp': 85824,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 5,
#   'skillSlot': 1,
#   'timestamp': 85891,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 9,
#   'skillSlot': 1,
#   'timestamp': 86554,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 8,
#   'skillSlot': 1,
#   'timestamp': 86954,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 1,
#   'timestamp': 87357,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 1,
#   'timestamp': 87692,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 1,
#   'timestamp': 89695,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 3,
#   'skillSlot': 1,
#   'timestamp': 89926,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 90060,
#   'type': 'ITEM_DESTROYED'},
#  {'assistingParticipantIds': [6, 8, 9, 10],
#   'bounty': 180,
#   'killStreakLength': 1,
#   'killerId': 7,
#   'position': {'x': 6113, 'y': 5413},
#   'shutdownBounty': 0,
#   'timestamp': 90894,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 6,
#     'physicalDamage': 111,
#     'spellName': 'jinxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 6,
#     'physicalDamage': 65,
#     'spellName': 'jinxbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Jinx',
#     'participantId': 7,
#     'physicalDamage': 96,
#     'spellName': 'jinxw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 58,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'morganaw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 26,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 16,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Urgot',
#     'participantId': 10,
#     'physicalDamage': 98,
#     'spellName': 'urgotq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionRanged',
#     'participantId': 0,
#     'physicalDamage': 8,
#     'spellName': 'ha_chaosminionrangedbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 27,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiqe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 29,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiqe',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 167,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiee',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 58,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiwe',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 28,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 31,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 75,
#     'spellName': 'zede',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 91,
#     'spellName': 'zedq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 46,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 75,
#     'spellName': 'asheq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 236,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 4},
#  {'killType': 'KILL_MULTI',
#   'killerId': 7,
#   'multiKillLength': 2,
#   'position': {'x': 6403, 'y': 6108},
#   'timestamp': 90894,
#   'type': 'CHAMPION_SPECIAL_KILL'},
#  {'itemId': 2003,
#   'participantId': 7,
#   'timestamp': 95054,
#   'type': 'ITEM_DESTROYED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 2,
#   'skillSlot': 1,
#   'timestamp': 97257,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 2003,
#   'participantId': 10,
#   'timestamp': 102215,
#   'type': 'ITEM_DESTROYED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 1,
#   'timestamp': 103481,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1042,
#   'participantId': 4,
#   'timestamp': 104081,
#   'type': 'ITEM_PURCHASED'},
#  {'assistingParticipantIds': [6],
#   'bounty': 180,
#   'killStreakLength': 2,
#   'killerId': 7,
#   'position': {'x': 5019, 'y': 5849},
#   'shutdownBounty': 0,
#   'timestamp': 106684,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 6,
#     'physicalDamage': 86,
#     'spellName': 'missfortunericochetshot',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 43,
#     'name': 'MissFortune',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'missfortunescattershot',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 13,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 6,
#     'physicalDamage': 34,
#     'spellName': 'missfortunepassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 12,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 8,
#     'physicalDamage': 30,
#     'spellName': 'missfortunepassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 5,
#     'name': 'MissFortune',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'missfortunescattershot',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 8,
#     'physicalDamage': 74,
#     'spellName': 'missfortunericochetshot',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 10,
#     'physicalDamage': 73,
#     'spellName': 'missfortunericochetshot',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 63,
#     'name': 'MissFortune',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'missfortunescattershot',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 10,
#     'physicalDamage': 11,
#     'spellName': 'missfortunepassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 10,
#     'physicalDamage': 29,
#     'spellName': 'missfortunepassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 265,
#     'spellName': 'zedq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 81,
#     'spellName': 'zede',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 20,
#     'name': 'Zed',
#     'participantId': 6,
#     'physicalDamage': 60,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 91,
#     'spellName': 'volley',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 2},
#  {'assistingParticipantIds': [1, 4],
#   'bounty': 180,
#   'killStreakLength': 0,
#   'killerId': 2,
#   'position': {'x': 4790, 'y': 5669},
#   'shutdownBounty': 0,
#   'timestamp': 107049,
#   'type': 'CHAMPION_KILL',
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 2,
#     'physicalDamage': 86,
#     'spellName': 'missfortunericochetshot',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 43,
#     'name': 'MissFortune',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': 'missfortunescattershot',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 13,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MissFortune',
#     'participantId': 2,
#     'physicalDamage': 68,
#     'spellName': 'missfortunepassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Heimerdinger',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 13,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 36,
#     'name': 'Heimerdinger',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'heimerdingerw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 6},
#  {'assistingParticipantIds': [7, 8, 10],
#   'bounty': 163,
#   'killStreakLength': 0,
#   'killerId': 9,
#   'position': {'x': 6759, 'y': 6003},
#   'shutdownBounty': 0,
#   'timestamp': 115487,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': True,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 7,
#     'physicalDamage': 83,
#     'spellName': 'snowballfollowupcast',
#     'spellSlot': 5,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'snowballfollowupcast',
#     'spellSlot': 5,
#     'trueDamage': 30,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'summonersnowball',
#     'spellSlot': 5,
#     'trueDamage': 30,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 7,
#     'physicalDamage': 89,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 111,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 7,
#     'physicalDamage': 83,
#     'spellName': 'masteryibasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 8,
#     'physicalDamage': 85,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 30,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 9,
#     'physicalDamage': 86,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 31,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 10,
#     'physicalDamage': 62,
#     'spellName': 'alphastrike',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'MasterYi',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'wujustyle',
#     'spellSlot': 2,
#     'trueDamage': 33,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 27,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweipassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 68,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiee',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 74,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiwe',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 24,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 15,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 46,
#     'spellName': 'hweibasicattack',
#     'spellSlot': 52,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 41,
#     'spellName': 'hweibasicattack2',
#     'spellSlot': 52,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 122,
#     'name': 'Hwei',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'hweiqq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'HA_ChaosMinionMelee',
#     'participantId': 0,
#     'physicalDamage': 0,
#     'spellName': 'ha_chaosminionmeleebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'MINION'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Urgot',
#     'participantId': 10,
#     'physicalDamage': 119,
#     'spellName': 'urgotpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Urgot',
#     'participantId': 10,
#     'physicalDamage': 68,
#     'spellName': 'urgote',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Urgot',
#     'participantId': 10,
#     'physicalDamage': 193,
#     'spellName': 'urgotw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 41,
#     'spellName': 'morganabasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 22,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 29,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 48,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'morganaw',
#     'spellSlot': 1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Morgana',
#     'participantId': 9,
#     'physicalDamage': 62,
#     'spellName': 'morganabasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 25,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 94,
#     'spellName': 'ashebasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Ashe',
#     'participantId': 7,
#     'physicalDamage': 66,
#     'spellName': 'ashebasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 3}]

# %% [markdown]
# 2 minutes in and we have a frist blood, and the position of that kill
#
# {'assistingParticipantIds': [6, 8, 9, 10],
#   'bounty': 270,
#   'killStreakLength': 0,
#   'killerId': 7,
#   'position': {'x': 6906, 'y': 5944},
#   'shutdownBounty': 0,
#   'timestamp': 85594,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': .....
#
# }

# %% [markdown]
# ### Exploration done time for infrastructure
#
# Goal: Create a dataframe of the current locations of each player for a single game shown above

# %%
from get_data import select_player_locations, get_next_puuid

data = select_player_locations(match_ids[0], "ARAM", timeline)
data
# Out:
# [{'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 1096,
#   'y': 1180,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 1135,
#   'y': 1063,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 1099,
#   'y': 944,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 1000,
#   'y': 870,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 877,
#   'y': 868,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 12020,
#   'y': 11716,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 12059,
#   'y': 11599,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 12023,
#   'y': 11480,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 11924,
#   'y': 11406,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 11801,
#   'y': 11404,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5695,
#   'y': 5793,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 6850,
#   'y': 5956,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 6076,
#   'y': 5967,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5904,
#   'y': 6479,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 6023,
#   'y': 6114,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 7394,
#   'y': 6488,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7250,
#   'y': 6975,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6798,
#   'y': 7538,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 7356,
#   'y': 7394,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6510,
#   'y': 7309,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5016,
#   'y': 5220,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 936,
#   'y': 1060,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 6759,
#   'y': 6003,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5653,
#   'y': 5228,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 5885,
#   'y': 4928,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 11762,
#   'y': 11529,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 6990,
#   'y': 6632,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6448,
#   'y': 6212,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6993,
#   'y': 6709,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 2,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 7022,
#   'y': 6056,
#   'level': 4},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5478,
#   'y': 5154,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 5204,
#   'y': 5728,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 5384,
#   'y': 5560,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5016,
#   'y': 5060,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 5948,
#   'y': 5255,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6011,
#   'y': 6631,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 10137,
#   'y': 10001,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 7023,
#   'y': 6062,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6921,
#   'y': 6807,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 3,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6766,
#   'y': 6423,
#   'level': 5},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 6419,
#   'y': 6046,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 6407,
#   'y': 5662,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 7057,
#   'y': 6214,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5361,
#   'y': 5498,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 5740,
#   'y': 4842,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6332,
#   'y': 6676,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 5986,
#   'y': 5603,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 11682,
#   'y': 11446,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6894,
#   'y': 6604,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 4,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 7101,
#   'y': 6486,
#   'level': 6},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 6148,
#   'y': 6081,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 6211,
#   'y': 5979,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 7329,
#   'y': 7261,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 6615,
#   'y': 6199,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 5523,
#   'y': 6228,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6371,
#   'y': 6954,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7579,
#   'y': 7100,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 7384,
#   'y': 6713,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 7481,
#   'y': 7308,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 5,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6335,
#   'y': 6889,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 6093,
#   'y': 5532,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 1271,
#   'y': 1397,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 6225,
#   'y': 5917,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 4686,
#   'y': 4570,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 5198,
#   'y': 4669,
#   'level': 7},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 4955,
#   'y': 4721,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 5662,
#   'y': 5069,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 5380,
#   'y': 5397,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 5431,
#   'y': 5346,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 6,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 5566,
#   'y': 5304,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5830,
#   'y': 5968,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 6379,
#   'y': 6311,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 6474,
#   'y': 7018,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 6439,
#   'y': 7067,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 6137,
#   'y': 6059,
#   'level': 8},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6529,
#   'y': 6814,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7711,
#   'y': 6669,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6975,
#   'y': 7177,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 7391,
#   'y': 7309,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 7,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6540,
#   'y': 7094,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5307,
#   'y': 5085,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 5171,
#   'y': 5651,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 4994,
#   'y': 5648,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5158,
#   'y': 5308,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 5363,
#   'y': 4984,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6805,
#   'y': 5916,
#   'level': 9},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 6252,
#   'y': 5937,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6455,
#   'y': 5875,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6184,
#   'y': 6257,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 8,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6794,
#   'y': 5978,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 6281,
#   'y': 6318,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 6643,
#   'y': 6185,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 7937,
#   'y': 7602,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 6617,
#   'y': 6133,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 6837,
#   'y': 6315,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6840,
#   'y': 6095,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7323,
#   'y': 6887,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6908,
#   'y': 7652,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6364,
#   'y': 6796,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 9,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 5456,
#   'y': 5034,
#   'level': 10},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5432,
#   'y': 5451,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 5735,
#   'y': 4963,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 4917,
#   'y': 5663,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5078,
#   'y': 5246,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 936,
#   'y': 1060,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6846,
#   'y': 5937,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 10066,
#   'y': 9933,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6780,
#   'y': 6486,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6580,
#   'y': 6662,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 10,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 5837,
#   'y': 6444,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 6744,
#   'y': 6381,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 4179,
#   'y': 4927,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 6908,
#   'y': 6146,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 6345,
#   'y': 5879,
#   'level': 11},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 7243,
#   'y': 6659,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 6868,
#   'y': 6492,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 11708,
#   'y': 11310,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 7247,
#   'y': 7070,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 11860,
#   'y': 11596,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 11,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6113,
#   'y': 5849,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 4309,
#   'y': 4048,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 4356,
#   'y': 4307,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 5427,
#   'y': 4895,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 4398,
#   'y': 4232,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 4177,
#   'y': 4269,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 4571,
#   'y': 4314,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7412,
#   'y': 7237,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 3977,
#   'y': 4798,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 5264,
#   'y': 4793,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 5512,
#   'y': 4966,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 4598,
#   'y': 4707,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 4121,
#   'y': 5183,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 4080,
#   'y': 4083,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 7261,
#   'y': 7625,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 4705,
#   'y': 5055,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 11860,
#   'y': 11596,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 5913,
#   'y': 6519,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 5813,
#   'y': 5490,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 5966,
#   'y': 5835,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 5193,
#   'y': 5932,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 9143,
#   'y': 8631,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 9033,
#   'y': 9139,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 10597,
#   'y': 11204,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 9649,
#   'y': 8671,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 10330,
#   'y': 8815,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 9725,
#   'y': 8787,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 9318,
#   'y': 9327,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 9640,
#   'y': 9349,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 10002,
#   'y': 10791,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 9182,
#   'y': 9156,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5397,
#   'y': 5325,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 3998,
#   'y': 4146,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 6022,
#   'y': 5749,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5435,
#   'y': 4624,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 4207,
#   'y': 4100,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 5649,
#   'y': 6162,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7500,
#   'y': 7515,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6473,
#   'y': 6392,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6828,
#   'y': 6447,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6002,
#   'y': 5683,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 10392,
#   'y': 9920,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 11319,
#   'y': 10020,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 11352,
#   'y': 10297,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 11011,
#   'y': 10107,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 10582,
#   'y': 9621,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 10449,
#   'y': 9551,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 11471,
#   'y': 10093,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 9736,
#   'y': 10401,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 11477,
#   'y': 9993,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 10253,
#   'y': 10070,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 11057,
#   'y': 9945,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 10785,
#   'y': 9249,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 11282,
#   'y': 9843,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 9912,
#   'y': 9108,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 8083,
#   'y': 8295,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 11175,
#   'y': 9872,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 9247,
#   'y': 9141,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 7245,
#   'y': 6916,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 7426,
#   'y': 8130,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 7324,
#   'y': 7579,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 11120,
#   'y': 9911,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 11581,
#   'y': 10822,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 10507,
#   'y': 10286,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 10623,
#   'y': 9917,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 10751,
#   'y': 10236,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 11212,
#   'y': 9918,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 9247,
#   'y': 9141,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 7245,
#   'y': 6916,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 7426,
#   'y': 8130,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 7324,
#   'y': 7579,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 1096,
#   'y': 1180,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 1135,
#   'y': 1063,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 1099,
#   'y': 944,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 1000,
#   'y': 870,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 877,
#   'y': 868,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 12020,
#   'y': 11716,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 12059,
#   'y': 11599,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 12023,
#   'y': 11480,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 11924,
#   'y': 11406,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 0,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 11801,
#   'y': 11404,
#   'level': 1},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5695,
#   'y': 5793,
#   'level': 3},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 1,
# ...
#   'frame': 12,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 4398,
#   'y': 4232,
#   'level': 12},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 4177,
#   'y': 4269,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 4571,
#   'y': 4314,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7412,
#   'y': 7237,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 3977,
#   'y': 4798,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 5264,
#   'y': 4793,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 12,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 5512,
#   'y': 4966,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 4598,
#   'y': 4707,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 4121,
#   'y': 5183,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 4080,
#   'y': 4083,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 7261,
#   'y': 7625,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 4705,
#   'y': 5055,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 11860,
#   'y': 11596,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 5913,
#   'y': 6519,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 5813,
#   'y': 5490,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 5966,
#   'y': 5835,
#   'level': 13},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 13,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 5193,
#   'y': 5932,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 9143,
#   'y': 8631,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 9033,
#   'y': 9139,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 10597,
#   'y': 11204,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 9649,
#   'y': 8671,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 10330,
#   'y': 8815,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 9725,
#   'y': 8787,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 9318,
#   'y': 9327,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 9640,
#   'y': 9349,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 10002,
#   'y': 10791,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 14,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 9182,
#   'y': 9156,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 5397,
#   'y': 5325,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 3998,
#   'y': 4146,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 6022,
#   'y': 5749,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 5435,
#   'y': 4624,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 4207,
#   'y': 4100,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 5649,
#   'y': 6162,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 7500,
#   'y': 7515,
#   'level': 14},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 6473,
#   'y': 6392,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 6828,
#   'y': 6447,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 15,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 6002,
#   'y': 5683,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 10392,
#   'y': 9920,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 11319,
#   'y': 10020,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 11352,
#   'y': 10297,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 11011,
#   'y': 10107,
#   'level': 15},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 10582,
#   'y': 9621,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 10449,
#   'y': 9551,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 11471,
#   'y': 10093,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 9736,
#   'y': 10401,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 11477,
#   'y': 9993,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 16,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 10253,
#   'y': 10070,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 11057,
#   'y': 9945,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 10785,
#   'y': 9249,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 11282,
#   'y': 9843,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 9912,
#   'y': 9108,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 8083,
#   'y': 8295,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 11175,
#   'y': 9872,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 9247,
#   'y': 9141,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 7245,
#   'y': 6916,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 7426,
#   'y': 8130,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 17,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 7324,
#   'y': 7579,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '1',
#   'player_puuid': '_FznSp7W4096_tEkwFTiAmPJerwuyY9aqcMJ9CrvmeBIX59gZLPsMPb4iRdMV6DkUsIS6SeVBBc8Cw',
#   'x': 11120,
#   'y': 9911,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '2',
#   'player_puuid': 'zhkSsv-0jE9dKvWh6h3xTO3UH6KIafKkI-v5E7zQjcKZWmnnzFyH415Ev-G0a1bKWo9o91IEKBumGQ',
#   'x': 11581,
#   'y': 10822,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '3',
#   'player_puuid': '8ZwlZrtP-UWTq82MS34VbSvE3opxX6dD6AFwV0VUw29ovgRGwvSmarCxljvP1qzBSz6vmvXpFVAvxQ',
#   'x': 10507,
#   'y': 10286,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '4',
#   'player_puuid': 'iyNh3kBlX5g3nTPqt03REuWavBhnySCx6Ims9-nIR5C9bOf2lJa--qFlOVp-OV-EsSrwPOVJXIEstA',
#   'x': 10623,
#   'y': 9917,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '5',
#   'player_puuid': 'EgKQP7KwzGTALtoAkGdy4GOi1a9yNx_JqPqQJkWD75lKm80qFB6BmPL6-ebCb4Et6q1zK3o0hH8Y2w',
#   'x': 10751,
#   'y': 10236,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '6',
#   'player_puuid': '0u5cOnC8z_gcVpDpG5OzbaiAF2-765y0yjZMseSrcHYkpg0aKV3n7rgAUG1nrHRV2E3NIYaHTa5pxg',
#   'x': 11212,
#   'y': 9918,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '7',
#   'player_puuid': '-FYL436Q4NShi_V3LqLth92pviFCqpn3Gij_vA5dnscpBwJe4B7IJSixd3jV8uOrG_Hwbru26oZM5Q',
#   'x': 9247,
#   'y': 9141,
#   'level': 16},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '8',
#   'player_puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'x': 7245,
#   'y': 6916,
#   'level': 18},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '9',
#   'player_puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'x': 7426,
#   'y': 8130,
#   'level': 17},
#  {'match_ids': 'NA1_4913902543',
#   'match_type': 'ARAM',
#   'frame': 18,
#   'player_part_id': '10',
#   'player_puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'x': 7324,
#   'y': 7579,
#   'level': 17}]

# %%
get_next_puuid(player_data, timeline)
# Out:
# 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ'

# %%
import random
def get_n_matches_data(lol_watcher, puuid, n, my_region="na1"):
    data = []
    for _ in range(n):
        match_ids = lol_watcher.match.matchlist_by_puuid(my_region, puuid)
        match_id = random.choice(match_ids)
        
        match_meta = lol_watcher.match.by_id(my_region, match_id)
        match_type = match_meta["info"]["gameMode"]

        timeline = lol_watcher.match.timeline_by_match(my_region, match_id)
        
        data = select_player_locations(match_id, match_type, timeline, data=data)
        puuid = get_next_puuid(puuid, timeline)
    return data

data = get_n_matches_data(lol_watcher, player_data['puuid'], 40, my_region="na1")
# Out:
# NA1_4906408509
# NA1_4906497820
# NA1_4913096250
# NA1_4912102736
# NA1_4910909165
# NA1_4913902543
# NA1_4912324242
# NA1_4913986371
# NA1_4913589399
# NA1_4913547916
# NA1_4912978472
# NA1_4907133965
# NA1_4912913660
# NA1_4912913660
# NA1_4912913660
# NA1_4912853003
# NA1_4914623258
# NA1_4908870510
# NA1_4914477445
# NA1_4905350000
# NA1_4878448614
# NA1_4878626249
# NA1_4914677064
# NA1_4914689599
# NA1_4914689599
# NA1_4912961720
# NA1_4912961720
# NA1_4909800130
# NA1_4910783748
# NA1_4911830299
# NA1_4911881634
# NA1_4908226910
# NA1_4913455426
# NA1_4913647041
# NA1_4913505349
# NA1_4914589650
# NA1_4913912584
# NA1_4913952739
# NA1_4913952739
# NA1_4913500381

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df
# Out:
#            match_ids match_type  frame player_part_id  \
# 0     NA1_4906408509       ARAM      0              1
# 1     NA1_4906408509       ARAM      0              2
# 2     NA1_4906408509       ARAM      0              3
# 3     NA1_4906408509       ARAM      0              4
# 4     NA1_4906408509       ARAM      0              5
# ...              ...        ...    ...            ...
# 9935  NA1_4913500381    CLASSIC     33              6
# 9936  NA1_4913500381    CLASSIC     33              7
# 9937  NA1_4913500381    CLASSIC     33              8
# 9938  NA1_4913500381    CLASSIC     33              9
# 9939  NA1_4913500381    CLASSIC     33             10
#
#                                            player_puuid     x     y  level
# 0     kG7JSQpC7deUOSBnkqRxfOLB8nXC2sYwHLLUhDegbzKqq_...  1096  1180      1
# 1     ihzcXkONhaeuwgYCqIwhUmby-U5t4NXvvpKHnDAWdlJhNX...  1135  1063      1
# 2     89CjrTlPtYYoAjjEVSc-eVDAKk6aULd63RWKavHiIetyG8...  1099   944      1
# 3     pHkQUyo8Qpzk0s1ZPjF8GATX8pmBMZ62HmzgzII6Ys4k-A...  1000   870      1
# 4     -pN6bf-VQRe_f_G1kwF9IJB-D_z2GVWZwAmpf9Nar8ZAiD...   877   868      1
# ...                                                 ...   ...   ...    ...
# 9935  5QCTz70pbl8vaygbTZ3cUsYMuifgg4YZyi5jyOins322BW...  3545   886     16
# 9936  lYyso47uG6N89fj9gCaeJuJiC96d5jXKcNhgO0jyddwgKw...  3756   938     16
# 9937  3WyuZHFN70XOgV1YF4_WrgKSdz_tboT-f6Cu4r068zt1-h...  1945  1995     17
# 9938  jdTqDr0j3DAY41RcS0gJMZIkil8mZQYSYv789TIxZojxqG...  2444  1036     16
# 9939  dyuY9j3Y5dMK0JAyxSIA7WYxXX7W-NQiangxcx9LPLXYfw...  2015  1426     14
#
# [9940 rows x 8 columns]

# %%
df["player_puuid"].value_counts()
# Out:
# player_puuid
# K2FCH6s02C0n8p8aUqxpGAZBFeYTgsHJ-Wrowg4S2IrdyMk6UpjTxKEVHdgQtuyyritlaJqaVyKDRw    281
# 7YT_7WOj--VM-hOxeDmoqR23aw17Nt9gJcDu8_VkCCw5-i7InktEEO1BoKwwHADM6eKB0KpOedLrsA    281
# DSUPQEjZ_E5tW8rAQ02AiOiw44zBw2lgbFyNBmGU4_6wfp8Lqzye9dUd2pHOOBZpKL8NDm7QXtqyLQ    167
# 58567Yu693KRwzpLFz6-NYhL3lZpKFMcog4h-zVgBJ9qMO8JpxyuH8r1PNCjmrawvtssJOtKKIERTg    145
# jdTqDr0j3DAY41RcS0gJMZIkil8mZQYSYv789TIxZojxqGCV5abSRR6V3hRhY7blRvWka-xpeseOdA    124
#                                                                                  ...
# 25jjH-PbdqrRKaYfOY9M423yrqdhI_vvvA2D00mferXoDt-OZru2BpZUqyThE1iwUVQuchVur26DWg      3
# -AhLouJhxC-vkrERd1d6euuCAlAccVOcTuY56B53gD0AcaozHOTIMRd997qy27yXqJ5VYh_AcYH2XA      3
# G7f1XDpeiY_sn51S5g1nHeWmwGIQ1B0p13V_zQpKKC1JX1-Sv1MVuwNV_gx9BT6sfVWkv55ecjY7EQ      3
# NmdFPuXLz3U99fWtgGBA5qw44QS7w3VNgxswyjy3GZlUVHNwdq9v2607O6wBzcDnPcAMN1YqfPjmew      3
# 6iYYg63rihDnUopHKh5XimNh6yw4RB9GYlwaq-4MimGPTe6D2VIekzTNUmDaBqZ0SKiwTjAop2yMSA      3
# Name: count, Length: 286, dtype: int64

# %%
df["match_ids"].value_counts()
# Out:
# match_ids
# NA1_4912913660    1110
# NA1_4913952739     900
# NA1_4907133965     470
# NA1_4914689599     400
# NA1_4908226910     370
# NA1_4908870510     370
# NA1_4913500381     340
# NA1_4912978472     340
# NA1_4913912584     310
# NA1_4914589650     310
# NA1_4914623258     300
# NA1_4912961720     280
# NA1_4912102736     270
# NA1_4913589399     270
# NA1_4905350000     250
# NA1_4910909165     240
# NA1_4914477445     240
# NA1_4913547916     230
# NA1_4909800130     230
# NA1_4912853003     220
# NA1_4906408509     220
# NA1_4912324242     200
# NA1_4913647041     200
# NA1_4913096250     200
# NA1_4911830299     200
# NA1_4913902543     190
# NA1_4913455426     180
# NA1_4878626249     170
# NA1_4910783748     170
# NA1_4913986371     150
# NA1_4878448614     150
# NA1_4911881634     150
# NA1_4914677064     140
# NA1_4913505349     140
# NA1_4906497820      30
# Name: count, dtype: int64

# %%
df["match_type"].value_counts()
# Out:
# match_type
# ARAM       6570
# CLASSIC    3370
# Name: count, dtype: int64

# %%
df["match_ids"].nunique()
# Out:
# 35
