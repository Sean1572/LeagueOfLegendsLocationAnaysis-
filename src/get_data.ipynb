# %%
# %load_ext autoreload
# %autoreload 2

import requests
import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#!pip install python-dotenv

# %% [markdown]
# # Api Key

# %%
#Hi yall, so for this we need riot api keys. They have 24 hour refreshes but to be extra safe put them in a .env file

import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv('riot_api_key')

if api_key == None:
    raise Exception(
        "Go to https://developer.riotgames.com/ and get an api key set up"
    )
else:
    print("looking good")
# Out:
# looking good

# %% [markdown]
# Read https://developer.riotgames.com/docs/portal#web-apis_api-keys for key info on api keys
#
# # Riotwatcher
#
# Using riotwatcher for a library to handle the api, see https://github.com/pseudonym117/Riot-Watcher

# %%
# !pip install riotwatcher
# Out:
# Requirement already satisfied: riotwatcher in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (3.2.5)
# Requirement already satisfied: requests in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from riotwatcher) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\seanh\appdata\roaming\python\python38\site-packages (from requests->riotwatcher) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from requests->riotwatcher) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from requests->riotwatcher) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seanh\miniconda3\envs\asid\lib\site-packages (from requests->riotwatcher) (2023.11.17)

# %%
# Example code from https://github.com/pseudonym117/Riot-Watcher for debugging purporses
from riotwatcher import LolWatcher, ApiError

lol_watcher = LolWatcher(api_key)

my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'pseudonym117')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.response.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise
# Out:
# {'id': 'dD3xFaEaFlbon9FZ6ljyBU7pXSbLV3FD36RwtK8kaC8h_-Y', 'accountId': '2AmPLTJbOTz48G33AO-dPUcXUEtRh5FdJ3LTMB9Jr9Xt2w', 'puuid': 'A6VIZHINPBHNzS1W3Yw0LltoZbJOrDIJgUEaZT7Pi2aC3TJYbv_TRQM4ywJnQflgwZbYCESO66ZAAg', 'name': 'pseudonym117', 'profileIconId': 539, 'revisionDate': 1707288979000, 'summonerLevel': 190}
# []
# {'type': 'champion', 'format': 'standAloneComplex', 'version': '14.3.1', 'data': {'Aatrox': {'version': '14.3.1', 'id': 'Aatrox', 'key': '266', 'name': 'Aatrox', 'title': 'the Darkin Blade', 'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...', 'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}, 'image': {'full': 'Aatrox.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 0, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Fighter', 'Tank'], 'partype': 'Blood Well', 'stats': {'hp': 650, 'hpperlevel': 114, 'mp': 0, 'mpperlevel': 0, 'movespeed': 345, 'armor': 38, 'armorperlevel': 4.45, 'spellblock': 32, 'spellblockperlevel': 2.05, 'attackrange': 175, 'hpregen': 3, 'hpregenperlevel': 1, 'mpregen': 0, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 60, 'attackdamageperlevel': 5, 'attackspeedperlevel': 2.5, 'attackspeed': 0.651}}, 'Ahri': {'version': '14.3.1', 'id': 'Ahri', 'key': '103', 'name': 'Ahri', 'title': 'the Nine-Tailed Fox', 'blurb': "Innately connected to the magic of the spirit realm, Ahri is a fox-like vastaya who can manipulate her prey's emotions and consume their essence—receiving flashes of their memory and insight from each soul she consumes. Once a powerful yet wayward...", 'info': {'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 5}, 'image': {'full': 'Ahri.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 48, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Mage', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 590, 'hpperlevel': 96, 'mp': 418, 'mpperlevel': 25, 'movespeed': 330, 'armor': 21, 'armorperlevel': 4.7, 'spellblock': 30, 'spellblockperlevel': 1.3, 'attackrange': 550, 'hpregen': 2.5, 'hpregenperlevel': 0.6, 'mpregen': 8, 'mpregenperlevel': 0.8, 'crit': 0, 'critperlevel': 0, 'attackdamage': 53, 'attackdamageperlevel': 3, 'attackspeedperlevel': 2.2, 'attackspeed': 0.668}}, 'Akali': {'version': '14.3.1', 'id': 'Akali', 'key': '84', 'name': 'Akali', 'title': 'the Rogue Assassin', 'blurb': 'Abandoning the Kinkou Order and her title of the Fist of Shadow, Akali now strikes alone, ready to be the deadly weapon her people need. Though she holds onto all she learned from her master Shen, she has pledged to defend Ionia from its enemies, one...', 'info': {'attack': 5, 'defense': 3, 'magic': 8, 'difficulty': 7}, 'image': {'full': 'Akali.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 96, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Assassin'], 'partype': 'Energy', 'stats': {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpperlevel': 0, 'movespeed': 345, 'armor': 23, 'armorperlevel': 4.7, 'spellblock': 37, 'spellblockperlevel': 2.05, 'attackrange': 125, 'hpregen': 9, 'hpregenperlevel': 0.9, 'mpregen': 50, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 62, 'attackdamageperlevel': 3.3, 'attackspeedperlevel': 3.2, 'attackspeed': 0.625}}, 'Akshan': {'version': '14.3.1', 'id': 'Akshan', 'key': '166', 'name': 'Akshan', 'title': 'the Rogue Sentinel', 'blurb': 'Raising an eyebrow in the face of danger, Akshan fights evil with dashing charisma, righteous vengeance, and a conspicuous lack of shirts. He is highly skilled in the art of stealth combat, able to evade the eyes of his enemies and reappear when they...', 'info': {'attack': 0, 'defense': 0, 'magic': 0, 'difficulty': 0}, 'image': {'full': 'Akshan.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 144, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Marksman', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 630, 'hpperlevel': 107, 'mp': 350, 'mpperlevel': 40, 'movespeed': 330, 'armor': 26, 'armorperlevel': 4.7, 'spellblock': 30, 'spellblockperlevel': 1.3, 'attackrange': 500, 'hpregen': 3.75, 'hpregenperlevel': 0.65, 'mpregen': 8.2, 'mpregenperlevel': 0.7, 'crit': 0, 'critperlevel': 0, 'attackdamage': 52, 'attac ...
# Summoner with that ridiculous name not found.

# %%
import riotwatcher
kumo = lol_watcher.summoner.by_name(my_region, 'Kumo9')
kumo
# Out:
# {'id': 'xfsx-L4ICwAKOSz3sWtFR5grH1VZQfx0NTjZgCSema2ciXc',
#  'accountId': 'GYAsbTulexAir78__2_sIQJLGE2yci0DLbSbZQKk9EUwmg',
#  'puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#  'name': 'Kumo9',
#  'profileIconId': 5935,
#  'revisionDate': 1707449176730,
#  'summonerLevel': 390}

# %%
lol_watcher.league.by_summoner(my_region, kumo["id"])
# Out:
# [{'leagueId': '0def7191-9628-3af8-b648-88aaf6879c5f',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'CHALLENGER',
#   'rank': 'I',
#   'summonerId': 'xfsx-L4ICwAKOSz3sWtFR5grH1VZQfx0NTjZgCSema2ciXc',
#   'summonerName': 'Kumo9',
#   'leaguePoints': 1197,
#   'wins': 227,
#   'losses': 177,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False}]

# %%
lol_watcher.league.by_id(my_region, "0def7191-9628-3af8-b648-88aaf6879c5f")
# Out:
# {'tier': 'CHALLENGER',
#  'leagueId': '0def7191-9628-3af8-b648-88aaf6879c5f',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "LeBlanc's Hunters",
#  'entries': [{'summonerId': 'u51Q1fP5IlNp2m9zEMwahXqkuzot8ybdoFowhsfIDdrQPdQ',
#    'summonerName': 'c2 meteos',
#    'leaguePoints': 634,
#    'rank': 'I',
#    'wins': 74,
#    'losses': 49,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'rbvR8jTkWGOWr4AL9qEUN3IiwdV1q7MIdmneQlXHjfuFRUOV',
#    'summonerName': 'Sasha xo',
#    'leaguePoints': 508,
#    'rank': 'I',
#    'wins': 62,
#    'losses': 40,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '1Jlx3hvqbVMG_YPcB0ycXa4NDSw0o89ihDAzrIt9BHku-4s',
#    'summonerName': 'SnipaXD',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'yHawgElWO312dh5hdJy0tzWmBAwEj7WG7F6HesOQ0BIh6k3a',
#    'summonerName': 'SlSYPHUS',
#    'leaguePoints': 477,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 141,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ebv3vqP42Z3NuqN3NIpQqMDo_yT8_oMVFECX36Q3yJGWKjI',
#    'summonerName': 'jimmykoi',
#    'leaguePoints': 734,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rXNIbNCSKm_gg2qZALLQ3jpsRxgrk7gL7YlRGfdwXmOVH88',
#    'summonerName': 'YouAllSuck',
#    'leaguePoints': 1044,
#    'rank': 'I',
#    'wins': 139,
#    'losses': 96,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'OJ15SKyiZjaKdDW_ZDA_ZL_fhFlLkWL5DnpbCBqkLXaIod5m',
#    'summonerName': 'Doaenel 1 Dantes',
#    'leaguePoints': 529,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 89,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KFGLz4s8SQXgrdiNeuyJQNgTcs4JjT-KEKs4PAUESCmWMCU',
#    'summonerName': 'Saiyans',
#    'leaguePoints': 527,
#    'rank': 'I',
#    'wins': 88,
#    'losses': 56,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Q0Vv3DqjTTT5a1no7GiX0-AGobVVOFFisuqSaCYWDYwX-IMEuKkqzQcaiA',
#    'summonerName': 'llIIlIlIlIlIlIlI',
#    'leaguePoints': 554,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 45,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '7DxqNLJJbA2uUkvx0Xlb-JexKLKuSpTSiTOWEQ5OXoL9BX0',
#    'summonerName': 'quante9',
#    'leaguePoints': 989,
#    'rank': 'I',
#    'wins': 111,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'G62p7lZZ-WXqedxQBsEzMNfkFfE-mUhyieCfzOKeJX1Qmkw',
#    'summonerName': 'Astuary King',
#    'leaguePoints': 559,
#    'rank': 'I',
#    'wins': 128,
#    'losses': 96,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'aKNUnxoS-DMHLsYTawfMGP-hxLZ4Ujq8O2gi1muZWwjj-zhLV0_4CaOSYA',
#    'summonerName': 'showmewhatyouare',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 64,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'WrqKcPNCNw2URobknOSLIMRYK33nHZPxkx8L-NvUKiZeuGmD',
#    'summonerName': 'ScrubNoob',
#    'leaguePoints': 715,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 117,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'gRLbfz2Lf0bReZ8GXJ2-QgkP4KI39tTstf3jWwnRn_GK-C1q',
#    'summonerName': 'llIlIllIllllllIl',
#    'leaguePoints': 505,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Ov8AD3aAnnP-tc6blhMJsTARwdJKKWEEyqAXf8rf54PoOD59IT3NJLFelQ',
#    'summonerName': 'impisscheese',
#    'leaguePoints': 517,
#    'rank': 'I',
#    'wins': 46,
#    'losses': 24,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'jc_bKlSZK1nZ_bfkCwbu6lBmeVo83QB1_RvjuTItPI1z-wg',
#    'summonerName': 'hahahaigh',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 84,
#    'losses': 57,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'TbGDGSfeEqjmNShDzBs4wTu56JX6rFL8Se3flqkil5YEbnE',
#    'summonerName': 'Odece',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 83,
#    'losses': 61,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'nf8n5P7wti0jp76xUA5WbgrIEHcv5ntQiN6a-l7LsJ6pMuY',
#    'summonerName': 'Cupic',
#    'leaguePoints': 825,
#    'rank': 'I',
#    'wins': 67,
#    'losses': 38,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'd0crEKX5PCbzwjVZdip_UlI1IVpS8xxfjvG6aTnxmkE5xD0',
#    'summonerName': 'CLG Ravey',
#    'leaguePoints': 575,
#    'rank': 'I',
#    'wins': 194,
#    'losses': 168,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'sARosAw0AS4OpG9nxMhHSkqF5tixLLopAkhzaM4NBJMeqhW1X_oB9hPAwQ',
#    'summonerName': '454545',
#    'leaguePoints': 728,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 33,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'RLCbUut5J0KtbcXxe1LMYsrUTvprz9IG7Izo6voDXrOfG1k',
#    'summonerName': 'EmiyaOo',
#    'leaguePoints': 591,
#    'rank': 'I',
#    'wins': 80,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Vq5QifiRMq0aml61wYHr5SpvFerHVK_dmi8SAxLetNG-EBs',
#    'summonerName': 'Solarbacca',
#    'leaguePoints': 1020,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 91,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'A6tqDaxdmG31pQw8B14Fy0jqZQXDBhrOT-zqe_Ur3-q1ys8',
#    'summonerName': 'smurphd',
#    'leaguePoints': 803,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'QaXwfpeuU4pLbzxtiWmB4O_Q1NR2AVyUGf80gKdRW2N_LnvX',
#    'summonerName': 'twtv huncho1v9',
#    'leaguePoints': 511,
#    'rank': 'I',
#    'wins': 77,
#    'losses': 44,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Lk0Oc0cQeaVuVxDQ5QwHyoPk2kClurwF7-a35AObyPc0WtcO',
#    'summonerName': 'HU Kidbeatz',
#    'leaguePoints': 536,
#    'rank': 'I',
#    'wins': 59,
#    'losses': 33,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'kD3VBTcN14MYbzIGIgV0SejCL06v8uDPwzOdhQicfSrxotI',
#    'summonerName': 'Insurance',
#    'leaguePoints': 506,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 89,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'GFJGk0HlIjY9-2PWTICsvA-duIxGjfRebSUI6dgr8ZGA2dA',
#    'summonerName': 'Waku Waku Week',
#    'leaguePoints': 508,
#    'rank': 'I',
#    'wins': 99,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FXYdgXzq2oNz_qVbQu4Q_CVeFz7r_qO-MmaNAf6EcWQuFsMHaFjE-wgbyQ',
#    'summonerName': 'blxscx',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 52,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'w1Vp9SvrBE0MCWsYTeHwmqSJZ78PmJIozQmndcQGOg7Di56HDZidI8WaxA',
#    'summonerName': '',
#    'leaguePoints': 514,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 153,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'coy_X-0cq1q-ES1EaNOCgUOc_UD_JX3Y3HblwFjjCqULJjsnkxQmVa59Pw',
#    'summonerName': '5kid',
#    'leaguePoints': 631,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 57,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'lJpaBwCIWSeBgBi0D03ttJQi-_gCOsknt1oCqisdLXn7upM',
#    'summonerName': 'ArekXander',
#    'leaguePoints': 501,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 60,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'xfsx-L4ICwAKOSz3sWtFR5grH1VZQfx0NTjZgCSema2ciXc',
#    'summonerName': 'Kumo9',
#    'leaguePoints': 1197,
#    'rank': 'I',
#    'wins': 227,
#    'losses': 177,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'N9iV9stlyXU9WrzZRlvJSSzJrzd6Av6l9hDhInQ_K1QDFII',
#    'summonerName': 'Reppy',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 100,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'zRova4D3gZfzNNxYRIzrvQbxfZ_3mJShvpfZbQvhFMthsrrr5r9Jrhjk_A',
#    'summonerName': 'Yousuf',
#    'leaguePoints': 435,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tg4qOeIlThpAEEDZgaCOmRG7yEf3__qohtRLdp_csC0VtWw',
#    'summonerName': 'Lancelot Link',
#    'leaguePoints': 517,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 201,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KSpP5vUTgFdlSmnq2tm62NebbnWGcNj408dMWh_yMl3F3bg',
#    'summonerName': 'Mobility3',
#    'leaguePoints': 426,
#    'rank': 'I',
#    'wins': 135,
#    'losses': 128,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KaJz8lcVFnmCRGdAMPrXRbM3qtuLNM9I3tL6rdM3ZzuWDVo',
#    'summonerName': 'sponsorless',
#    'leaguePoints': 792,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'uUZpKg3Q1M4WDQT-dPodC_XVpON7kn_c3ZyAvWE8gDPxwfI',
#    'summonerName': 'DIg Striker',
#    'leaguePoints': 666,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 87,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jV8NN4KyzTzv-v66bFG5rNYzNHV1uQtZotKRmtQRplMqDau3',
#    'summonerName': 'Bejjj',
#    'leaguePoints': 661,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 47,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'Cch3rKA9CGoqc8pM9NflrRzidbCXCd9tRVp3tES--DmQa1B3NXJUPj_0-g',
#    'summonerName': 'Zao Shui QAQ',
#    'leaguePoints': 953,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 105,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ZERUDDvrL3fuKztzkdYAfOfJHkKA7a8QKrRAShKZY0dJyoKWls5hvBetBQ',
#    'summonerName': '',
#    'leaguePoints': 512,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 127,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'MJvc_-CN5iSI_gp9nFWYVBcfetQ6nBXBC2aSH-BeDCenIydI03pg7mgULg',
#    'summonerName': 'finaIe',
#    'leaguePoints': 497,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'MX35rfwiIuH8llOqlYlz5pDY33_k8zq2w77dLsFmgSuR_KczZF53zeTovw',
#    'summonerName': 'Kimochi Kimochi',
#    'leaguePoints': 517,
#    'rank': 'I',
#    'wins': 75,
#    'losses': 47,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'n25lT6ntNlYfBmaiNE4eZ4e2ex3Uk8f44mg4f-QEShjfnbgctB3A4nuZXw',
#    'summonerName': '再见',
#    'leaguePoints': 572,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 72,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'y7q9q3LecPxN5AaQGRnYHzSj68uWhqoaQKn2dXuiRDhIVtg',
#    'summonerName': 'Leancuisine13',
#    'leaguePoints': 650,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 136,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'JxuvaAi3q0VBRP645Nk7NWCZDmsYttyFLs2Su-zoSH8aXqw',
#    'summonerName': 'checca',
#    'leaguePoints': 639,
#    'rank': 'I',
#    'wins': 62,
#    'losses': 23,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '5GYSfeNnNN0S1yZv3WGKMw-eOQrzxvK6lNfHdfBpyADLZTuWdxmBrAcR0w',
#    'summonerName': 'Laekilexa',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 72,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'nssiUl3dUkhjHBxGyP3RKR3GeK4fgg2ar-jvG94bfQr7yE0zoy6yWbzt9Q',
#    'summonerName': 'Inoriboob',
#    'leaguePoints': 536,
#    'rank': 'I',
#    'wins': 124,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FXISGLUGemWi2Co8n-H340vKMNW8WlCjiO4EVCSZzHXUbQFMhGod4FIa9Q',
#    'summonerName': 'we out here',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 59,
#    'losses': 38,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2DdeKHiLi-gyFh1O0Zwe8s-anen3y9O4Q-mWSSuQev3f-ss',
#    'summonerName': 'BOBtimer',
#    'leaguePoints': 487,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 55,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'xiz7iFckO3sco2tI0CNHjtBVr-E0oe2jzIrNrSnU5LVdylY',
#    'summonerName': 'Augustine',
#    'leaguePoints': 1036,
#    'rank': 'I',
#    'wins': 223,
#    'losses': 193,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vDA3xWPQZkghHpTCSOAoI2a3LXGkko3I4Cxx1Ew7YBwhD2e1YUlxO6YKWQ',
#    'summonerName': 'OaHbmLpng3E27TGS',
#    'leaguePoints': 898,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '9uTmuEF6PcBe0WTHgMixwyfrXVNVKKGKPDk6fWWX0kAJ1CJUPYgRtjiWVw',
#    'summonerName': 'STEVESTEVE1',
#    'leaguePoints': 516,
#    'rank': 'I',
#    'wins': 61,
#    'losses': 35,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'MEmLr0Zo1pzO_JJDVxu-8DmWdc7lLr2yauAtMB6EDUyBefc',
#    'summonerName': 'XinNianXingDaYun',
#    'leaguePoints': 552,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 192,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '6L1dZLHOLbQpqCZFUU2O9GzVvw1WfVg9YMSCIp3Kn7mYSGk0y3AsWlui9g',
#    'summonerName': '',
#    'leaguePoints': 679,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'JEoGResg_Gs3Sw8sV8TXAvtltVlx2d-H8MTqZcVz5ULrd9P5jv_Lnf8N3A',
#    'summonerName': 'X2eXUvy7x729i493',
#    'leaguePoints': 936,
#    'rank': 'I',
#    'wins': 115,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'QS88dOVipqWApQ_x9xqhqfooUY00Bc9rz5hvMHDFcwm7ZPxo3zU0wGNCqw',
#    'summonerName': 'Paklaiton',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 211,
#    'losses': 190,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '0JZiQYZDPs8yjASiVdKaeTF1wo1ez8oUysohuU3_dvbngRZuuAWaHtYFaQ',
#    'summonerName': 'Kurfyou 2',
#    'leaguePoints': 509,
#    'rank': 'I',
#    'wins': 58,
#    'losses': 37,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'x_BEfsN0KamA_GQGOHmigc_V9wPuo8ARu3wmRknAsiGEUmI',
#    'summonerName': 'CaptBear',
#    'leaguePoints': 681,
#    'rank': 'I',
#    'wins': 126,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3JvcSdHZC36UGSPxZe2Yiqqgk3xwierbcDhP7lJ_SIHJl98',
#    'summonerName': 'garbocan',
#    'leaguePoints': 505,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 64,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Qadn2M94uYr5b43rzP8I5P0ge4ibO1Sp-b1jd6EcNXNXH4A',
#    'summonerName': 'Sharpe',
#    'leaguePoints': 508,
#    'rank': 'I',
#    'wins': 66,
#    'losses': 41,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Y8JKMxkHyxgnnz2DBqMoT-ORXfYe8LRR-AV4VGILsIkc89hY',
#    'summonerName': 'TE AMO KARLA',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 66,
#    'losses': 37,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 't480T6j5_1YoLyfzNJWBZ8KhACCHmk7HDusfAlgEJvBY8X6MSNFpoulsEw',
#    'summonerName': '',
#    'leaguePoints': 901,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 31,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '2BnglEQ6Me4vvfMriT6bsYtSekzy8-N9C1Dj-1wKZMxLWeJD',
#    'summonerName': 'SpeedWägon',
#    'leaguePoints': 506,
#    'rank': 'I',
#    'wins': 75,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'h59Drx1lwG4DjoHywE7_A7XzHNNESxAU2jFKJdtg3PDKikdf7AAWWPt61Q',
#    'summonerName': 'A K',
#    'leaguePoints': 522,
#    'rank': 'I',
#    'wins': 62,
#    'losses': 28,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'XYDs4vAD9xc4TnMTBQ81gTomlvWt8l0DqXmxBtntLkxBwns',
#    'summonerName': 'MEECHOL',
#    'leaguePoints': 514,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 57,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'AtVREzxKhl-_JvsYBhXp-e3sqkuBHwGZNO0FDe57kv74MHM',
#    'summonerName': 'Love Ego',
#    'leaguePoints': 474,
#    'rank': 'I',
#    'wins': 150,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'i-BHSR-bJCQU1LNECh5BcJLaR3FD2VSjg-mMAS5AXbrKV2k',
#    'summonerName': 'Vulcan 01',
#    'leaguePoints': 641,
#    'rank': 'I',
#    'wins': 68,
#    'losses': 45,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0BDnImxVsw5ist6mPeSdvSOhD7xgXprhxAdOLVPzsnZ7',
#    'summonerName': 'Cody Sun',
#    'leaguePoints': 868,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'q9eAawRcXUawHSQ83tHbkW20HsONos5PbT-Zc1XkPC3wKb4',
#    'summonerName': '2wfrevdxsc',
#    'leaguePoints': 554,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'rB5nI0rXmgHHglNqsi1o2-LQYdO_LQoplDEL1SigBgKys00DWOTpI2ePAA',
#    'summonerName': '100 Sniper',
#    'leaguePoints': 531,
#    'rank': 'I',
#    'wins': 108,
#    'losses': 75,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'jRWLx-Gi8ft8YpnXci_mPTk1RHNVVcFmKN7EgGg2CZgDvZI',
#    'summonerName': 'Jóurney',
#    'leaguePoints': 589,
#    'rank': 'I',
#    'wins': 75,
#    'losses': 66,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'brwrRiQoButNztnvEDpDh1BFALRuOVNlVPbnMIvSXSNrEi4',
#    'summonerName': 'Samikin',
#    'leaguePoints': 606,
#    'rank': 'I',
#    'wins': 65,
#    'losses': 44,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '8KyeFCKbedEzdxWggUXNF3MAqTcV6AT3DWyMpnwWBK6v1FRQ',
#    'summonerName': 'laineebunnie',
#    'leaguePoints': 700,
#    'rank': 'I',
#    'wins': 56,
#    'losses': 15,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'U9XFCzmiW6vBmhswd-nLLfOrz-APrYNPlRrr_VHbYj9pA_U',
#    'summonerName': 'Denathor',
#    'leaguePoints': 615,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '5WzRTJPVC7kLnm68NCer64XzI_gZ2Pyqt1jv07rgvgxzlwY1vnKkawJUPA',
#    'summonerName': 'þ Dark Templar',
#    'leaguePoints': 579,
#    'rank': 'I',
#    'wins': 73,
#    'losses': 44,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'fDyM7reC8ZsNuG-wFvC-w9dmwnkQDbX5e4vVtn6dwe5XWCg',
#    'summonerName': 'eIse',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 69,
#    'losses': 43,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'HfgwFuLP2JLifG5LhfyMQl5_tG-PvDM4Q-DKkZIeSjKQaN4',
#    'summonerName': 'Eliass',
#    'leaguePoints': 516,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'JYnQ4UCS-FgSblnrV76LPY6RO0F4B80nNDYt8VvodVVQFWU',
#    'summonerName': 'Phantom',
#    'leaguePoints': 592,
#    'rank': 'I',
#    'wins': 85,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'sUYnak79zcL2uZ_WzchWX56tppU-W60FybeMt9u6H-LglsIz',
#    'summonerName': 'Wuju Saber',
#    'leaguePoints': 708,
#    'rank': 'I',
#    'wins': 136,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'd3a8bpcYNInAKBaJhP07J5c8Z8KRNIv-xajVTypdgD_z8YXM',
#    'summonerName': 'SlayerSupremelol',
#    'leaguePoints': 646,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 56,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BLE2Ij_Yl72bnQSOARxlg4tGy9mJkFa3pIrGtBulMyB0wyo',
#    'summonerName': 'Le Sontofukimchi',
#    'leaguePoints': 711,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HuovBHb8eVGpCZyaKLvPWXUHNjfqGR7C3GmblBvkRrYxNoFd2iPwQF53mQ',
#    'summonerName': 'LaMeIo BaII',
#    'leaguePoints': 535,
#    'rank': 'I',
#    'wins': 78,
#    'losses': 46,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '9amDTlucRTBjOqHFbzhe0XOA53BQIIpuyf_t-6Zmwx-TMKG6',
#    'summonerName': 'Kén',
#    'leaguePoints': 514,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fHA_Wtrin55wkwO_KkzLcE3ovY4zFxJC0GIy6DmibKKVrKHdGjGpafX7JQ',
#    'summonerName': 'tæsoo',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 95,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'hJ3cSZOWxvhl3g4xmWtrMx_WwOhWVCr7OtsWjt5AshgCPT0',
#    'summonerName': 'Nikkone',
#    'leaguePoints': 643,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 71,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 't54H9T4rdrVb6JVmk-x1Uvnx_JpQ5LQdd8XScyDL-IarYAw',
#    'summonerName': 'Giant Yordle',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 135,
#    'losses': 107,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8zpoy2nJvhDVq_a0C989_zL8YcT-q3yIpk9AMprLjtkDXBc',
#    'summonerName': 'neeko sex king',
#    'leaguePoints': 514,
#    'rank': 'I',
#    'wins': 61,
#    'losses': 39,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UvK5Hw6tTNvAHtJLeKwWVMsNetlGabRYYw-mp_nHgUFMLhk',
#    'summonerName': '',
#    'leaguePoints': 595,
#    'rank': 'I',
#    'wins': 52,
#    'losses': 36,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XYBBLRlHdWYU6iYUBsYy_Q1lfkEa5YkiPHK4etRih0ZyIC8SfDDkvIj5Hw',
#    'summonerName': 'gargora',
#    'leaguePoints': 537,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 83,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7W_Rq5s5lCMptlgVjgAFRt1mhovjHiI9pwsjHb7mhQSegSo',
#    'summonerName': 'Principal',
#    'leaguePoints': 688,
#    'rank': 'I',
#    'wins': 88,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ifIQBA7zD8VsyZZP6-5FqgkWU25OWESMOnPCo1HBCmo1FiEp',
#    'summonerName': 'RapÍd',
#    'leaguePoints': 566,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 80,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FRxn-ElQeup5OHZdk0AoqqL-mph7BVBh-8m1GFUinMXoqLA',
#    'summonerName': 'Kzykendy',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 66,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'jMhrZXgRLCHLiwZn76lkHzxHsFADEWCJMKiDuUGCIZP8CO4',
#    'summonerName': 'who dat who dat',
#    'leaguePoints': 823,
#    'rank': 'I',
#    'wins': 157,
#    'losses': 123,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wRmH8g43IbKpyq4P6zjsK4PBYSkTzp4xSzmheqjkfaVPzYw',
#    'summonerName': 'Breezyyy',
#    'leaguePoints': 541,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 130,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '3o7qpJGdVzAn6JXyDO6_CtbI2MUKySnuz4Ye_XcDup-4gyM',
#    'summonerName': 'RHINOOOOOOOOOOOO',
#    'leaguePoints': 514,
#    'rank': 'I',
#    'wins': 47,
#    'losses': 21,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'QSdIhIrv-3MJsS2L-P4DBjtQdkjHzVm7sD6h6UiRQf9-a_I',
#    'summonerName': 'ThëBeesKnees',
#    'leaguePoints': 587,
#    'rank': 'I',
#    'wins': 139,
#    'losses': 111,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'JyVbvaFjGFQnrmF7A51Te5dHFJpg5SvH_CotmMwGo0oZ6ew',
#    'summonerName': 'My Seal',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'U32tE6bQlqX2X87DDI1QLUNCNujUUyY3wYSfzZyc_jaYKZAJbMukXKevKQ',
#    'summonerName': 'SIayer Supreme',
#    'leaguePoints': 548,
#    'rank': 'I',
#    'wins': 46,
#    'losses': 16,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'cVc0nj5uaKU_bJ_M4tF11mLlixEMW_jeDZXqLZw5XUlhYfeAJrO6UEpyGw',
#    'summonerName': 'THE LP PRINTER',
#    'leaguePoints': 517,
#    'rank': 'I',
#    'wins': 77,
#    'losses': 43,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'RKSLuFcMFh2R9A13U_XnEFKQe8MNe1QNp5Hjgn_yuw5OECXvNLlmoxlerQ',
#    'summonerName': '',
#    'leaguePoints': 509,
#    'rank': 'I',
#    'wins': 115,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '4tAVLjcHayNT6Me1LXPJ3LraRD1lwL0S0qL3K7zoctoVg0VqEbZ8dEpeiw',
#    'summonerName': 'FLY Yuuji',
#    'leaguePoints': 783,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 94,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'RBCj3Rgz07pmI94pRqKf4B3l_GVkkv4gy2PtKPcriin6Y9WR',
#    'summonerName': 'Mrs Daughtrey',
#    'leaguePoints': 632,
#    'rank': 'I',
#    'wins': 84,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '5udTyKLV9bHM-M9frfMLPpd3Ghh6b96rNgga6I5I9mM7mrw',
#    'summonerName': 'Stop It App',
#    'leaguePoints': 554,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tbkkpl9Rbv_g4eP2xViglU2WbJqMFJvwOS5JRE0b9qH_BxzRit7p7q0V2w',
#    'summonerName': 'GoldenRiver',
#    'leaguePoints': 691,
#    'rank': 'I',
#    'wins': 70,
#    'losses': 34,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'T6C-YYda7bqZEq8JzH8vsLea2EmcIJ_k35i1cFO8jorNd3w',
#    'summonerName': 'Wocaoo',
#    'leaguePoints': 512,
#    'rank': 'I',
#    'wins': 54,
#    'losses': 34,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '1IfYUJzvh33gNWHj5EEa-v9ZR-lxl6Cq5CJOwQbZ-K7uC0u7N4UVqmP3PQ',
#    'summonerName': 'Yonedaime',
#    'leaguePoints': 529,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'mX4R_JQoL_KKz3GG-mnnX1lr9kx9CvV5jc4QV4fQ0pPrEPY',
#    'summonerName': 'big dacko',
#    'leaguePoints': 579,
#    'rank': 'I',
#    'wins': 73,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '4_09XRZ4_m-tTJWEYVeaS-uP8cMwNdSfBzI3lEkprXyqVxQ',
#    'summonerName': 'twitter InwonLT',
#    'leaguePoints': 916,
#    'rank': 'I',
#    'wins': 101,
#    'losses': 60,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'p3AW4h--39zSqNyEYR50VTM0HmcBIX5CtcEp6c9TBDu3JDk',
#    'summonerName': 'KatEvolved',
#    'leaguePoints': 1109,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 131,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'U6qVKv41ALWAGWxS6mHoT8bM-WbGdDy1LxpGebn0s66I-o-q',
#    'summonerName': 'Skywardd',
#    'leaguePoints': 508,
#    'rank': 'I',
#    'wins': 101,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'yiaSXgnZKUMcWD0bxsvh4xh_uma6ES6xp8OPI5qBVXTrCO8',
#    'summonerName': 'enryu imi',
#    'leaguePoints': 563,
#    'rank': 'I',
#    'wins': 78,
#    'losses': 55,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '-a8VreZdDCEnY9g96k61VgkYcXQ8sdO6uDtxe2SG8sZvtY1hqBbiQ9VtSA',
#    'summonerName': 'niUAzIbNaRHoggRw',
#    'leaguePoints': 814,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 40,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'RNG7Slbnoq5c26O1lIOco0nO_OGxUDBhGUpHLJzxD6oZOqLM',
#    'summonerName': 'TL Honda CoreJJ',
#    'leaguePoints': 713,
#    'rank': 'I',
#    'wins': 75,
#    'losses': 49,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '_40DnVN7yo1m1MVaf2I16QmVdRisSaw9wtl0S_TfXCX-s6L6QXjBQ4-9-A',
#    'summonerName': 'weieryuxin',
#    'leaguePoints': 1248,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 39,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'EZNosD54lpgMz6aAMD4sLj_7Pvxcp4bcyDOGut7FAD0QwfA',
#    'summonerName': 'Click Click Yay',
#    'leaguePoints': 508,
#    'rank': 'I',
#    'wins': 70,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '5Uz6yjH2aEwP7nciEHNpI-ye3AX5fMhHUi-vHQaP1kmw8Pg',
#    'summonerName': '10 IQ PLAYER',
#    'leaguePoints': 608,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'LDUTt5CwtTer-2B6ibOLwV8Ic1mbQeP06mtmeqCrloIuh5ykrMOWqkhyUQ',
#    'summonerName': 'I will trade',
#    'leaguePoints': 798,
#    'rank': 'I',
#    'wins': 71,
#    'losses': 38,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'qv2mLpLJgo2Wjq2FA0b9J56JvrU99cXwGAu9nmi_Ckx6gG1wvktwk2f0iQ',
#    'summonerName': 'GandalfTheXiao',
#    'leaguePoints': 506,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ZlIBR35vfolS50BxsIVoQB6Q56z0J4QXV7xlsuVeQnxmOcwO4BZCOqEncw',
#    'summonerName': '',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 73,
#    'losses': 47,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'mikhSQWqJarkFzGwlqB5LvY0OmgK5mi4ke2SUjP26NHbnj8',
#    'summonerName': 'sha2am',
#    'leaguePoints': 520,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rgsoEHrYLBzAidi5hzRiXhiWNOJ-FxWRcRjMLgl3Cqr-ULc',
#    'summonerName': 'LFT Draven baka',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'Q9IYp0ROQE8ZIESc6NpnHljcTNzduq7Idh4Jftm_RLhRBnU',
#    'summonerName': 'jamican banana',
#    'leaguePoints': 739,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 164,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'aVCqdvzTimgk1g5LjzCzfiXoc0szzpdtPTE02a4o-Q',
#    'summonerName': 'Pobelter',
#    'leaguePoints': 889,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 144,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'UTHilYANq8OmknEmY_oC0RrHLQ8FHK8bMTThizeajXx686Y',
#    'summonerName': 'issariu',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 58,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'sXc2alyafIxxiZ5gF0p53dBQiDaDJpNYpF4IgyokCkGgNN0',
#    'summonerName': 'duoking1',
#    'leaguePoints': 501,
#    'rank': 'I',
#    'wins': 57,
#    'losses': 32,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'cZkCWRjqnX4luimUZvQGJFCa5J7PVAGv6n-LH6Fm1BHB0cY',
#    'summonerName': 'T0mio',
#    'leaguePoints': 1088,
#    'rank': 'I',
#    'wins': 119,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NvjUzx4UDTyvO5JZg3_4vQXbrxrjQblk4H1VV9HoMzXVOq4',
#    'summonerName': 'dtro1',
#    'leaguePoints': 644,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'GhY5Phthou6B_T-8DqbMqG_2n_oI-EBqTen7LhFDV3zDdKjXyVs8IGZfeg',
#    'summonerName': 'drowsy fever',
#    'leaguePoints': 577,
#    'rank': 'I',
#    'wins': 130,
#    'losses': 98,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'EFobjuuQgt3jc1eWtoV0ZDTds-RbE6-iWDFRE4RZIwQFRr8',
#    'summonerName': 'no invade pls',
#    'leaguePoints': 836,
#    'rank': 'I',
#    'wins': 145,
#    'losses': 109,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'MBa8yxcqz2nO3YyRiRmQUJJl7fK60wHMEvR2-OIXjXQ6mFnPTNac-xOb_w',
#    'summonerName': 'Vamks',
#    'leaguePoints': 569,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'AuapoE6qTEyRsDMDh7yZ4MvwM0GQ3WCF99FcJntCv60rStinqeLRdunSvw',
#    'summonerName': 'Jiang duo bao',
#    'leaguePoints': 728,
#    'rank': 'I',
#    'wins': 71,
#    'losses': 49,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'O4ZHKCOyOmr7vP12hTdl0KvMmwuvEpI22Kn9U64iDChLv3WvzdDWHVvKxQ',
#    'summonerName': 'torturedhero',
#    'leaguePoints': 788,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'itvveuk9Bui2dLR9P6acufZymKtkwh5vfW_YLY6YFIkbgmTWhoWiSYcS_Q',
#    'summonerName': 'Levitate',
#    'leaguePoints': 545,
#    'rank': 'I',
#    'wins': 78,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'E5qNdaIyrt1vpOS3Tri2HIzpVYAs2biUJNt-HtHG6v2b6-w',
#    'summonerName': 'Cosboat',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 54,
#    'losses': 29,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ui1y8N3VAFMLkR5o0p1qMImKvrD28Ft-N-oGz6JcLoE-ovQ',
#    'summonerName': 'MySwordCrimson',
#    'leaguePoints': 955,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '70M-KQ74HHU2q0c3CNqvUgDxM1mx9dy8Zdtc54MMzTE3VvyH',
#    'summonerName': 'Arendelle',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'U77mma9uUgzKegmF3IEhjNHO2BQerErwoQFy-4CvudYz0OHLBh9lFOZTHQ',
#    'summonerName': 'randomlydie',
#    'leaguePoints': 1025,
#    'rank': 'I',
#    'wins': 83,
#    'losses': 35,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '9DSgCign2AmmyjhMY5TGWH9tFelGNCFIWOB6kQVznWQu4HrV',
#    'summonerName': 'handytaco2',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 101,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'S4Y4nqpisYVhaIQeD5Yl6HcRnyP0OFiHokjB2k9Sr8cODB4',
#    'summonerName': '14 July',
#    'leaguePoints': 819,
#    'rank': 'I',
#    'wins': 84,
#    'losses': 47,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TDZL026Qft88JHrFhUYw7RuGvJJ417jNjkVstGCLUO2mkt8',
#    'summonerName': 'Like star',
#    'leaguePoints': 594,
#    'rank': 'I',
#    'wins': 139,
#    'losses': 119,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'Ydz-7h9-t3yECMZ18b0rvemN5vtBFnT8q1RKcrkRIjvs2MY',
#    'summonerName': 'Tensidade',
#    'leaguePoints': 610,
#    'rank': 'I',
#    'wins': 116,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '9XfIZPqGFnad3eQuBs7LqZgmAqFRJYRklx2Abxr8rxTTSQvcoACu4YwecQ',
#    'summonerName': 'TTV Pomerzz 1',
#    'leaguePoints': 684,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-0a1G_cY6kpAM6Ew_aGa0ldkNAy6-aGMIvkM4uKHg4sP3ew',
#    'summonerName': 'Nanners UwU',
#    'leaguePoints': 519,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 127,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'c8zNByStydQ9LR4Q6kqG1jSoatJrYwTz7GStGWq9AdJ9xxE',
#    'summonerName': 'Qube',
#    'leaguePoints': 541,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ElK2hR32ieQE5nju9oI5HCe5oPvTY2q5uH1Ln2ysVljP9SAWW9_lJ1dTzw',
#    'summonerName': 'KeeL9',
#    'leaguePoints': 660,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NoDFBA2bjixNnPgWk00ooZzX-eWziX-J-u2BI5oo-T1rADFHbFUmf0DFIw',
#    'summonerName': 'Xe9GKFW9KbJyNKxR',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 64,
#    'losses': 31,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'pLhGjHcDmP8m-5NYuwpU9uTa56vrbOjgYeJ4AnY0UF5eDW6e',
#    'summonerName': 'nxi',
#    'leaguePoints': 650,
#    'rank': 'I',
#    'wins': 99,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#    'summonerName': 'Miraicle',
#    'leaguePoints': 638,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 85,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'R5Z7cH2Nu1DQ6iq_zkEHCXNsPUmRLa7iusD5r6xVm_Qy6944',
#    'summonerName': 'Shippuden Op 4',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 83,
#    'losses': 47,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'k_yW5VHr5Xl_KCwJ0iEEd4m6G9ctXO2TXjdSbh-PezOxWI8',
#    'summonerName': 'Sushee',
#    'leaguePoints': 660,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 80,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'BwoHWhlOyNuNrod_jA5YgrA_aYMZZSBtxh0T4cO5rvipKoBU',
#    'summonerName': 'Kenvi',
#    'leaguePoints': 574,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'QrPoEOfAQF5BIj8gzwsULoKbPAU-fJLNa5rpKmxBn4rqMObl',
#    'summonerName': 'UM1 Kokushibo',
#    'leaguePoints': 634,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 91,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'PBWRBL3uHjHuUciiTpn3uFDnYkBnCwcyYbPbQaiXFE4WTdU',
#    'summonerName': 'Hyattie',
#    'leaguePoints': 518,
#    'rank': 'I',
#    'wins': 72,
#    'losses': 49,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '14Vy1pLcu-tzMX7HwryUWHND2WsbM962533V0igUTEYzvbC8tNMPeCf_Xg',
#    'summonerName': '16th place',
#    'leaguePoints': 583,
#    'rank': 'I',
#    'wins': 93,
#    'losses': 72,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'HaG60DzjbSgDly0LcUEWppRVMSplIkoCvFHWS6qUmJcTh9Y',
#    'summonerName': 'kıńo',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 83,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'q1qIweTM9g3JWg2rMunMtqMh1QNEFIWNnbEGcORlkKseu0ZJ',
#    'summonerName': 'jin tui wei gu',
#    'leaguePoints': 507,
#    'rank': 'I',
#    'wins': 69,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'eYVZPoVCS6O8RyPwWjWdr664Bt6zJGSd7cMA0jNswGxpVN8gQTlYRSS8ew',
#    'summonerName': 'munch btw',
#    'leaguePoints': 551,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '51HrVtiwUmvFtleIbps1UHPBuM_EizJf0WRH8Qnz338bDJriZv-CebBsqA',
#    'summonerName': 'coached by NEACE',
#    'leaguePoints': 520,
#    'rank': 'I',
#    'wins': 95,
#    'losses': 30,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'OA19C5Gpj1ydnF6L3zyXEaBEb5Qq5TfhUSd0LX2nXWj6q2g',
#    'summonerName': 'Just1',
#    'leaguePoints': 453,
#    'rank': 'I',
#    'wins': 61,
#    'losses': 44,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'XSfjpo2Ir5y8mBcZ1br94tIX68prRhKghhoFZ3zdtJwQlY3s',
#    'summonerName': 'unbound angel',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'aKx-z1jc_rt22dE3XGVcV0Py2JrYAOr7j83qAeco42U3ZW0',
#    'summonerName': 'live Iove tickle',
#    'leaguePoints': 585,
#    'rank': 'I',
#    'wins': 77,
#    'losses': 40,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'QOPt3CAKNwxCQvhmU_HrN11Xvs1n7aXHPwRBu_1f01qbhWY',
#    'summonerName': 'im Ahj',
#    'leaguePoints': 575,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 95,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8acrFuXSZhKlIYvjq8hlseJK_PP-T2MaR5wGtooELF6mUGscmwIV1dVHJw',
#    'summonerName': 'iqwoieqjwnf',
#    'leaguePoints': 751,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'FmPaKz16rU--LSQuzUQFfnknfxD2VTjhYX_q8UatOJa-KnQ',
#    'summonerName': 'Conchad',
#    'leaguePoints': 559,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 62,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'yS75nMdSTrJ8BDNqpzGb-bSkDTqz4zEwDDW0XQBwX93sVQE',
#    'summonerName': 'Spica9',
#    'leaguePoints': 1111,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 112,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '7MrxEULjNY5RvExnzfpRFYkEpP-jG4yl_LLWuCDFHw2dUxU',
#    'summonerName': 'dpi6400',
#    'leaguePoints': 754,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'PntFnMxVP8877hT91sD9h8-Hj7m8LufI_3JQjht6vS6XgCVisRPzOSMwbw',
#    'summonerName': 'Iast wisper',
#    'leaguePoints': 617,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'yLAvWRMEnQtQilFuSiKQa5IU9Wd2IIlrT0FvidOJ7YvjV1E',
#    'summonerName': '4 Stars',
#    'leaguePoints': 702,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 56,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'B5LFdxIQNigg5EOp_TpuzgheAFdWcQ7fI_SE8sxtbGcmdYc',
#    'summonerName': 'eepy idiot',
#    'leaguePoints': 591,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'nAxHMVdaJsOgXLg5BWC0dUfFxYRkGT2bQLeNJhe5WB9rkoM',
#    'summonerName': 'Cendi',
#    'leaguePoints': 647,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 79,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zwvezc3jkgu1zAPuS1ODCaPTHa3t1m__yaS5qK5iq5JTzm0',
#    'summonerName': 'super bubble',
#    'leaguePoints': 509,
#    'rank': 'I',
#    'wins': 146,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oas_mjBNUyYdlw6L9hngTk6u6D9Ey3VZMTTOCuU3JMSXD0bt',
#    'summonerName': 'yukinoooooo',
#    'leaguePoints': 891,
#    'rank': 'I',
#    'wins': 152,
#    'losses': 121,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FkGg8gs5ZSbqy13VCL2P4Vgmxz-XZLbSkMNz2MRHeudBRwg',
#    'summonerName': 'Rhaastafarian',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 100,
#    'losses': 66,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'tqnAV5xRCQlzGEQ824M5LPYvTaJ85Aiw9vJjszskQyl1EIc',
#    'summonerName': 'Jedos',
#    'leaguePoints': 566,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 156,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'OR8L2D5WtYNc_l-sLGJxWzX3DTDo28sJXRqyZV-BuZbiroc',
#    'summonerName': 'Not Cupic',
#    'leaguePoints': 537,
#    'rank': 'I',
#    'wins': 47,
#    'losses': 22,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '244bm4InxIa5_NLNOPxe9yTXj9U4PvLnoeAs2W-8N4hN2cA',
#    'summonerName': 'sorde',
#    'leaguePoints': 810,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 97,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'isfIZjXDPTgOPIpTwYaXjn06_IiUYy3TIFcTRUFOwXohyz4',
#    'summonerName': 'Fishlord',
#    'leaguePoints': 531,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 92,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XUdFMI6EMNszktdOVnF254F-EBOfgqOhcWnPL4R8k8FgFAs',
#    'summonerName': 'Alekseyy',
#    'leaguePoints': 577,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7Pf3FHBIzCHk_SrYzxDIEwYdJ2ozoIy8f3L7STYOm0BiqkY',
#    'summonerName': 'Niikaido',
#    'leaguePoints': 534,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 78,
# ...
#    'summonerName': 'Only Human',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 91,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7WuaMhzhiA6fG5GDN28DNvmTouw-2mEQtzuWir-XAKAae5MjeuOLjU55iA',
#    'summonerName': 'Mountain Haze',
#    'leaguePoints': 501,
#    'rank': 'I',
#    'wins': 81,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'pDMi_jAOdKsn02lNMcLofcfUmpxdW7FMP1GSLB9QECvQ0EOc',
#    'summonerName': 'zz1',
#    'leaguePoints': 899,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 75,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Jdf16qhrWT-YVEC54TjQ7nhdydYeeno59r3kOKXZk93VUho',
#    'summonerName': 'Dhokla',
#    'leaguePoints': 522,
#    'rank': 'I',
#    'wins': 100,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'fc0ST6D0U-1wRlUhxNCRZKusDK3Vl9c_kCeoi2NVxwQy_2o',
#    'summonerName': 'Losing Focus',
#    'leaguePoints': 542,
#    'rank': 'I',
#    'wins': 101,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'DR8IxTq5CgS6dGVwdePpK5jPJHGE0ZcKA3UZwTiBMBTJ20OtBKEBl6ic0w',
#    'summonerName': '599',
#    'leaguePoints': 604,
#    'rank': 'I',
#    'wins': 58,
#    'losses': 24,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'zYu5mcLfznMQu9NxV0giXpmDw1XXUUFiJgbxN_i059_6T504fLBYKRmeGA',
#    'summonerName': 'dunya',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 78,
#    'losses': 57,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'XX-gCMa3qVVH3X_GDVERDMtflk3G4oqJkwZX7cVn9Wmz3vmfJq1_VgHaqw',
#    'summonerName': 'Eventual vîctory',
#    'leaguePoints': 668,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 45,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '-xfjRuSnJMa9-ozgUytII9rTQwx4uRKnFhE8qY9z-DJb_MYQFDJ62KXV7w',
#    'summonerName': 'T de Tilt',
#    'leaguePoints': 667,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OSPUh8cUfNfkcQz4iDAooaE330am8SvUi4HnG2MzkGbpW58Lsa6cZvLwsQ',
#    'summonerName': 'returner',
#    'leaguePoints': 502,
#    'rank': 'I',
#    'wins': 57,
#    'losses': 37,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CNYsYp0hxLeEj6iVRdm3YH9GxfRs3x-KB0iPzLX0j9EnJWk',
#    'summonerName': 'Akamige',
#    'leaguePoints': 520,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 123,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '-mhcnkW-OLwr1jOuQ05Jzw1eONo6LCqQWQnDg1_g_FKql7Ggglc-U0voDw',
#    'summonerName': 'Crispena',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 136,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '3hWahsCil-57fIKDtHCp54aII6aiinSINyxtCGuAqMRDg_hd',
#    'summonerName': 'YørdleQuęęn',
#    'leaguePoints': 542,
#    'rank': 'I',
#    'wins': 76,
#    'losses': 44,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'gINg2-2FDhK_tjkvc5cOLpQADDkXDziSZWk6TwiEbSjigRRyhQyO6gCEjQ',
#    'summonerName': 'CHAO JI XIAO LU',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 65,
#    'losses': 36,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'zgcaJBgTYhKT_U3XlbLE1tp2HEl0xb1xurEfeGp-06q8e9U',
#    'summonerName': 'PantsAreYouTube',
#    'leaguePoints': 845,
#    'rank': 'I',
#    'wins': 267,
#    'losses': 228,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mvGPvcfcRbJ5zgMuJ1VAa1OQXxCUYHg-nn47aNe32w7zwzM',
#    'summonerName': 'HOOKED by kz',
#    'leaguePoints': 821,
#    'rank': 'I',
#    'wins': 88,
#    'losses': 57,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'IBmqaGCoDEl0rWNiJPdeuIg_Eq27c-U_qSuDW5YPQgra2TQ',
#    'summonerName': 'Insomnia Jjangu',
#    'leaguePoints': 628,
#    'rank': 'I',
#    'wins': 107,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OKl7eW3_3X5RqtKgPO4bvk5rfJF1PadwvFkrXtOH12X3ZhV0RqG7v2-YLw',
#    'summonerName': 'toe enjoyer 69',
#    'leaguePoints': 576,
#    'rank': 'I',
#    'wins': 111,
#    'losses': 87,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'SwGeyc-cb383SE349EORuRRLi1BR97LwAkxQX87oJowv27-M',
#    'summonerName': 'Ke Ni Jiu Shi FW',
#    'leaguePoints': 535,
#    'rank': 'I',
#    'wins': 125,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'dCDdzw1sZiMWZxOaymJ7EEu-F3YNNQQsNa-06cczIK_KI46N12-zZbYRqw',
#    'summonerName': 'WDL',
#    'leaguePoints': 703,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 107,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OSlP911nCPnNW16tdhl_DF-t8x_iZOOKT4hCh5bEjpZ6nOgnce0ML3WqOQ',
#    'summonerName': 'Retrozing',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 77,
#    'losses': 55,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'NY2-_pv6rkvM11yjEQJRDormlgKXrrByl5SniH5cpzuCxj8',
#    'summonerName': 'Kenny4eva',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 52,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'fiZFZ3gDjhxWwsRNb2frmqxRXqAfjVpRsCbdvDOlUCqQ938',
#    'summonerName': 'Aedes',
#    'leaguePoints': 462,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 129,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Y8jnQ_LNnI1JG4dB9jmShK9xt3wJv0CSkzJ0YANEUgEYiPE',
#    'summonerName': 'da xi gua',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 126,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '6Gat_cukuM-CGb374tUt8j5_xn4rLvHpASJi2EhNxDHC0l_P',
#    'summonerName': 'philosophy chat',
#    'leaguePoints': 589,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 61,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'qEeOj_YWuP16C7-Zo6ZN9K67xjhReTDnRv6fVt2jHdVFePI',
#    'summonerName': 'Shockey',
#    'leaguePoints': 530,
#    'rank': 'I',
#    'wins': 71,
#    'losses': 52,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'buZxqgp9H8KstAE5OlAc5xHJluHz3UV_GO0DYHJvKbClJ_M',
#    'summonerName': 'PaIco',
#    'leaguePoints': 543,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '4qSBwDEY3ooFd7OIcJGLchu21PhsJH3odDhxAYdtqiBUlKs',
#    'summonerName': 'RENGAR EATS BUTT',
#    'leaguePoints': 677,
#    'rank': 'I',
#    'wins': 57,
#    'losses': 19,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nJ9atcJzVoR0zzdjlaU2Cy3mB7Tex7Mr_BuWxyTFREvaStg0GsQN86jzEw',
#    'summonerName': 'kingggg9',
#    'leaguePoints': 528,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 53,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'TuHEcW5F7tsDf8jD8krUv1ENaMH1ASyQlrQQiGgQrImlWB0',
#    'summonerName': 'HandfooI',
#    'leaguePoints': 627,
#    'rank': 'I',
#    'wins': 202,
#    'losses': 187,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'KNh61lqdK8xZwkCI6i-ueuke-HqAHZgXxbSpqHt0LpPX6Kg',
#    'summonerName': 'Matrixmdmd',
#    'leaguePoints': 535,
#    'rank': 'I',
#    'wins': 63,
#    'losses': 25,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'yhg4JCp6aRH-9lHKDnRMQxbsIkJAv8JaHK7dO57WjbnP4UY8',
#    'summonerName': 'NA PIayer',
#    'leaguePoints': 793,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 39,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'cD7Wjkip5CPqTB68qNkoHaJrhWwxK1BUeVr8H6HG5Rszgpk',
#    'summonerName': 'Jauny12',
#    'leaguePoints': 774,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 66,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'P7aN4D5sbeNCiSPIN9yoajAqAynHsmTVTalAu-RvtKS8vE4',
#    'summonerName': 'Allorim',
#    'leaguePoints': 555,
#    'rank': 'I',
#    'wins': 93,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'BVmHHk7AlegS3-_JQdAOpbEB70ko9oYUIQOX0AofPb_5r3ae',
#    'summonerName': 'sup line',
#    'leaguePoints': 817,
#    'rank': 'I',
#    'wins': 99,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zUxLsrSMjYZ5daYOUJQWHdtvrgyQRSVLhFqeVwVmyMHvVcXJ',
#    'summonerName': 'Space Excalibur',
#    'leaguePoints': 587,
#    'rank': 'I',
#    'wins': 81,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'XM3tDLjRVFPf3IJdA37WptKOG_zp21UX2dYJcVJMj4oz5gk',
#    'summonerName': 'kookykrook',
#    'leaguePoints': 501,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 195,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ReHf_lsBFAme-vqWHJ9CNtRhMV_4HtqUB_wZywRYswVLiFJa',
#    'summonerName': 'array4',
#    'leaguePoints': 772,
#    'rank': 'I',
#    'wins': 84,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3DCcl7hOs8cGJ-z3c2MF9X_ikfs5Uu9oXEXYvD25R4YJJQh5RUTht1UAnQ',
#    'summonerName': 'Shogolol',
#    'leaguePoints': 521,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 75,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'PpjgL-oQS_IClNJUKlCViu0Csk9xwIlQPA1lw8i76D6W1H8',
#    'summonerName': 'SK Telecom T1 K',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 107,
#    'losses': 87,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Xwk8dlJ5mmv_Jyz-ugE8hcx33xLfC4k_DzCSobiYZUr-oD0',
#    'summonerName': 'Khalood Habibi',
#    'leaguePoints': 779,
#    'rank': 'I',
#    'wins': 98,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '19UhWgWcJK9jEUxoe7f0_HbCt6w2GdXpJAZlTRI5OJbRiZM',
#    'summonerName': 'wx tonytoppwd',
#    'leaguePoints': 1140,
#    'rank': 'I',
#    'wins': 203,
#    'losses': 156,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-1I6gcvbPFHw2-UOMjj57Guy97R9YklsAr9aM4dEeqhVTfo3h-b6XNjHew',
#    'summonerName': '',
#    'leaguePoints': 575,
#    'rank': 'I',
#    'wins': 99,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HvU0BpCbq01igkDtSC0x3Lyt95Lxxonpl46FuuoH0DTv3kI',
#    'summonerName': 'TempestLoveYuely',
#    'leaguePoints': 860,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NCX4mxfkqOTJ5coQpOUA4UIVek7a4A7v-Ec6Riji3WrbO54',
#    'summonerName': 'TheRealPhilip',
#    'leaguePoints': 648,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 60,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '-vh6V6Lkwmzxxp7QTnsNNF9YzPTQYaOjsjU6iw6RiZRaFo6mvFIFR-xqRA',
#    'summonerName': '',
#    'leaguePoints': 542,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'at8h-dBLaw57fAmlwEUaE0ayfQf8ginutkdgfhDCXTP9Ae0',
#    'summonerName': 'Mitch McConnel',
#    'leaguePoints': 514,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 64,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'm-pxg623eyVPaLZi4ZAirHCTlzzJYF2z2Kb5zlUs4TK42UvA',
#    'summonerName': '171 xo',
#    'leaguePoints': 500,
#    'rank': 'I',
#    'wins': 73,
#    'losses': 46,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tyFe2uQ7s1223uGuluQ0MYmyzl3bwnm-qKpeoPooo4b079pBCW2NjaSE7A',
#    'summonerName': 'Su Muqiu',
#    'leaguePoints': 552,
#    'rank': 'I',
#    'wins': 67,
#    'losses': 40,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'i--pBiMTp5RG9_j8YAZgajmFmzSxBd6aSgS6X0NCIl41OHbK9zAaYGb0Gw',
#    'summonerName': '',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 31,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Bp9QSCqc4S4LPhlVx-HfxqYsszi0yT2mpKSCAfhKVrMbVb63',
#    'summonerName': 'FF moment',
#    'leaguePoints': 718,
#    'rank': 'I',
#    'wins': 193,
#    'losses': 169,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jFmDOxHdM4h-dJLxkxjwM294xoEHf4UR52hoXkLPYGKgBJMFEbXQ4Ky0FA',
#    'summonerName': 'jqu6rTseuBYIuGxu',
#    'leaguePoints': 922,
#    'rank': 'I',
#    'wins': 100,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'SdvZU7EKytLe9r8ebwSVbiDOZE1OwXxyFHG3VQZgv6sQ_4g',
#    'summonerName': 'lunacia',
#    'leaguePoints': 616,
#    'rank': 'I',
#    'wins': 99,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'yGuidR7rJ3dOkMSl76O0aHjmepBVe4-WF3bEoA-t5w21mPDNZeD0oNjkXg',
#    'summonerName': 'My Dream LCS',
#    'leaguePoints': 661,
#    'rank': 'I',
#    'wins': 92,
#    'losses': 62,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mcy9VLuImuWa3ozAXAYqgOYoCeHJxSIrXdY-FJVr9XqFGRw',
#    'summonerName': 'DDOSS',
#    'leaguePoints': 579,
#    'rank': 'I',
#    'wins': 77,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'AwB5ZizK6isdT0-8Ki65_tm1pXBi48A_PkAW9g_XXoU22nM',
#    'summonerName': 'eodum sock',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 137,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'VeJW9pwLmt8PQsc-u6qYnQSQIPCE7RSnyrpFdS6C0yLqY_En',
#    'summonerName': 'AhernxPt',
#    'leaguePoints': 508,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 61,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'QYtmUzQCTrdeufM8lgMO2D1Qqc9ci2YzAhMK3HxHmEC8jp2Nb-_xfzbfaQ',
#    'summonerName': 'Shrimp Shark1',
#    'leaguePoints': 656,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'iQNy9SuiObvB0_0qApfxtBYOxPT_vRKjs2uctGwuORLQKibHfiLv5VIZJQ',
#    'summonerName': 'Hannah Targaryen',
#    'leaguePoints': 615,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'sre67mm7eJigZF-QwDCCvxaFtGnejQIskTWj7BmsAv_xr2BzJpyDpSv78w',
#    'summonerName': 'iIOK4oe0HokFSa2D',
#    'leaguePoints': 706,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 41,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True}]}

# %%
match_ids = lol_watcher.match.matchlist_by_puuid(my_region, kumo['puuid'])
match_meta = lol_watcher.match.by_id(my_region, match_ids[0])

# %%
match_meta["info"].keys()
match_meta["info"]["queueId"]
# Out:
# 420

# %%
match_meta["info"]["teams"] #Team ID 100 is blue team. Team ID 200 is purple team."
# Out:
# [{'bans': [{'championId': 20, 'pickTurn': 1},
#    {'championId': 78, 'pickTurn': 2},
#    {'championId': 84, 'pickTurn': 3},
#    {'championId': 254, 'pickTurn': 4},
#    {'championId': -1, 'pickTurn': 5}],
#   'objectives': {'baron': {'first': False, 'kills': 0},
#    'champion': {'first': True, 'kills': 42},
#    'dragon': {'first': False, 'kills': 3},
#    'horde': {'first': False, 'kills': 0},
#    'inhibitor': {'first': False, 'kills': 1},
#    'riftHerald': {'first': False, 'kills': 0},
#    'tower': {'first': False, 'kills': 6}},
#   'teamId': 100,
#   'win': False},
#  {'bans': [{'championId': 81, 'pickTurn': 6},
#    {'championId': 20, 'pickTurn': 7},
#    {'championId': 28, 'pickTurn': 8},
#    {'championId': 141, 'pickTurn': 9},
#    {'championId': 104, 'pickTurn': 10}],
#   'objectives': {'baron': {'first': True, 'kills': 1},
#    'champion': {'first': False, 'kills': 34},
#    'dragon': {'first': True, 'kills': 2},
#    'horde': {'first': True, 'kills': 6},
#    'inhibitor': {'first': True, 'kills': 2},
#    'riftHerald': {'first': True, 'kills': 1},
#    'tower': {'first': True, 'kills': 8}},
#   'teamId': 200,
#   'win': True}]

# %%
test_id = match_meta["info"]["participants"][0]["summonerId"]

lol_watcher.league.by_summoner(my_region, test_id)
# Out:
# [{'leagueId': '7432311a-8fd8-3d84-ae63-4e3f55ee06bc',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'GRANDMASTER',
#   'rank': 'I',
#   'summonerId': '2xJQF3m0nfMzLqEBjZo3yxKMiStjtD7jkY7IhKokoVicsPE',
#   'summonerName': 'Why am l Bad',
#   'leaguePoints': 450,
#   'wins': 147,
#   'losses': 125,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False}]

# %%
match_meta["info"]["participants"][0]["individualPosition"]
# Out:
# 'TOP'

# %% [markdown]
# Above should show some of the example codes with the last value should be "Summoner with that ridiculous name not found". If you got an error, **refresh the api key**.
#
# If above looks good move on to the next step
#
# # Exploration of an example timeline!
#
# Goal is to find the last game of the player **listed in our enviorment file** last game and the key events of that last game.

# %%
player = os.getenv('player_name')

if player == None:
    raise Exception(
        "Add your riot account name to enviroment file"
    )
else:
    print("looking good")
# Out:
# looking good

# %%
# Get player name
player_data = lol_watcher.summoner.by_name(my_region, player)
print(player_data.keys())
match_ids = lol_watcher.match.matchlist_by_puuid(my_region, player_data['puuid'])
match_ids
# Out:
# dict_keys(['id', 'accountId', 'puuid', 'name', 'profileIconId', 'revisionDate', 'summonerLevel'])
# ['NA1_4915859238',
#  'NA1_4915847800',
#  'NA1_4913902543',
#  'NA1_4913883766',
#  'NA1_4913080900',
#  'NA1_4913051913',
#  'NA1_4909089736',
#  'NA1_4909066231',
#  'NA1_4909027717',
#  'NA1_4908999551',
#  'NA1_4907368584',
#  'NA1_4907360146',
#  'NA1_4907346997',
#  'NA1_4907326575',
#  'NA1_4907312646',
#  'NA1_4907293384',
#  'NA1_4906520978',
#  'NA1_4906502148',
#  'NA1_4906497820',
#  'NA1_4906460448']

# %% [markdown]
# Notes
# - Riot only saves last twenty games
# - If we want to go through random matches, we can follow a simliar approch found at https://github.com/christophM/LolCrawler for slowing opening up diffrent matches to study
# - Some matches may be just ARAM, maybe some are rift matches
# - We will need to keep this in mind
#
# How do we know if a match is an aram match or a rift match?

# %%
match_meta = lol_watcher.match.by_id(my_region, match_ids[0])
match_meta
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4915859238',
#   'participants': ['zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#    'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#    'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#    'pOM6Z9HBZaC9_BDtwTEIXJlUOFu7LxlPMwSFvUIUrCrP8YBBQoUcCh77yGTpj7oAK2tvJ73PmiK1Og',
#    'uttiPcXHs8lm5VUjrlX91lrBRcXCIBUuGwb1_QkYyLecBcWaAkNXCvZiO0wg3UtdMyhSC5rRvj5Hzw',
#    '7zgo_t1-cCqlmm7H8No9RDE86asakBNQZbmJgxo5_IwcJRjlWySn2g8KTxIn3QxjWmLuv0jnKXEd6A',
#    'lw5YPLiIr6b7RId76DLk1NPTH4vCAcS5MMnYp28Wf1eslUL1Ko5nK5OTd-tqbd_wN9B3BtbWGNYL9w',
#    'gh7OaNbKLLDOF03ElMcXADzZzVewF7GjmfeqgHrIKdN9jkOl1W0rjweJEhGM7yloDoF2KjssT7F2nw',
#    'RXzD_9dKc-fJr5xC6ykG8Bv5ocPMxKYyXDjb_Bzr2rDyfPlanOWldeQANK0oqUKpH9k15cOJiwU9Jg',
#    'QiQ6U5WHvO85EFHjXZCfxmPrUmdSS6shJH_Ta0z_PhXHtFabitEjAYYYafYCM1Q7-SgNKBdUANztYg']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1707374382081,
#   'gameDuration': 1398,
#   'gameEndTimestamp': 1707375818510,
#   'gameId': 4915859238,
#   'gameMode': 'URF',
#   'gameName': 'teambuilder-match-4915859238',
#   'gameStartTimestamp': 1707374420397,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '14.3.558.8314',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 10,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 5,
#     'champExperience': 29542,
#     'champLevel': 23,
#     'championId': 84,
#     'championName': 'Akali',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 5306,
#     'damageDealtToObjectives': 33842,
#     'damageDealtToTurrets': 5306,
#     'damageSelfMitigated': 38632,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 6,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 17847,
#     'goldSpent': 15900,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 3020,
#     'item1': 3084,
#     'item2': 4633,
#     'item3': 3102,
#     'item4': 6664,
#     'item5': 2502,
#     'item6': 3340,
#     'itemsPurchased': 20,
#     'killingSprees': 2,
#     'kills': 10,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 462,
#     'magicDamageDealt': 171961,
#     'magicDamageDealtToChampions': 34841,
#     'magicDamageTaken': 24766,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 50,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 4,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 4908, 'var2': 3963, 'var3': 0},
#         {'perk': 9111, 'var1': 2682, 'var2': 400, 'var3': 0},
#         {'perk': 9105, 'var1': 11, 'var2': 20, 'var3': 0},
#         {'perk': 8014, 'var1': 847, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8451, 'var1': 297, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 1773, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 8399,
#     'physicalDamageDealtToChampions': 3198,
#     'physicalDamageTaken': 17701,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6502,
#     'pushPings': 0,
#     'puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'NightRaidKyoji',
#     'riotIdTagline': '1006',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 459,
#     'spell2Casts': 60,
#     'spell3Casts': 245,
#     'spell4Casts': 26,
#     'subteamPlacement': 0,
#     'summoner1Casts': 11,
#     'summoner1Id': 3,
#     'summoner2Casts': 8,
#     'summoner2Id': 4,
#     'summonerId': 'JnLgiARpGvLeWk0VssqSH046kwNgxhRlk12WW8SDKBE_niw',
#     'summonerLevel': 366,
#     'summonerName': 'NightRaidKyoji',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 9,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 10,
#     'totalDamageDealt': 186164,
#     'totalDamageDealtToChampions': 39442,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 43506,
#     'totalEnemyJungleMinionsKilled': 34,
#     'totalHeal': 12644,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 85,
#     'totalTimeCCDealt': 123,
#     'totalTimeSpentDead': 59,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5804,
#     'trueDamageDealtToChampions': 1402,
#     'trueDamageTaken': 1038,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 14,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 11,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 8,
#     'baronKills': 1,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'champExperience': 24699,
#     'champLevel': 21,
#     'championId': 99,
#     'championName': 'Lux',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 4322,
#     'damageDealtToObjectives': 15367,
#     'damageDealtToTurrets': 4322,
#     'damageSelfMitigated': 8156,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13182,
#     'goldSpent': 12800,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6655,
#     'item1': 3020,
#     'item2': 4646,
#     'item3': 4628,
#     'item4': 4645,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 18,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 478,
#     'magicDamageDealt': 62877,
#     'magicDamageDealtToChampions': 10728,
#     'magicDamageTaken': 16395,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 10,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 391, 'var2': 10, 'var3': 0},
#         {'perk': 8126, 'var1': 608, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 4, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8224, 'var1': 1016, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 7682,
#     'physicalDamageDealtToChampions': 556,
#     'physicalDamageTaken': 4106,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6503,
#     'pushPings': 0,
#     'puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#     'quadraKills': 0,
#     'riotIdGameName': 'NightRaidRin',
#     'riotIdTagline': '1006',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 59,
#     'spell2Casts': 49,
#     'spell3Casts': 123,
#     'spell4Casts': 13,
#     'subteamPlacement': 0,
#     'summoner1Casts': 13,
#     'summoner1Id': 6,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': 'eZFkRa_HSBOsBUUjCD9BzHIpr9IqCTOU4hxupO4Ib-j2Zho',
#     'summonerLevel': 174,
#     'summonerName': 'NightRaidRin',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 33,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 2,
#     'totalDamageDealt': 72340,
#     'totalDamageDealtToChampions': 11957,
#     'totalDamageShieldedOnTeammates': 2996,
#     'totalDamageTaken': 23170,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1146,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 60,
#     'totalTimeCCDealt': 215,
#     'totalTimeSpentDead': 211,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1780,
#     'trueDamageDealtToChampions': 672,
#     'trueDamageTaken': 2667,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 1,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 1,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 11,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'champExperience': 22406,
#     'champLevel': 20,
#     'championId': 76,
#     'championName': 'Nidalee',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 15631,
#     'damageDealtToObjectives': 31205,
#     'damageDealtToTurrets': 15631,
#     'damageSelfMitigated': 11489,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 14873,
#     'goldSpent': 13900,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 3,
#     'inhibitorTakedowns': 3,
#     'inhibitorsLost': 0,
#     'item0': 4646,
#     'item1': 3020,
#     'item2': 4645,
#     'item3': 3089,
#     'item4': 3100,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 10,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 356,
#     'magicDamageDealt': 68600,
#     'magicDamageDealtToChampions': 26680,
#     'magicDamageTaken': 18402,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 2,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 904, 'var2': 18, 'var3': 0},
#         {'perk': 8143, 'var1': 504, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 320, 'var2': 4, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8210, 'var1': 1, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 1, 'var2': 10, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 6171,
#     'physicalDamageDealtToChampions': 868,
#     'physicalDamageTaken': 7514,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5451,
#     'pushPings': 0,
#     'puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#     'quadraKills': 0,
#     'riotIdGameName': 'SilouxV2',
#     'riotIdTagline': 'NA1',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 216,
#     'spell2Casts': 52,
#     'spell3Casts': 109,
#     'spell4Casts': 57,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 6,
#     'summonerId': 'rFZda_meq1oprRAGtywvV4x05Udlte6zfZBF2MLPvGzPvHLo',
#     'summonerLevel': 34,
#     'summonerName': 'SilouxV2',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 2,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 76193,
#     'totalDamageDealtToChampions': 27977,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 27616,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 13005,
#     'totalHealsOnTeammates': 4219,
#     'totalMinionsKilled': 27,
#     'totalTimeCCDealt': 17,
#     'totalTimeSpentDead': 306,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 1421,
#     'trueDamageDealtToChampions': 429,
#     'trueDamageTaken': 1698,
#     'turretKills': 4,
#     'turretTakedowns': 7,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 19,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 12,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 10,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'champExperience': 26299,
#     'champLevel': 22,
#     'championId': 64,
#     'championName': 'LeeSin',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 8,
#     'damageDealtToBuildings': 9953,
#     'damageDealtToObjectives': 54794,
#     'damageDealtToTurrets': 9953,
#     'damageSelfMitigated': 55686,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 5,
#     'doubleKills': 0,
#     'dragonKills': 2,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 1,
#     'goldEarned': 21052,
#     'goldSpent': 21025,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 6692,
#     'item1': 3053,
#     'item2': 3074,
#     'item3': 3111,
#     'item4': 6610,
#     'item5': 3071,
#     'item6': 3340,
#     'itemsPurchased': 31,
#     'killingSprees': 2,
#     'kills': 15,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 396,
#     'largestKillingSpree': 12,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1042,
#     'magicDamageDealt': 53515,
#     'magicDamageDealtToChampions': 8664,
#     'magicDamageTaken': 15558,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 72,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 11,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 1495, 'var2': 0, 'var3': 0},
#         {'perk': 8143, 'var1': 1740, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 1234, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 2396, 'var2': 500, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 175940,
#     'physicalDamageDealtToChampions': 35561,
#     'physicalDamageTaken': 19511,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4659,
#     'pushPings': 0,
#     'puuid': 'pOM6Z9HBZaC9_BDtwTEIXJlUOFu7LxlPMwSFvUIUrCrP8YBBQoUcCh77yGTpj7oAK2tvJ73PmiK1Og',
#     'quadraKills': 0,
#     'riotIdGameName': 'UyuMilk',
#     'riotIdTagline': '143',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 330,
#     'spell2Casts': 326,
#     'spell3Casts': 189,
#     'spell4Casts': 19,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 9,
#     'summoner2Id': 1,
#     'summonerId': 'mry49Vj-a1B3tWj92gbXhL5dAl0CiZhw_4DOVlDDgeaSmj0',
#     'summonerLevel': 344,
#     'summonerName': 'UyuMilk',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 43,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 30,
#     'totalDamageDealt': 232156,
#     'totalDamageDealtToChampions': 44761,
#     'totalDamageShieldedOnTeammates': 826,
#     'totalDamageTaken': 37715,
#     'totalEnemyJungleMinionsKilled': 12,
#     'totalHeal': 19363,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 85,
#     'totalTimeCCDealt': 382,
#     'totalTimeSpentDead': 92,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2700,
#     'trueDamageDealtToChampions': 535,
#     'trueDamageTaken': 2646,
#     'turretKills': 3,
#     'turretTakedowns': 3,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 35,
#     'visionWardsBoughtInGame': 5,
#     'wardsKilled': 0,
#     'wardsPlaced': 22,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 3,
#     'assists': 4,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'champExperience': 30810,
#     'champLevel': 24,
#     'championId': 86,
#     'championName': 'Garen',
#     'championTransform': 0,
#     'commandPings': 3,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 3695,
#     'damageDealtToObjectives': 12020,
#     'damageDealtToTurrets': 3695,
#     'damageSelfMitigated': 455720,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 3,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 2,
#     'goldEarned': 19665,
#     'goldSpent': 19970,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6610,
#     'item1': 6665,
#     'item2': 3065,
#     'item3': 2502,
#     'item4': 3033,
#     'item5': 3084,
#     'item6': 3340,
#     'itemsPurchased': 28,
#     'killingSprees': 5,
#     'kills': 14,
#     'lane': 'TOP',
#     'largestCriticalStrike': 526,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 283,
#     'magicDamageDealt': 31326,
#     'magicDamageDealtToChampions': 27262,
#     'magicDamageTaken': 62989,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 6,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 11287, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 2590, 'var2': 360, 'var3': 0},
#         {'perk': 9105, 'var1': 7, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 2830, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8429, 'var1': 74, 'var2': 19, 'var3': 14},
#         {'perk': 8451, 'var1': 410, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 195894,
#     'physicalDamageDealtToChampions': 83484,
#     'physicalDamageTaken': 50801,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6438,
#     'pushPings': 0,
#     'puuid': 'uttiPcXHs8lm5VUjrlX91lrBRcXCIBUuGwb1_QkYyLecBcWaAkNXCvZiO0wg3UtdMyhSC5rRvj5Hzw',
#     'quadraKills': 0,
#     'riotIdGameName': '419X',
#     'riotIdTagline': 'NA1',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 202,
#     'spell2Casts': 107,
#     'spell3Casts': 165,
#     'spell4Casts': 20,
#     'subteamPlacement': 0,
#     'summoner1Casts': 12,
#     'summoner1Id': 4,
#     'summoner2Casts': 16,
#     'summoner2Id': 14,
#     'summonerId': 'dzErti_AwFgDVhXL2YEQ9LGUS9RDGmEPLBbF2IlZ-AJA',
#     'summonerLevel': 181,
#     'summonerName': '419X',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 110,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 249638,
#     'totalDamageDealtToChampions': 132106,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 135122,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 85181,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 155,
#     'totalTimeCCDealt': 244,
#     'totalTimeSpentDead': 273,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 22418,
#     'trueDamageDealtToChampions': 21359,
#     'trueDamageTaken': 21331,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 14,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 8,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 7,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'champExperience': 22802,
#     'champLevel': 20,
#     'championId': 112,
#     'championName': 'Viktor',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 334,
#     'damageDealtToObjectives': 2381,
#     'damageDealtToTurrets': 334,
#     'damageSelfMitigated': 23999,
#     'dangerPings': 0,
#     'deaths': 10,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13712,
#     'goldSpent': 13250,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 3157,
#     'item1': 3135,
#     'item2': 3158,
#     'item3': 4645,
#     'item4': 6655,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 21,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 251,
#     'magicDamageDealt': 94626,
#     'magicDamageDealtToChampions': 23813,
#     'magicDamageTaken': 16256,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 1494, 'var2': 0, 'var3': 0},
#         {'perk': 8224, 'var1': 997, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 1, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 600, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 4, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 2128,
#     'physicalDamageDealtToChampions': 651,
#     'physicalDamageTaken': 14825,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5083,
#     'pushPings': 0,
#     'puuid': '7zgo_t1-cCqlmm7H8No9RDE86asakBNQZbmJgxo5_IwcJRjlWySn2g8KTxIn3QxjWmLuv0jnKXEd6A',
#     'quadraKills': 0,
#     'riotIdGameName': 'Shy',
#     'riotIdTagline': 'CHS',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 74,
#     'spell2Casts': 70,
#     'spell3Casts': 150,
#     'spell4Casts': 39,
#     'subteamPlacement': 0,
#     'summoner1Casts': 1,
#     'summoner1Id': 7,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'zEgsNtSun6mrpnByIPD5-1H2NLzq_gpDeNtlrBx8gJy7rrE',
#     'summonerLevel': 276,
#     'summonerName': 'Malzahar',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 27,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 2,
#     'totalDamageDealt': 99140,
#     'totalDamageDealtToChampions': 24465,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 34337,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 724,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 98,
#     'totalTimeCCDealt': 281,
#     'totalTimeSpentDead': 286,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2385,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 3255,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 8,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 5,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 10,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'champExperience': 28600,
#     'champLevel': 23,
#     'championId': 875,
#     'championName': 'Sett',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 7261,
#     'damageDealtToObjectives': 7261,
#     'damageDealtToTurrets': 7261,
#     'damageSelfMitigated': 76771,
#     'dangerPings': 0,
#     'deaths': 12,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 16696,
#     'goldSpent': 16200,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 6610,
#     'item1': 3748,
#     'item2': 3161,
#     'item3': 1001,
#     'item4': 3153,
#     'item5': 6333,
#     'item6': 3340,
#     'itemsPurchased': 25,
#     'killingSprees': 2,
#     'kills': 5,
#     'lane': 'TOP',
#     'largestCriticalStrike': 643,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 219,
#     'magicDamageDealt': 1869,
#     'magicDamageDealtToChampions': 199,
#     'magicDamageTaken': 19322,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 7,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 2672, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 1589, 'var2': 300, 'var3': 0},
#         {'perk': 9104, 'var1': 13, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 2021, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8444, 'var1': 1666, 'var2': 0, 'var3': 0},
#         {'perk': 8242, 'var1': 140, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 127528,
#     'physicalDamageDealtToChampions': 50478,
#     'physicalDamageTaken': 43138,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5031,
#     'pushPings': 2,
#     'puuid': 'lw5YPLiIr6b7RId76DLk1NPTH4vCAcS5MMnYp28Wf1eslUL1Ko5nK5OTd-tqbd_wN9B3BtbWGNYL9w',
#     'quadraKills': 0,
#     'riotIdGameName': 'COCOnutAZY',
#     'riotIdTagline': 'NA1',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 79,
#     'spell2Casts': 34,
#     'spell3Casts': 67,
#     'spell4Casts': 16,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 6,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': 'wRXVeLYiuc3BhAZljBMpMDGpreVJ_5sQ1tP1ZAaDu0kWBX2c5ccdcOCnrQ',
#     'summonerLevel': 93,
#     'summonerName': 'COCOnutAZY',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 41,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 140380,
#     'totalDamageDealtToChampions': 61514,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 69783,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 16505,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 95,
#     'totalTimeCCDealt': 131,
#     'totalTimeSpentDead': 309,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 10982,
#     'trueDamageDealtToChampions': 10836,
#     'trueDamageTaken': 7322,
#     'turretKills': 2,
#     'turretTakedowns': 2,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 11,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'champExperience': 30918,
#     'champLevel': 24,
#     'championId': 518,
#     'championName': 'Neeko',
#     'championTransform': 0,
#     'commandPings': 2,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 2935,
#     'damageDealtToObjectives': 4177,
#     'damageDealtToTurrets': 2935,
#     'damageSelfMitigated': 29761,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 18642,
#     'goldSpent': 16700,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 3040,
#     'item1': 3020,
#     'item2': 4646,
#     'item3': 4645,
#     'item4': 3135,
#     'item5': 3089,
#     'item6': 3340,
#     'itemsPurchased': 21,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 278,
#     'magicDamageDealt': 179654,
#     'magicDamageDealtToChampions': 40859,
#     'magicDamageTaken': 22064,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 1,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 8,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1252, 'var2': 24, 'var3': 0},
#         {'perk': 8139, 'var1': 2095, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 2, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 7100,
#     'physicalDamageDealtToChampions': 1789,
#     'physicalDamageTaken': 20890,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 1,
#     'pushPings': 0,
#     'puuid': 'gh7OaNbKLLDOF03ElMcXADzZzVewF7GjmfeqgHrIKdN9jkOl1W0rjweJEhGM7yloDoF2KjssT7F2nw',
#     'quadraKills': 0,
#     'riotIdGameName': 'Big bad dust',
#     'riotIdTagline': 'NA1',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 145,
#     'spell2Casts': 128,
#     'spell3Casts': 170,
#     'spell4Casts': 19,
#     'subteamPlacement': 0,
#     'summoner1Casts': 12,
#     'summoner1Id': 4,
#     'summoner2Casts': 10,
#     'summoner2Id': 6,
#     'summonerId': 'rq54BRg2_BFevHMZKBTlwNUmR-b5GM710Vn0XelnqB4MY-Bssfavw5fMVA',
#     'summonerLevel': 20,
#     'summonerName': 'Big bad dust',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 78,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 1,
#     'totalDamageDealt': 186754,
#     'totalDamageDealtToChampions': 42648,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 44921,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3176,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 124,
#     'totalTimeCCDealt': 198,
#     'totalTimeSpentDead': 229,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 1966,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 20,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 1,
#     'wardsPlaced': 13,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 14,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'champExperience': 28633,
#     'champLevel': 23,
#     'championId': 99,
#     'championName': 'Lux',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 833,
#     'damageDealtToObjectives': 898,
#     'damageDealtToTurrets': 833,
#     'damageSelfMitigated': 19488,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 16366,
#     'goldSpent': 15900,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 4646,
#     'item1': 3020,
#     'item2': 4645,
#     'item3': 4628,
#     'item4': 6653,
#     'item5': 3135,
#     'item6': 3340,
#     'itemsPurchased': 17,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 380,
#     'magicDamageDealt': 115702,
#     'magicDamageDealtToChampions': 35845,
#     'magicDamageTaken': 11108,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 2,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1114, 'var2': 25, 'var3': 0},
#         {'perk': 8126, 'var1': 2080, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8224, 'var1': 622, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 5928,
#     'physicalDamageDealtToChampions': 1635,
#     'physicalDamageTaken': 11208,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5530,
#     'pushPings': 0,
#     'puuid': 'RXzD_9dKc-fJr5xC6ykG8Bv5ocPMxKYyXDjb_Bzr2rDyfPlanOWldeQANK0oqUKpH9k15cOJiwU9Jg',
#     'quadraKills': 0,
#     'riotIdGameName': 'Beijing ER',
#     'riotIdTagline': 'NA1',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 134,
#     'spell2Casts': 68,
#     'spell3Casts': 233,
#     'spell4Casts': 42,
#     'subteamPlacement': 0,
#     'summoner1Casts': 15,
#     'summoner1Id': 6,
#     'summoner2Casts': 9,
#     'summoner2Id': 4,
#     'summonerId': 'lY4pcod8eRcK6eiP4_bIhuKc9fVAWEgEy8lLasDO_s-zRrM',
#     'summonerLevel': 251,
#     'summonerName': 'Beijing ER',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 87,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 2,
#     'totalDamageDealt': 140372,
#     'totalDamageDealtToChampions': 39028,
#     'totalDamageShieldedOnTeammates': 11231,
#     'totalDamageTaken': 23957,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 623,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 96,
#     'totalTimeCCDealt': 231,
#     'totalTimeSpentDead': 208,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 18742,
#     'trueDamageDealtToChampions': 1547,
#     'trueDamageTaken': 1640,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 9,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 1,
#     'wardsPlaced': 5,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 8,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'champExperience': 30150,
#     'champLevel': 24,
#     'championId': 31,
#     'championName': 'Chogath',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 9559,
#     'damageDealtToObjectives': 9559,
#     'damageDealtToTurrets': 9559,
#     'damageSelfMitigated': 119099,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 20409,
#     'goldSpent': 19000,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 3084,
#     'item1': 3065,
#     'item2': 3068,
#     'item3': 2502,
#     'item4': 3075,
#     'item5': 3748,
#     'item6': 3340,
#     'itemsPurchased': 28,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 30,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 228,
#     'magicDamageDealt': 161734,
#     'magicDamageDealtToChampions': 35835,
#     'magicDamageTaken': 39425,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5001, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8437, 'var1': 4359, 'var2': 4960, 'var3': 0},
#         {'perk': 8446, 'var1': 4712, 'var2': 0, 'var3': 0},
#         {'perk': 8429, 'var1': 74, 'var2': 18, 'var3': 12},
#         {'perk': 8451, 'var1': 520, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9105, 'var1': 7, 'var2': 50, 'var3': 0},
#         {'perk': 9111, 'var1': 2576, 'var2': 320, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 34963,
#     'physicalDamageDealtToChampions': 10871,
#     'physicalDamageTaken': 45317,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 29,
#     'pushPings': 0,
#     'puuid': 'QiQ6U5WHvO85EFHjXZCfxmPrUmdSS6shJH_Ta0z_PhXHtFabitEjAYYYafYCM1Q7-SgNKBdUANztYg',
#     'quadraKills': 0,
#     'riotIdGameName': 'NickleW',
#     'riotIdTagline': 'NA1',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 155,
#     'spell2Casts': 76,
#     'spell3Casts': 79,
#     'spell4Casts': 20,
#     'subteamPlacement': 0,
#     'summoner1Casts': 11,
#     'summoner1Id': 4,
#     'summoner2Casts': 13,
#     'summoner2Id': 14,
#     'summonerId': 'XazOrOWVt8xYp1ghgxMNEHR3Rx-uAe24erkEyXjpG2Ak-UDqebJbFYJ4Kg',
#     'summonerLevel': 108,
#     'summonerName': 'NickleW',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 93,
#     'timePlayed': 1398,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 222359,
#     'totalDamageDealtToChampions': 56706,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 94957,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 21192,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 170,
#     'totalTimeCCDealt': 690,
#     'totalTimeSpentDead': 233,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 25661,
#     'trueDamageDealtToChampions': 9999,
#     'trueDamageTaken': 10214,
#     'turretKills': 2,
#     'turretTakedowns': 2,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False}],
#   'platformId': 'NA1',
#   'queueId': 1900,
#   'teams': [{'bans': [{'championId': 24, 'pickTurn': 1},
#      {'championId': 136, 'pickTurn': 2},
#      {'championId': 29, 'pickTurn': 3},
#      {'championId': 67, 'pickTurn': 4},
#      {'championId': 105, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': False, 'kills': 45},
#      'dragon': {'first': True, 'kills': 4},
#      'horde': {'first': True, 'kills': 3},
#      'inhibitor': {'first': True, 'kills': 4},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 11}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 523, 'pickTurn': 6},
#      {'championId': 114, 'pickTurn': 7},
#      {'championId': 11, 'pickTurn': 8},
#      {'championId': 67, 'pickTurn': 9},
#      {'championId': 902, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 32},
#      'dragon': {'first': False, 'kills': 0},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 5}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
match_meta["info"]["gameMode"]
# Out:
# 'URF'

# %% [markdown]
# :)
#
# ### Time for timeline

# %%
timeline = lol_watcher.match.timeline_by_match(my_region, match_ids[0])
timeline
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4915859238',
#   'participants': ['zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#    'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#    'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#    'pOM6Z9HBZaC9_BDtwTEIXJlUOFu7LxlPMwSFvUIUrCrP8YBBQoUcCh77yGTpj7oAK2tvJ73PmiK1Og',
#    'uttiPcXHs8lm5VUjrlX91lrBRcXCIBUuGwb1_QkYyLecBcWaAkNXCvZiO0wg3UtdMyhSC5rRvj5Hzw',
#    '7zgo_t1-cCqlmm7H8No9RDE86asakBNQZbmJgxo5_IwcJRjlWySn2g8KTxIn3QxjWmLuv0jnKXEd6A',
#    'lw5YPLiIr6b7RId76DLk1NPTH4vCAcS5MMnYp28Wf1eslUL1Ko5nK5OTd-tqbd_wN9B3BtbWGNYL9w',
#    'gh7OaNbKLLDOF03ElMcXADzZzVewF7GjmfeqgHrIKdN9jkOl1W0rjweJEhGM7yloDoF2KjssT7F2nw',
#    'RXzD_9dKc-fJr5xC6ykG8Bv5ocPMxKYyXDjb_Bzr2rDyfPlanOWldeQANK0oqUKpH9k15cOJiwU9Jg',
#    'QiQ6U5WHvO85EFHjXZCfxmPrUmdSS6shJH_Ta0z_PhXHtFabitEjAYYYafYCM1Q7-SgNKBdUANztYg']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'frameInterval': 60000,
#   'frames': [{'events': [{'realTimestamp': 1707374420291,
#       'timestamp': 0,
#       'type': 'PAUSE_END'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 570,
#        'healthMax': 570,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 37,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 200,
#        'powerMax': 200,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 554, 'y': 581},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 21,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 580,
#        'healthMax': 580,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 480,
#        'powerMax': 480,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 593, 'y': 464},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 610,
#        'healthMax': 610,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 295,
#        'powerMax': 295,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 557, 'y': 345},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 36,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 645,
#        'healthMax': 645,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 200,
#        'powerMax': 200,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 458, 'y': 271},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 690,
#        'healthMax': 690,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 335, 'y': 269},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 600,
#        'healthMax': 600,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 335,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 405,
#        'powerMax': 405,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 14500, 'y': 14511},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 33,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 670,
#        'healthMax': 670,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 28,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 335,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 14539, 'y': 14394},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 21,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 610,
#        'healthMax': 610,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 340,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 450,
#        'powerMax': 450,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 14503, 'y': 14275},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 21,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 580,
#        'healthMax': 580,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 330,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 480,
#        'powerMax': 480,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 14404, 'y': 14201},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 25,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 0,
#        'cooldownReduction': 0,
#        'health': 644,
#        'healthMax': 644,
#        'healthRegen': 0,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 345,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 270,
#        'powerMax': 270,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 500,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 0,
#        'totalDamageDoneToChampions': 0,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 14281, 'y': 14199},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 500,
#       'xp': 0}},
#     'timestamp': 0},
#    {'events': [{'levelUpType': 'NORMAL',
#       'participantId': 10,
#       'skillSlot': 1,
#       'timestamp': 2077,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 3,
#       'skillSlot': 1,
#       'timestamp': 3377,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 3070,
#       'participantId': 8,
#       'timestamp': 3443,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 8,
#       'skillSlot': 3,
#       'timestamp': 4109,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 6,
#       'skillSlot': 1,
#       'timestamp': 5075,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 1028,
#       'participantId': 10,
#       'timestamp': 6076,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 2,
#       'skillSlot': 1,
#       'timestamp': 6875,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 1052,
#       'participantId': 9,
#       'timestamp': 8444,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1036,
#       'participantId': 7,
#       'timestamp': 8778,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1052,
#       'participantId': 3,
#       'timestamp': 10314,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2022,
#       'participantId': 2,
#       'timestamp': 10381,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1056,
#       'participantId': 6,
#       'timestamp': 11082,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 11082,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 11082,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 2003,
#       'goldGain': 50,
#       'participantId': 6,
#       'timestamp': 12050,
#       'type': 'ITEM_UNDO'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 9,
#       'skillSlot': 1,
#       'timestamp': 12883,
#       'type': 'SKILL_LEVEL_UP'},
#      {'afterId': 0,
#       'beforeId': 2003,
#       'goldGain': 50,
#       'participantId': 6,
#       'timestamp': 13582,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 1036,
#       'participantId': 5,
#       'timestamp': 14749,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 1056,
#       'goldGain': 400,
#       'participantId': 6,
#       'timestamp': 15084,
#       'type': 'ITEM_UNDO'},
#      {'afterId': 0,
#       'beforeId': 1036,
#       'goldGain': 350,
#       'participantId': 5,
#       'timestamp': 15684,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 1056,
#       'participantId': 6,
#       'timestamp': 16817,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 16817,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 6,
#       'timestamp': 16817,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1028,
#       'participantId': 5,
#       'timestamp': 18916,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 2003,
#       'goldGain': 50,
#       'participantId': 6,
#       'timestamp': 19648,
#       'type': 'ITEM_UNDO'},
#      {'afterId': 0,
#       'beforeId': 2003,
#       'goldGain': 50,
#       'participantId': 6,
#       'timestamp': 19816,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 3340,
#       'participantId': 5,
#       'timestamp': 20115,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 5,
#       'timestamp': 20512,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2003,
#       'participantId': 5,
#       'timestamp': 20812,
#       'type': 'ITEM_PURCHASED'},
#      {'afterId': 0,
#       'beforeId': 1056,
#       'goldGain': 400,
#       'participantId': 6,
#       'timestamp': 21345,
#       'type': 'ITEM_UNDO'},
#      {'itemId': 1052,
#       'participantId': 6,
#       'timestamp': 23314,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1028,
#       'participantId': 1,
#       'timestamp': 23413,
#       'type': 'ITEM_PURCHASED'},
#      {'creatorId': 8,
#       'timestamp': 23480,
#       'type': 'WARD_PLACED',
#       'wardType': 'YELLOW_TRINKET'},
#      {'itemId': 3340,
#       'participantId': 1,
#       'timestamp': 24445,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 7,
#       'skillSlot': 3,
#       'timestamp': 25382,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 5,
#       'skillSlot': 1,
#       'timestamp': 28384,
#       'type': 'SKILL_LEVEL_UP'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 1,
#       'skillSlot': 1,
#       'timestamp': 29084,
#       'type': 'SKILL_LEVEL_UP'},
#      {'itemId': 1036,
#       'participantId': 4,
#       'timestamp': 32756,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 2031,
#       'participantId': 4,
#       'timestamp': 33556,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 3340,
#       'participantId': 4,
#       'timestamp': 34458,
#       'type': 'ITEM_PURCHASED'},
#      {'levelUpType': 'NORMAL',
#       'participantId': 4,
#       'skillSlot': 1,
#       'timestamp': 36629,
#       'type': 'SKILL_LEVEL_UP'},
#      {'assistingParticipantIds': [6, 7, 8, 9],
#       'bounty': 400,
#       'killStreakLength': 0,
#       'killerId': 10,
#       'position': {'x': 798, 'y': 10072},
#       'shutdownBounty': 0,
#       'timestamp': 39497,
#       'type': 'CHAMPION_KILL',
#       'victimDamageDealt': [{'basic': False,
#         'magicDamage': 0,
#         'name': 'Garen',
#         'participantId': 7,
#         'physicalDamage': 118,
#         'spellName': 'garenq',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimDamageReceived': [{'basic': False,
#         'magicDamage': 163,
#         'name': 'Chogath',
#         'participantId': 10,
#         'physicalDamage': 0,
#         'spellName': 'rupture',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 19,
#         'name': 'Chogath',
#         'participantId': 10,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Chogath',
#         'participantId': 10,
#         'physicalDamage': 45,
#         'spellName': 'chogathbasicattack2',
#         'spellSlot': 65,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Chogath',
#         'participantId': 10,
#         'physicalDamage': 0,
#         'spellName': 'summonerdot',
#         'spellSlot': 5,
#         'trueDamage': 56,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 33,
#         'spellName': 'luxbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 8,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 8,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 133,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': 'luxlightbinding',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 25,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': 'luxilluminationpassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Sett',
#         'participantId': 7,
#         'physicalDamage': 70,
#         'spellName': 'settpassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Sett',
#         'participantId': 7,
#         'physicalDamage': 65,
#         'spellName': 'sette',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Sett',
#         'participantId': 7,
#         'physicalDamage': 53,
#         'spellName': 'settbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 7,
#         'name': 'Neeko',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Neeko',
#         'participantId': 8,
#         'physicalDamage': 62,
#         'spellName': 'neekobasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 104,
#         'name': 'Viktor',
#         'participantId': 6,
#         'physicalDamage': 0,
#         'spellName': 'viktorpowertransfer',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 20,
#         'name': 'Viktor',
#         'participantId': 6,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimId': 5},
#      {'killType': 'KILL_FIRST_BLOOD',
#       'killerId': 10,
#       'position': {'x': 1599, 'y': 11640},
#       'timestamp': 39497,
#       'type': 'CHAMPION_SPECIAL_KILL'},
#      {'assistingParticipantIds': [8, 10],
#       'bounty': 300,
#       'killStreakLength': 0,
#       'killerId': 9,
#       'position': {'x': 1432, 'y': 10429},
#       'shutdownBounty': 0,
#       'timestamp': 44570,
#       'type': 'CHAMPION_KILL',
#       'victimDamageDealt': [{'basic': False,
#         'magicDamage': 9,
#         'name': 'Nidalee',
#         'participantId': 7,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 124,
#         'name': 'Nidalee',
#         'participantId': 7,
#         'physicalDamage': 0,
#         'spellName': 'javelintoss',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 183,
#         'name': 'Nidalee',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'javelintoss',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimDamageReceived': [{'basic': False,
#         'magicDamage': 177,
#         'name': 'Neeko',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'neekoe',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 10,
#         'name': 'Neeko',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Neeko',
#         'participantId': 8,
#         'physicalDamage': 36,
#         'spellName': 'neekobasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 227,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': 'luxlightbinding',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 9,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 184,
#         'name': 'Chogath',
#         'participantId': 10,
#         'physicalDamage': 0,
#         'spellName': 'rupture',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimId': 3},
#      {'assistingParticipantIds': [1, 2, 3],
#       'bounty': 300,
#       'killStreakLength': 0,
#       'killerId': 4,
#       'position': {'x': 2302, 'y': 12263},
#       'shutdownBounty': 0,
#       'timestamp': 46204,
#       'type': 'CHAMPION_KILL',
#       'victimDamageDealt': [{'basic': False,
#         'magicDamage': 49,
#         'name': 'Neeko',
#         'participantId': 1,
#         'physicalDamage': 0,
#         'spellName': 'neekoe',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Neeko',
#         'participantId': 1,
#         'physicalDamage': 35,
#         'spellName': 'neekobasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 58,
#         'name': 'Neeko',
#         'participantId': 2,
#         'physicalDamage': 0,
#         'spellName': 'neekoe',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Neeko',
#         'participantId': 2,
#         'physicalDamage': 39,
#         'spellName': 'neekobasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 58,
#         'name': 'Neeko',
#         'participantId': 4,
#         'physicalDamage': 0,
#         'spellName': 'neekoe',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimDamageReceived': [{'basic': False,
#         'magicDamage': 66,
#         'name': 'Lux',
#         'participantId': 2,
#         'physicalDamage': 0,
#         'spellName': 'luxlightbinding',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 25,
#         'name': 'Lux',
#         'participantId': 2,
#         'physicalDamage': 0,
#         'spellName': 'luxilluminationpassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Lux',
#         'participantId': 2,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 9,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Lux',
#         'participantId': 2,
#         'physicalDamage': 42,
#         'spellName': 'luxbasicattack2',
#         'spellSlot': 65,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 142,
#         'name': 'Akali',
#         'participantId': 1,
#         'physicalDamage': 0,
#         'spellName': 'akaliq',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 183,
#         'name': 'Nidalee',
#         'participantId': 3,
#         'physicalDamage': 0,
#         'spellName': 'javelintoss',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'LeeSin',
#         'participantId': 4,
#         'physicalDamage': 64,
#         'spellName': 'blindmonkqone',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'LeeSin',
#         'participantId': 4,
#         'physicalDamage': 120,
#         'spellName': 'blindmonkqtwo',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'LeeSin',
#         'participantId': 4,
#         'physicalDamage': 30,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'LeeSin',
#         'participantId': 4,
#         'physicalDamage': 78,
#         'spellName': 'leesinbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimId': 8},
#      {'assistingParticipantIds': [6, 8, 9, 10],
#       'bounty': 300,
#       'killStreakLength': 0,
#       'killerId': 7,
#       'position': {'x': 1796, 'y': 12052},
#       'shutdownBounty': 0,
#       'timestamp': 49405,
#       'type': 'CHAMPION_KILL',
#       'victimDamageDealt': [{'basic': False,
#         'magicDamage': 0,
#         'name': 'LeeSin',
#         'participantId': 9,
#         'physicalDamage': 66,
#         'spellName': 'blindmonkqone',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'LeeSin',
#         'participantId': 9,
#         'physicalDamage': 73,
#         'spellName': 'blindmonkqtwo',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimDamageReceived': [{'basic': False,
#         'magicDamage': 58,
#         'name': 'Neeko',
#         'participantId': 8,
#         'physicalDamage': 0,
#         'spellName': 'neekoe',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 74,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': 'luxlightbinding',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 29,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': 'luxilluminationpassive',
#         'spellSlot': 63,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 13,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 9,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Lux',
#         'participantId': 9,
#         'physicalDamage': 75,
#         'spellName': 'luxbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 181,
#         'name': 'Chogath',
#         'participantId': 10,
#         'physicalDamage': 0,
#         'spellName': 'rupture',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 116,
#         'name': 'Viktor',
#         'participantId': 6,
#         'physicalDamage': 0,
#         'spellName': 'viktorpowertransfer',
#         'spellSlot': 0,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 22,
#         'name': 'Viktor',
#         'participantId': 6,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': False,
#         'magicDamage': 0,
#         'name': 'Sett',
#         'participantId': 7,
#         'physicalDamage': 81,
#         'spellName': 'sette',
#         'spellSlot': 2,
#         'trueDamage': 0,
#         'type': 'OTHER'},
#        {'basic': True,
#         'magicDamage': 0,
#         'name': 'Sett',
#         'participantId': 7,
#         'physicalDamage': 66,
#         'spellName': 'settbasicattack',
#         'spellSlot': 64,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimId': 4},
#      {'itemId': 1001,
#       'participantId': 4,
#       'timestamp': 53873,
#       'type': 'ITEM_PURCHASED'},
#      {'itemId': 1001,
#       'participantId': 8,
#       'timestamp': 56309,
#       'type': 'ITEM_PURCHASED'}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 72,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 31,
#        'cooldownReduction': 0,
#        'health': 335,
#        'healthMax': 730,
#        'healthRegen': 36,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 37,
#        'movementSpeed': 405,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 200,
#        'powerMax': 200,
#        'powerRegen': 100,
#        'spellVamp': 0},
#       'currentGold': 145,
#       'damageStats': {'magicDamageDone': 973,
#        'magicDamageDoneToChampions': 973,
#        'magicDamageTaken': 424,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 71,
#        'totalDamageDone': 973,
#        'totalDamageDoneToChampions': 973,
#        'totalDamageTaken': 505,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 8},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 1,
#       'position': {'x': 998, 'y': 10221},
#       'timeEnemySpentControlled': 6066,
#       'totalGold': 545,
#       'xp': 8},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 20,
#        'armor': 21,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 54,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 279,
#        'healthMax': 590,
#        'healthRegen': 11,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 390,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 480,
#        'powerMax': 480,
#        'powerRegen': 14,
#        'spellVamp': 0},
#       'currentGold': 275,
#       'damageStats': {'magicDamageDone': 249,
#        'magicDamageDoneToChampions': 249,
#        'magicDamageTaken': 304,
#        'physicalDamageDone': 77,
#        'physicalDamageDoneToChampions': 77,
#        'physicalDamageTaken': 39,
#        'totalDamageDone': 344,
#        'totalDamageDoneToChampions': 344,
#        'totalDamageTaken': 344,
#        'trueDamageDone': 18,
#        'trueDamageDoneToChampions': 18,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 2,
#       'position': {'x': 785, 'y': 9489},
#       'timeEnemySpentControlled': 4439,
#       'totalGold': 525,
#       'xp': 8},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 31,
#        'armor': 32,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 58,
#        'attackSpeed': 120,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 620,
#        'healthMax': 620,
#        'healthRegen': 12,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 400,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 295,
#        'powerMax': 295,
#        'powerRegen': 12,
#        'spellVamp': 0},
#       'currentGold': 175,
#       'damageStats': {'magicDamageDone': 317,
#        'magicDamageDoneToChampions': 317,
#        'magicDamageTaken': 598,
#        'physicalDamageDone': 0,
#        'physicalDamageDoneToChampions': 0,
#        'physicalDamageTaken': 36,
#        'totalDamageDone': 317,
#        'totalDamageDoneToChampions': 317,
#        'totalDamageTaken': 644,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 9},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 3,
#       'position': {'x': 1289, 'y': 10459},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 575,
#       'xp': 8},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 36,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 82,
#        'attackSpeed': 175,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 655,
#        'healthMax': 655,
#        'healthRegen': 15,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 427,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 200,
#        'powerMax': 200,
#        'powerRegen': 100,
#        'spellVamp': 0},
#       'currentGold': 20,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 496,
#        'physicalDamageDone': 434,
#        'physicalDamageDoneToChampions': 434,
#        'physicalDamageTaken': 223,
#        'totalDamageDone': 434,
#        'totalDamageDoneToChampions': 434,
#        'totalDamageTaken': 729,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 9},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 4,
#       'position': {'x': 1891, 'y': 8758},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 820,
#       'xp': 8},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 88,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 30,
#        'cooldownReduction': 0,
#        'health': 186,
#        'healthMax': 850,
#        'healthRegen': 16,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 190,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 0,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 775,
#        'physicalDamageDone': 453,
#        'physicalDamageDoneToChampions': 453,
#        'physicalDamageTaken': 703,
#        'totalDamageDone': 509,
#        'totalDamageDoneToChampions': 509,
#        'totalDamageTaken': 1552,
#        'trueDamageDone': 56,
#        'trueDamageDoneToChampions': 56,
#        'trueDamageTaken': 73},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 5,
#       'position': {'x': 1694, 'y': 12586},
#       'timeEnemySpentControlled': 2469,
#       'totalGold': 500,
#       'xp': 0},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 29,
#        'armor': 23,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 53,
#        'attackSpeed': 120,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 610,
#        'healthMax': 610,
#        'healthRegen': 16,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 395,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 405,
#        'powerMax': 405,
#        'powerRegen': 16,
#        'spellVamp': 0},
#       'currentGold': 143,
#       'damageStats': {'magicDamageDone': 655,
#        'magicDamageDoneToChampions': 655,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 36,
#        'physicalDamageDoneToChampions': 36,
#        'physicalDamageTaken': 0,
#        'totalDamageDone': 691,
#        'totalDamageDoneToChampions': 691,
#        'totalDamageTaken': 0,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 6,
#       'position': {'x': 2422, 'y': 12533},
#       'timeEnemySpentControlled': 0,
#       'totalGold': 543,
#       'xp': 22},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 35,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 86,
#        'attackSpeed': 124,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 130,
#        'healthMax': 680,
#        'healthRegen': 63,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 400,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 335,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 515,
#       'damageStats': {'magicDamageDone': 0,
#        'magicDamageDoneToChampions': 0,
#        'magicDamageTaken': 421,
#        'physicalDamageDone': 677,
#        'physicalDamageDoneToChampions': 677,
#        'physicalDamageTaken': 287,
#        'totalDamageDone': 677,
#        'totalDamageDoneToChampions': 677,
#        'totalDamageTaken': 718,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 8},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 7,
#       'position': {'x': 1688, 'y': 12781},
#       'timeEnemySpentControlled': 2837,
#       'totalGold': 865,
#       'xp': 14},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 15,
#        'armor': 21,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 48,
#        'attackSpeed': 120,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 712,
#        'healthMax': 712,
#        'healthRegen': 15,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 555,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 714,
#        'powerMax': 714,
#        'powerRegen': 14,
#        'spellVamp': 0},
#       'currentGold': 91,
#       'damageStats': {'magicDamageDone': 361,
#        'magicDamageDoneToChampions': 361,
#        'magicDamageTaken': 417,
#        'physicalDamageDone': 173,
#        'physicalDamageDoneToChampions': 173,
#        'physicalDamageTaken': 336,
#        'totalDamageDone': 534,
#        'totalDamageDoneToChampions': 534,
#        'totalDamageTaken': 763,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 9},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 8,
#       'position': {'x': 13053, 'y': 9251},
#       'timeEnemySpentControlled': 5408,
#       'totalGold': 791,
#       'xp': 22},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 44,
#        'armor': 21,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 54,
#        'attackSpeed': 100,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 328,
#        'healthMax': 590,
#        'healthRegen': 11,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 30,
#        'movementSpeed': 390,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 480,
#        'powerMax': 480,
#        'powerRegen': 14,
#        'spellVamp': 0},
#       'currentGold': 443,
#       'damageStats': {'magicDamageDone': 576,
#        'magicDamageDoneToChampions': 576,
#        'magicDamageTaken': 0,
#        'physicalDamageDone': 142,
#        'physicalDamageDoneToChampions': 142,
#        'physicalDamageTaken': 275,
#        'totalDamageDone': 763,
#        'totalDamageDoneToChampions': 763,
#        'totalDamageTaken': 275,
#        'trueDamageDone': 44,
#        'trueDamageDoneToChampions': 44,
#        'trueDamageTaken': 0},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 9,
#       'position': {'x': 2335, 'y': 13385},
#       'timeEnemySpentControlled': 9350,
#       'totalGold': 843,
#       'xp': 22},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 38,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 69,
#        'attackSpeed': 115,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 34,
#        'cooldownReduction': 0,
#        'health': 122,
#        'healthMax': 829,
#        'healthRegen': 10,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 32,
#        'movementSpeed': 405,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 270,
#        'powerMax': 270,
#        'powerRegen': 14,
#        'spellVamp': 0},
#       'currentGold': 616,
#       'damageStats': {'magicDamageDone': 1007,
#        'magicDamageDoneToChampions': 1007,
#        'magicDamageTaken': 700,
#        'physicalDamageDone': 45,
#        'physicalDamageDoneToChampions': 45,
#        'physicalDamageTaken': 65,
#        'totalDamageDone': 1108,
#        'totalDamageDoneToChampions': 1108,
#        'totalDamageTaken': 821,
#        'trueDamageDone': 56,
#        'trueDamageDoneToChampions': 56,
#        'trueDamageTaken': 56},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 1,
#       'minionsKilled': 0,
#       'participantId': 10,
#       'position': {'x': 2311, 'y': 13473},
#       'timeEnemySpentControlled': 38927,
#       'totalGold': 1016,
#       'xp': 22}},
#     'timestamp': 60018},
#    {'events': [{'assistingParticipantIds': [6, 9, 10],
#       'bounty': 274,
#       'killStreakLength': 1,
#       'killerId': 7,
#       'position': {'x': 1548, 'y': 12596},
# ...
#         'participantId': 9,
#         'physicalDamage': 0,
#         'spellName': '',
#         'spellSlot': -1,
#         'trueDamage': 0,
#         'type': 'OTHER'}],
#       'victimId': 6},
#      {'level': 20,
#       'participantId': 3,
#       'timestamp': 1391373,
#       'type': 'LEVEL_UP'},
#      {'gameId': 4915859238,
#       'realTimestamp': 1707375818688,
#       'timestamp': 1398319,
#       'type': 'GAME_END',
#       'winningTeam': 100}],
#     'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 280,
#        'armor': 199,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 140,
#        'attackSpeed': 214,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 49,
#        'cooldownReduction': 0,
#        'health': 5614,
#        'healthMax': 6658,
#        'healthRegen': 289,
#        'lifesteal': 0,
#        'magicPen': 18,
#        'magicPenPercent': 0,
#        'magicResist': 184,
#        'movementSpeed': 545,
#        'omnivamp': 10,
#        'physicalVamp': 0,
#        'power': 300,
#        'powerMax': 300,
#        'powerRegen': 100,
#        'spellVamp': 0},
#       'currentGold': 1947,
#       'damageStats': {'magicDamageDone': 171961,
#        'magicDamageDoneToChampions': 34841,
#        'magicDamageTaken': 24766,
#        'physicalDamageDone': 8399,
#        'physicalDamageDoneToChampions': 3198,
#        'physicalDamageTaken': 17701,
#        'totalDamageDone': 186164,
#        'totalDamageDoneToChampions': 39442,
#        'totalDamageTaken': 43506,
#        'trueDamageDone': 5804,
#        'trueDamageDoneToChampions': 1402,
#        'trueDamageTaken': 1038},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 50,
#       'level': 23,
#       'minionsKilled': 85,
#       'participantId': 1,
#       'position': {'x': 13195, 'y': 12780},
#       'timeEnemySpentControlled': 123883,
#       'totalGold': 17847,
#       'xp': 29542},
#      '2': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 448,
#        'armor': 136,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 123,
#        'attackSpeed': 226,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 31,
#        'cooldownReduction': 0,
#        'health': 3083,
#        'healthMax': 3083,
#        'healthRegen': 34,
#        'lifesteal': 0,
#        'magicPen': 40,
#        'magicPenPercent': 0,
#        'magicResist': 60,
#        'movementSpeed': 567,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1574,
#        'powerMax': 1574,
#        'powerRegen': 47,
#        'spellVamp': 0},
#       'currentGold': 382,
#       'damageStats': {'magicDamageDone': 62877,
#        'magicDamageDoneToChampions': 10728,
#        'magicDamageTaken': 16395,
#        'physicalDamageDone': 7682,
#        'physicalDamageDoneToChampions': 556,
#        'physicalDamageTaken': 4106,
#        'totalDamageDone': 72340,
#        'totalDamageDoneToChampions': 11957,
#        'totalDamageTaken': 23170,
#        'trueDamageDone': 1780,
#        'trueDamageDoneToChampions': 672,
#        'trueDamageTaken': 2667},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 10,
#       'level': 21,
#       'minionsKilled': 60,
#       'participantId': 2,
#       'position': {'x': 8284, 'y': 8196},
#       'timeEnemySpentControlled': 215157,
#       'totalGold': 13182,
#       'xp': 24699},
#      '3': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 666,
#        'armor': 136,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 126,
#        'attackSpeed': 246,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 31,
#        'cooldownReduction': 0,
#        'health': 2953,
#        'healthMax': 2953,
#        'healthRegen': 35,
#        'lifesteal': 0,
#        'magicPen': 40,
#        'magicPenPercent': 0,
#        'magicResist': 61,
#        'movementSpeed': 570,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1179,
#        'powerMax': 1179,
#        'powerRegen': 43,
#        'spellVamp': 0},
#       'currentGold': 973,
#       'damageStats': {'magicDamageDone': 68600,
#        'magicDamageDoneToChampions': 26680,
#        'magicDamageTaken': 18402,
#        'physicalDamageDone': 6171,
#        'physicalDamageDoneToChampions': 868,
#        'physicalDamageTaken': 7514,
#        'totalDamageDone': 76193,
#        'totalDamageDoneToChampions': 27977,
#        'totalDamageTaken': 27616,
#        'trueDamageDone': 1421,
#        'trueDamageDoneToChampions': 429,
#        'trueDamageTaken': 1698},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 2,
#       'level': 20,
#       'minionsKilled': 27,
#       'participantId': 3,
#       'position': {'x': 13276, 'y': 12362},
#       'timeEnemySpentControlled': 17558,
#       'totalGold': 14873,
#       'xp': 22406},
#      '4': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 153,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 487,
#        'attackSpeed': 216,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 72,
#        'cooldownReduction': 0,
#        'health': 4474,
#        'healthMax': 4474,
#        'healthRegen': 46,
#        'lifesteal': 12,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 108,
#        'movementSpeed': 477,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 200,
#        'powerMax': 200,
#        'powerRegen': 100,
#        'spellVamp': 0},
#       'currentGold': 1367,
#       'damageStats': {'magicDamageDone': 53515,
#        'magicDamageDoneToChampions': 8664,
#        'magicDamageTaken': 15558,
#        'physicalDamageDone': 175940,
#        'physicalDamageDoneToChampions': 35561,
#        'physicalDamageTaken': 19511,
#        'totalDamageDone': 232156,
#        'totalDamageDoneToChampions': 44761,
#        'totalDamageTaken': 37715,
#        'trueDamageDone': 2700,
#        'trueDamageDoneToChampions': 535,
#        'trueDamageTaken': 2646},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 72,
#       'level': 22,
#       'minionsKilled': 85,
#       'participantId': 4,
#       'position': {'x': 394, 'y': 461},
#       'timeEnemySpentControlled': 382610,
#       'totalGold': 21052,
#       'xp': 26299},
#      '5': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 373,
#        'armorPen': 0,
#        'armorPenPercent': 30,
#        'attackDamage': 312,
#        'attackSpeed': 239,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 49,
#        'cooldownReduction': 0,
#        'health': 8670,
#        'healthMax': 9026,
#        'healthRegen': 207,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 300,
#        'movementSpeed': 550,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 0,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 1235,
#       'damageStats': {'magicDamageDone': 31326,
#        'magicDamageDoneToChampions': 27262,
#        'magicDamageTaken': 62989,
#        'physicalDamageDone': 195894,
#        'physicalDamageDoneToChampions': 83484,
#        'physicalDamageTaken': 50801,
#        'totalDamageDone': 249638,
#        'totalDamageDoneToChampions': 132106,
#        'totalDamageTaken': 135122,
#        'trueDamageDone': 22418,
#        'trueDamageDoneToChampions': 21359,
#        'trueDamageTaken': 21331},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 8,
#       'level': 24,
#       'minionsKilled': 155,
#       'participantId': 5,
#       'position': {'x': 7246, 'y': 9950},
#       'timeEnemySpentControlled': 244579,
#       'totalGold': 19665,
#       'xp': 30810},
#      '6': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 424,
#        'armor': 175,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 111,
#        'attackSpeed': 202,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 3111,
#        'healthRegen': 41,
#        'lifesteal': 0,
#        'magicPen': 12,
#        'magicPenPercent': 39,
#        'magicResist': 55,
#        'movementSpeed': 435,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 2049,
#        'powerMax': 2049,
#        'powerRegen': 47,
#        'spellVamp': 0},
#       'currentGold': 472,
#       'damageStats': {'magicDamageDone': 94626,
#        'magicDamageDoneToChampions': 23813,
#        'magicDamageTaken': 16256,
#        'physicalDamageDone': 2128,
#        'physicalDamageDoneToChampions': 651,
#        'physicalDamageTaken': 14825,
#        'totalDamageDone': 99140,
#        'totalDamageDoneToChampions': 24465,
#        'totalDamageTaken': 34337,
#        'trueDamageDone': 2385,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 3255},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 4,
#       'level': 20,
#       'minionsKilled': 98,
#       'participantId': 6,
#       'position': {'x': 13653, 'y': 12987},
#       'timeEnemySpentControlled': 281064,
#       'totalGold': 13712,
#       'xp': 22802},
#      '7': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 197,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 406,
#        'attackSpeed': 242,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 0,
#        'healthMax': 4927,
#        'healthRegen': 487,
#        'lifesteal': 8,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 77,
#        'movementSpeed': 423,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 0,
#        'powerMax': 2463,
#        'powerRegen': 0,
#        'spellVamp': 0},
#       'currentGold': 496,
#       'damageStats': {'magicDamageDone': 1869,
#        'magicDamageDoneToChampions': 199,
#        'magicDamageTaken': 19322,
#        'physicalDamageDone': 127528,
#        'physicalDamageDoneToChampions': 50478,
#        'physicalDamageTaken': 43138,
#        'totalDamageDone': 140380,
#        'totalDamageDoneToChampions': 61514,
#        'totalDamageTaken': 69783,
#        'trueDamageDone': 10982,
#        'trueDamageDoneToChampions': 10836,
#        'trueDamageTaken': 7322},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 23,
#       'minionsKilled': 95,
#       'participantId': 7,
#       'position': {'x': 8600, 'y': 10226},
#       'timeEnemySpentControlled': 131001,
#       'totalGold': 16696,
#       'xp': 28600},
#      '8': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 839,
#        'armor': 153,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 111,
#        'attackSpeed': 297,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 3493,
#        'healthMax': 3493,
#        'healthRegen': 53,
#        'lifesteal': 0,
#        'magicPen': 40,
#        'magicPenPercent': 39,
#        'magicResist': 63,
#        'movementSpeed': 538,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 2212,
#        'powerMax': 2212,
#        'powerRegen': 49,
#        'spellVamp': 0},
#       'currentGold': 1937,
#       'damageStats': {'magicDamageDone': 179654,
#        'magicDamageDoneToChampions': 40859,
#        'magicDamageTaken': 22064,
#        'physicalDamageDone': 7100,
#        'physicalDamageDoneToChampions': 1789,
#        'physicalDamageTaken': 20890,
#        'totalDamageDone': 186754,
#        'totalDamageDoneToChampions': 42648,
#        'totalDamageTaken': 44921,
#        'trueDamageDone': 0,
#        'trueDamageDoneToChampions': 0,
#        'trueDamageTaken': 1966},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 1,
#       'level': 24,
#       'minionsKilled': 124,
#       'participantId': 8,
#       'position': {'x': 13706, 'y': 13242},
#       'timeEnemySpentControlled': 198966,
#       'totalGold': 18642,
#       'xp': 30918},
#      '9': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 523,
#        'armor': 145,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 132,
#        'attackSpeed': 243,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 25,
#        'cooldownReduction': 0,
#        'health': 3478,
#        'healthMax': 3478,
#        'healthRegen': 37,
#        'lifesteal': 0,
#        'magicPen': 40,
#        'magicPenPercent': 39,
#        'magicResist': 61,
#        'movementSpeed': 578,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1042,
#        'powerMax': 1042,
#        'powerRegen': 52,
#        'spellVamp': 0},
#       'currentGold': 461,
#       'damageStats': {'magicDamageDone': 115702,
#        'magicDamageDoneToChampions': 35845,
#        'magicDamageTaken': 11108,
#        'physicalDamageDone': 5928,
#        'physicalDamageDoneToChampions': 1635,
#        'physicalDamageTaken': 11208,
#        'totalDamageDone': 140372,
#        'totalDamageDoneToChampions': 39028,
#        'totalDamageTaken': 23957,
#        'trueDamageDone': 18742,
#        'trueDamageDoneToChampions': 1547,
#        'trueDamageTaken': 1640},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 2,
#       'level': 23,
#       'minionsKilled': 96,
#       'participantId': 9,
#       'position': {'x': 13704, 'y': 13163},
#       'timeEnemySpentControlled': 231014,
#       'totalGold': 16366,
#       'xp': 28633},
#      '10': {'championStats': {'abilityHaste': 0,
#        'abilityPower': 0,
#        'armor': 358,
#        'armorPen': 0,
#        'armorPenPercent': 0,
#        'attackDamage': 225,
#        'attackSpeed': 169,
#        'bonusArmorPenPercent': 0,
#        'bonusMagicPenPercent': 0,
#        'ccReduction': 65,
#        'cooldownReduction': 0,
#        'health': 7857,
#        'healthMax': 11742,
#        'healthRegen': 306,
#        'lifesteal': 0,
#        'magicPen': 0,
#        'magicPenPercent': 0,
#        'magicResist': 156,
#        'movementSpeed': 471,
#        'omnivamp': 0,
#        'physicalVamp': 0,
#        'power': 1794,
#        'powerMax': 1794,
#        'powerRegen': 37,
#        'spellVamp': 0},
#       'currentGold': 2179,
#       'damageStats': {'magicDamageDone': 161734,
#        'magicDamageDoneToChampions': 35835,
#        'magicDamageTaken': 39425,
#        'physicalDamageDone': 34963,
#        'physicalDamageDoneToChampions': 10871,
#        'physicalDamageTaken': 45317,
#        'totalDamageDone': 222359,
#        'totalDamageDoneToChampions': 56706,
#        'totalDamageTaken': 94957,
#        'trueDamageDone': 25661,
#        'trueDamageDoneToChampions': 9999,
#        'trueDamageTaken': 10214},
#       'goldPerSecond': 0,
#       'jungleMinionsKilled': 0,
#       'level': 24,
#       'minionsKilled': 170,
#       'participantId': 10,
#       'position': {'x': 7194, 'y': 9945},
#       'timeEnemySpentControlled': 690286,
#       'totalGold': 20409,
#       'xp': 30150}},
#     'timestamp': 1398319}],
#   'gameId': 4915859238,
#   'participants': [{'participantId': 1,
#     'puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ'},
#    {'participantId': 2,
#     'puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w'},
#    {'participantId': 3,
#     'puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA'},
#    {'participantId': 4,
#     'puuid': 'pOM6Z9HBZaC9_BDtwTEIXJlUOFu7LxlPMwSFvUIUrCrP8YBBQoUcCh77yGTpj7oAK2tvJ73PmiK1Og'},
#    {'participantId': 5,
#     'puuid': 'uttiPcXHs8lm5VUjrlX91lrBRcXCIBUuGwb1_QkYyLecBcWaAkNXCvZiO0wg3UtdMyhSC5rRvj5Hzw'},
#    {'participantId': 6,
#     'puuid': '7zgo_t1-cCqlmm7H8No9RDE86asakBNQZbmJgxo5_IwcJRjlWySn2g8KTxIn3QxjWmLuv0jnKXEd6A'},
#    {'participantId': 7,
#     'puuid': 'lw5YPLiIr6b7RId76DLk1NPTH4vCAcS5MMnYp28Wf1eslUL1Ko5nK5OTd-tqbd_wN9B3BtbWGNYL9w'},
#    {'participantId': 8,
#     'puuid': 'gh7OaNbKLLDOF03ElMcXADzZzVewF7GjmfeqgHrIKdN9jkOl1W0rjweJEhGM7yloDoF2KjssT7F2nw'},
#    {'participantId': 9,
#     'puuid': 'RXzD_9dKc-fJr5xC6ykG8Bv5ocPMxKYyXDjb_Bzr2rDyfPlanOWldeQANK0oqUKpH9k15cOJiwU9Jg'},
#    {'participantId': 10,
#     'puuid': 'QiQ6U5WHvO85EFHjXZCfxmPrUmdSS6shJH_Ta0z_PhXHtFabitEjAYYYafYCM1Q7-SgNKBdUANztYg'}]}}

# %% [markdown]
# ### This is a lot, gotta study the keys

# %%
timeline.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
timeline["metadata"]
# Out:
# {'dataVersion': '2',
#  'matchId': 'NA1_4915859238',
#  'participants': ['zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ',
#   'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w',
#   'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#   'pOM6Z9HBZaC9_BDtwTEIXJlUOFu7LxlPMwSFvUIUrCrP8YBBQoUcCh77yGTpj7oAK2tvJ73PmiK1Og',
#   'uttiPcXHs8lm5VUjrlX91lrBRcXCIBUuGwb1_QkYyLecBcWaAkNXCvZiO0wg3UtdMyhSC5rRvj5Hzw',
#   '7zgo_t1-cCqlmm7H8No9RDE86asakBNQZbmJgxo5_IwcJRjlWySn2g8KTxIn3QxjWmLuv0jnKXEd6A',
#   'lw5YPLiIr6b7RId76DLk1NPTH4vCAcS5MMnYp28Wf1eslUL1Ko5nK5OTd-tqbd_wN9B3BtbWGNYL9w',
#   'gh7OaNbKLLDOF03ElMcXADzZzVewF7GjmfeqgHrIKdN9jkOl1W0rjweJEhGM7yloDoF2KjssT7F2nw',
#   'RXzD_9dKc-fJr5xC6ykG8Bv5ocPMxKYyXDjb_Bzr2rDyfPlanOWldeQANK0oqUKpH9k15cOJiwU9Jg',
#   'QiQ6U5WHvO85EFHjXZCfxmPrUmdSS6shJH_Ta0z_PhXHtFabitEjAYYYafYCM1Q7-SgNKBdUANztYg']}

# %% [markdown]
# Metadata gives us particpants, looking at `player_data` this looks like they are `puuid`. So we could find a new match by selecting a random puuid and randomly selecting a match we haven't seen before simliar to the crawl idea in https://github.com/christophM/LolCrawler. Note I am repeating this github link because when we do write about the data collection process, we should cite this for giving us the idea behind it

# %%
player_data["puuid"], player_data["puuid"] in timeline["metadata"]["participants"]
# Out:
# ('GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA',
#  True)

# %% [markdown]
# Now for info

# %%
timeline["info"].keys()
# Out:
# dict_keys(['endOfGameResult', 'frameInterval', 'frames', 'gameId', 'participants'])

# %% [markdown]
# According to https://www.doranslab.gg/tools/jungle-tool.html, we get updates every minute, probably what below is saying

# %%
timeline["info"]["frameInterval"]
# Out:
# 60000

# %% [markdown]
# So gameID gives us a new id type for the match, for partipants it looks like they have a unique id interally for the game... sure I guess that helps save space in the frames

# %%
timeline["info"]["gameId"], timeline["info"]["participants"]
# Out:
# (4915859238,
#  [{'participantId': 1,
#    'puuid': 'zyr8N8v8UDXhe8s5kaCRh4_T2J-et-HZ3VxqQZfKt3NEavxHmbAGKvU23Gtse4wrZf2GneblWy2KFQ'},
#   {'participantId': 2,
#    'puuid': 'jG-sRLtdoqVGEym1P4ASyuqx1e13Mb1QT8OqxBz1iqbvTqyRdpRYOcGzhC0-29qsqOPNd_ZRXuiw1w'},
#   {'participantId': 3,
#    'puuid': 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA'},
#   {'participantId': 4,
#    'puuid': 'pOM6Z9HBZaC9_BDtwTEIXJlUOFu7LxlPMwSFvUIUrCrP8YBBQoUcCh77yGTpj7oAK2tvJ73PmiK1Og'},
#   {'participantId': 5,
#    'puuid': 'uttiPcXHs8lm5VUjrlX91lrBRcXCIBUuGwb1_QkYyLecBcWaAkNXCvZiO0wg3UtdMyhSC5rRvj5Hzw'},
#   {'participantId': 6,
#    'puuid': '7zgo_t1-cCqlmm7H8No9RDE86asakBNQZbmJgxo5_IwcJRjlWySn2g8KTxIn3QxjWmLuv0jnKXEd6A'},
#   {'participantId': 7,
#    'puuid': 'lw5YPLiIr6b7RId76DLk1NPTH4vCAcS5MMnYp28Wf1eslUL1Ko5nK5OTd-tqbd_wN9B3BtbWGNYL9w'},
#   {'participantId': 8,
#    'puuid': 'gh7OaNbKLLDOF03ElMcXADzZzVewF7GjmfeqgHrIKdN9jkOl1W0rjweJEhGM7yloDoF2KjssT7F2nw'},
#   {'participantId': 9,
#    'puuid': 'RXzD_9dKc-fJr5xC6ykG8Bv5ocPMxKYyXDjb_Bzr2rDyfPlanOWldeQANK0oqUKpH9k15cOJiwU9Jg'},
#   {'participantId': 10,
#    'puuid': 'QiQ6U5WHvO85EFHjXZCfxmPrUmdSS6shJH_Ta0z_PhXHtFabitEjAYYYafYCM1Q7-SgNKBdUANztYg'}])

# %% [markdown]
# Frames is where the data we care about lies, it is a list

# %%
type(timeline["info"]["frames"]), len(timeline["info"]["frames"])
# Out:
# (list, 25)

# %% [markdown]
# So above was around a 20 minute game, that explains alot I was playing aram.
#
# lets look at the frist point

# %%
timeline["info"]["frames"][0].keys()
# Out:
# dict_keys(['events', 'participantFrames', 'timestamp'])

# %%
timeline["info"]["frames"][0].keys()
# Out:
# dict_keys(['events', 'participantFrames', 'timestamp'])

# %%
timeline["info"]["frames"][0]["participantFrames"]["1"]
# Out:
# {'championStats': {'abilityHaste': 0,
#   'abilityPower': 0,
#   'armor': 23,
#   'armorPen': 0,
#   'armorPenPercent': 0,
#   'attackDamage': 25,
#   'attackSpeed': 100,
#   'bonusArmorPenPercent': 0,
#   'bonusMagicPenPercent': 0,
#   'ccReduction': 0,
#   'cooldownReduction': 0,
#   'health': 570,
#   'healthMax': 570,
#   'healthRegen': 0,
#   'lifesteal': 0,
#   'magicPen': 0,
#   'magicPenPercent': 0,
#   'magicResist': 37,
#   'movementSpeed': 345,
#   'omnivamp': 0,
#   'physicalVamp': 0,
#   'power': 200,
#   'powerMax': 200,
#   'powerRegen': 0,
#   'spellVamp': 0},
#  'currentGold': 500,
#  'damageStats': {'magicDamageDone': 0,
#   'magicDamageDoneToChampions': 0,
#   'magicDamageTaken': 0,
#   'physicalDamageDone': 0,
#   'physicalDamageDoneToChampions': 0,
#   'physicalDamageTaken': 0,
#   'totalDamageDone': 0,
#   'totalDamageDoneToChampions': 0,
#   'totalDamageTaken': 0,
#   'trueDamageDone': 0,
#   'trueDamageDoneToChampions': 0,
#   'trueDamageTaken': 0},
#  'goldPerSecond': 0,
#  'jungleMinionsKilled': 0,
#  'level': 1,
#  'minionsKilled': 0,
#  'participantId': 1,
#  'position': {'x': 554, 'y': 581},
#  'timeEnemySpentControlled': 0,
#  'totalGold': 500,
#  'xp': 0}

# %%
timeline["info"]["frames"][0]["participantFrames"]["1"].keys()
# Out:
# dict_keys(['championStats', 'currentGold', 'damageStats', 'goldPerSecond', 'jungleMinionsKilled', 'level', 'minionsKilled', 'participantId', 'position', 'timeEnemySpentControlled', 'totalGold', 'xp'])

# %% [markdown]
# Wait, that is really cool we get the following data:
#
# ['championStats', 'currentGold', 'damageStats', 'goldPerSecond', 'jungleMinionsKilled', 'level', 'minionsKilled', 'participantId', 'position', 'timeEnemySpentControlled', 'totalGold', 'xp']
#
# And under chamption stats we get
# ['abilityHaste', 'abilityPower', 'armor', 'armorPen', 'armorPenPercent', 'attackDamage', 'attackSpeed', 'bonusArmorPenPercent', 'bonusMagicPenPercent', 'ccReduction', 'cooldownReduction', 'health', 'healthMax', 'healthRegen', 'lifesteal', 'magicPen', 'magicPenPercent', 'magicResist', 'movementSpeed', 'omnivamp', 'physicalVamp', 'power', 'powerMax', 'powerRegen', 'spellVamp']
#
# Wow... that is a lot of data

# %%
timeline["info"]["frames"][0]["participantFrames"]["1"]["championStats"].keys()
# Out:
# dict_keys(['abilityHaste', 'abilityPower', 'armor', 'armorPen', 'armorPenPercent', 'attackDamage', 'attackSpeed', 'bonusArmorPenPercent', 'bonusMagicPenPercent', 'ccReduction', 'cooldownReduction', 'health', 'healthMax', 'healthRegen', 'lifesteal', 'magicPen', 'magicPenPercent', 'magicResist', 'movementSpeed', 'omnivamp', 'physicalVamp', 'power', 'powerMax', 'powerRegen', 'spellVamp'])

# %% [markdown]
# What does events actually mean?|

# %%
timeline["info"]["frames"][1]["events"]
# Out:
# [{'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 1,
#   'timestamp': 2077,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 3,
#   'skillSlot': 1,
#   'timestamp': 3377,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 3070,
#   'participantId': 8,
#   'timestamp': 3443,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 8,
#   'skillSlot': 3,
#   'timestamp': 4109,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 1,
#   'timestamp': 5075,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1028,
#   'participantId': 10,
#   'timestamp': 6076,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 2,
#   'skillSlot': 1,
#   'timestamp': 6875,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1052,
#   'participantId': 9,
#   'timestamp': 8444,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1036,
#   'participantId': 7,
#   'timestamp': 8778,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1052,
#   'participantId': 3,
#   'timestamp': 10314,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2022,
#   'participantId': 2,
#   'timestamp': 10381,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1056,
#   'participantId': 6,
#   'timestamp': 11082,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 11082,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 11082,
#   'type': 'ITEM_PURCHASED'},
#  {'afterId': 0,
#   'beforeId': 2003,
#   'goldGain': 50,
#   'participantId': 6,
#   'timestamp': 12050,
#   'type': 'ITEM_UNDO'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 9,
#   'skillSlot': 1,
#   'timestamp': 12883,
#   'type': 'SKILL_LEVEL_UP'},
#  {'afterId': 0,
#   'beforeId': 2003,
#   'goldGain': 50,
#   'participantId': 6,
#   'timestamp': 13582,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 1036,
#   'participantId': 5,
#   'timestamp': 14749,
#   'type': 'ITEM_PURCHASED'},
#  {'afterId': 0,
#   'beforeId': 1056,
#   'goldGain': 400,
#   'participantId': 6,
#   'timestamp': 15084,
#   'type': 'ITEM_UNDO'},
#  {'afterId': 0,
#   'beforeId': 1036,
#   'goldGain': 350,
#   'participantId': 5,
#   'timestamp': 15684,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 1056,
#   'participantId': 6,
#   'timestamp': 16817,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 16817,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 6,
#   'timestamp': 16817,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1028,
#   'participantId': 5,
#   'timestamp': 18916,
#   'type': 'ITEM_PURCHASED'},
#  {'afterId': 0,
#   'beforeId': 2003,
#   'goldGain': 50,
#   'participantId': 6,
#   'timestamp': 19648,
#   'type': 'ITEM_UNDO'},
#  {'afterId': 0,
#   'beforeId': 2003,
#   'goldGain': 50,
#   'participantId': 6,
#   'timestamp': 19816,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 3340,
#   'participantId': 5,
#   'timestamp': 20115,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 5,
#   'timestamp': 20512,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2003,
#   'participantId': 5,
#   'timestamp': 20812,
#   'type': 'ITEM_PURCHASED'},
#  {'afterId': 0,
#   'beforeId': 1056,
#   'goldGain': 400,
#   'participantId': 6,
#   'timestamp': 21345,
#   'type': 'ITEM_UNDO'},
#  {'itemId': 1052,
#   'participantId': 6,
#   'timestamp': 23314,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1028,
#   'participantId': 1,
#   'timestamp': 23413,
#   'type': 'ITEM_PURCHASED'},
#  {'creatorId': 8,
#   'timestamp': 23480,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'itemId': 3340,
#   'participantId': 1,
#   'timestamp': 24445,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 3,
#   'timestamp': 25382,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 5,
#   'skillSlot': 1,
#   'timestamp': 28384,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 1,
#   'skillSlot': 1,
#   'timestamp': 29084,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1036,
#   'participantId': 4,
#   'timestamp': 32756,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 2031,
#   'participantId': 4,
#   'timestamp': 33556,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 3340,
#   'participantId': 4,
#   'timestamp': 34458,
#   'type': 'ITEM_PURCHASED'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 1,
#   'timestamp': 36629,
#   'type': 'SKILL_LEVEL_UP'},
#  {'assistingParticipantIds': [6, 7, 8, 9],
#   'bounty': 400,
#   'killStreakLength': 0,
#   'killerId': 10,
#   'position': {'x': 798, 'y': 10072},
#   'shutdownBounty': 0,
#   'timestamp': 39497,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Garen',
#     'participantId': 7,
#     'physicalDamage': 118,
#     'spellName': 'garenq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 163,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'rupture',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 19,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 45,
#     'spellName': 'chogathbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'summonerdot',
#     'spellSlot': 5,
#     'trueDamage': 56,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 33,
#     'spellName': 'luxbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 8,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 8,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 133,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'luxlightbinding',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 25,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'luxilluminationpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 70,
#     'spellName': 'settpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 65,
#     'spellName': 'sette',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 53,
#     'spellName': 'settbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 7,
#     'name': 'Neeko',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Neeko',
#     'participantId': 8,
#     'physicalDamage': 62,
#     'spellName': 'neekobasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 104,
#     'name': 'Viktor',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'viktorpowertransfer',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 20,
#     'name': 'Viktor',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 5},
#  {'killType': 'KILL_FIRST_BLOOD',
#   'killerId': 10,
#   'position': {'x': 1599, 'y': 11640},
#   'timestamp': 39497,
#   'type': 'CHAMPION_SPECIAL_KILL'},
#  {'assistingParticipantIds': [8, 10],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 9,
#   'position': {'x': 1432, 'y': 10429},
#   'shutdownBounty': 0,
#   'timestamp': 44570,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 9,
#     'name': 'Nidalee',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 124,
#     'name': 'Nidalee',
#     'participantId': 7,
#     'physicalDamage': 0,
#     'spellName': 'javelintoss',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 183,
#     'name': 'Nidalee',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'javelintoss',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 177,
#     'name': 'Neeko',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'neekoe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 10,
#     'name': 'Neeko',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Neeko',
#     'participantId': 8,
#     'physicalDamage': 36,
#     'spellName': 'neekobasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 227,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'luxlightbinding',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 9,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 184,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'rupture',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 3},
#  {'assistingParticipantIds': [1, 2, 3],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 4,
#   'position': {'x': 2302, 'y': 12263},
#   'shutdownBounty': 0,
#   'timestamp': 46204,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 49,
#     'name': 'Neeko',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'neekoe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Neeko',
#     'participantId': 1,
#     'physicalDamage': 35,
#     'spellName': 'neekobasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 58,
#     'name': 'Neeko',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': 'neekoe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Neeko',
#     'participantId': 2,
#     'physicalDamage': 39,
#     'spellName': 'neekobasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 58,
#     'name': 'Neeko',
#     'participantId': 4,
#     'physicalDamage': 0,
#     'spellName': 'neekoe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 66,
#     'name': 'Lux',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': 'luxlightbinding',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 25,
#     'name': 'Lux',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': 'luxilluminationpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Lux',
#     'participantId': 2,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 9,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lux',
#     'participantId': 2,
#     'physicalDamage': 42,
#     'spellName': 'luxbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 142,
#     'name': 'Akali',
#     'participantId': 1,
#     'physicalDamage': 0,
#     'spellName': 'akaliq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 183,
#     'name': 'Nidalee',
#     'participantId': 3,
#     'physicalDamage': 0,
#     'spellName': 'javelintoss',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 4,
#     'physicalDamage': 64,
#     'spellName': 'blindmonkqone',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 4,
#     'physicalDamage': 120,
#     'spellName': 'blindmonkqtwo',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 4,
#     'physicalDamage': 30,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 4,
#     'physicalDamage': 78,
#     'spellName': 'leesinbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 8},
#  {'assistingParticipantIds': [6, 8, 9, 10],
#   'bounty': 300,
#   'killStreakLength': 0,
#   'killerId': 7,
#   'position': {'x': 1796, 'y': 12052},
#   'shutdownBounty': 0,
#   'timestamp': 49405,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 9,
#     'physicalDamage': 66,
#     'spellName': 'blindmonkqone',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 9,
#     'physicalDamage': 73,
#     'spellName': 'blindmonkqtwo',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 58,
#     'name': 'Neeko',
#     'participantId': 8,
#     'physicalDamage': 0,
#     'spellName': 'neekoe',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 74,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'luxlightbinding',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 29,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'luxilluminationpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 13,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 9,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 75,
#     'spellName': 'luxbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 181,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'rupture',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 116,
#     'name': 'Viktor',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'viktorpowertransfer',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 22,
#     'name': 'Viktor',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 81,
#     'spellName': 'sette',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 66,
#     'spellName': 'settbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 4},
#  {'itemId': 1001,
#   'participantId': 4,
#   'timestamp': 53873,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1001,
#   'participantId': 8,
#   'timestamp': 56309,
#   'type': 'ITEM_PURCHASED'}]

# %% [markdown]
# ### Okay that is interesting
#
# So events tell us even more things that happened during that time. This is after the frist minute so naturally players are buying thier frist items.

# %%
timeline["info"]["frames"][2]["events"]
# Out:
# [{'assistingParticipantIds': [6, 9, 10],
#   'bounty': 274,
#   'killStreakLength': 1,
#   'killerId': 7,
#   'position': {'x': 1548, 'y': 12596},
#   'shutdownBounty': 0,
#   'timestamp': 61756,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 0,
#     'name': 'Garen',
#     'participantId': 7,
#     'physicalDamage': 134,
#     'spellName': 'garenq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Garen',
#     'participantId': 9,
#     'physicalDamage': 136,
#     'spellName': 'garenq',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Garen',
#     'participantId': 10,
#     'physicalDamage': 65,
#     'spellName': 'garenbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Garen',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'summonerdot',
#     'spellSlot': 5,
#     'trueDamage': 70,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 256,
#     'name': 'Viktor',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'viktorpowertransfer',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 27,
#     'name': 'Viktor',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 149,
#     'spellName': 'settpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 148,
#     'spellName': 'sette',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 61,
#     'spellName': 'settbasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 125,
#     'spellName': 'settbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 33,
#     'spellName': 'luxbasicattack',
#     'spellSlot': 64,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 8,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 54,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'rupture',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 5},
#  {'creatorId': 4,
#   'timestamp': 63925,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'creatorId': 8,
#   'timestamp': 66029,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'assistingParticipantIds': [6, 7, 10],
#   'bounty': 300,
#   'killStreakLength': 1,
#   'killerId': 9,
#   'position': {'x': 1883, 'y': 12857},
#   'shutdownBounty': 0,
#   'timestamp': 66696,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': [{'basic': False,
#     'magicDamage': 75,
#     'name': 'LeeSin',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'feeneypulttargeting',
#     'spellSlot': 61,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'LeeSin',
#     'participantId': 7,
#     'physicalDamage': 66,
#     'spellName': 'leesinbasicattack2',
#     'spellSlot': 65,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimDamageReceived': [{'basic': False,
#     'magicDamage': 154,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': 'luxlightbinding',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 14,
#     'name': 'Lux',
#     'participantId': 9,
#     'physicalDamage': 0,
#     'spellName': '',
#     'spellSlot': -1,
#     'trueDamage': 9,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 121,
#     'name': 'Chogath',
#     'participantId': 10,
#     'physicalDamage': 0,
#     'spellName': 'rupture',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 88,
#     'spellName': 'sette',
#     'spellSlot': 2,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 93,
#     'spellName': 'settpassive',
#     'spellSlot': 63,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': True,
#     'magicDamage': 0,
#     'name': 'Sett',
#     'participantId': 7,
#     'physicalDamage': 75,
#     'spellName': 'settbasicattack3',
#     'spellSlot': 66,
#     'trueDamage': 0,
#     'type': 'OTHER'},
#    {'basic': False,
#     'magicDamage': 116,
#     'name': 'Viktor',
#     'participantId': 6,
#     'physicalDamage': 0,
#     'spellName': 'viktorpowertransfer',
#     'spellSlot': 0,
#     'trueDamage': 0,
#     'type': 'OTHER'}],
#   'victimId': 4},
#  {'creatorId': 3,
#   'timestamp': 77671,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'levelUpType': 'EVOLVE',
#   'participantId': 6,
#   'skillSlot': 3,
#   'timestamp': 80966,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 1028,
#   'participantId': 10,
#   'timestamp': 82231,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3801,
#   'participantId': 10,
#   'timestamp': 82231,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1036,
#   'participantId': 7,
#   'timestamp': 82366,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3133,
#   'participantId': 7,
#   'timestamp': 82366,
#   'type': 'ITEM_PURCHASED'},
#  {'creatorId': 3,
#   'timestamp': 82598,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'creatorId': 8,
#   'timestamp': 83199,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'itemId': 1052,
#   'participantId': 9,
#   'timestamp': 83732,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 3145,
#   'participantId': 9,
#   'timestamp': 83732,
#   'type': 'ITEM_PURCHASED'},
#  {'itemId': 1001,
#   'participantId': 10,
#   'timestamp': 84466,
#   'type': 'ITEM_PURCHASED'},
#  {'level': 2, 'participantId': 4, 'timestamp': 95906, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 4,
#   'skillSlot': 2,
#   'timestamp': 96806,
#   'type': 'SKILL_LEVEL_UP'},
#  {'itemId': 2003,
#   'participantId': 5,
#   'timestamp': 97672,
#   'type': 'ITEM_DESTROYED'},
#  {'itemId': 2003,
#   'participantId': 5,
#   'timestamp': 98841,
#   'type': 'ITEM_DESTROYED'},
#  {'killerId': 0,
#   'laneType': 'MID_LANE',
#   'position': {'x': 8955, 'y': 8510},
#   'teamId': 200,
#   'timestamp': 108604,
#   'type': 'TURRET_PLATE_DESTROYED'},
#  {'creatorId': 1,
#   'timestamp': 113306,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'level': 2, 'participantId': 6, 'timestamp': 115274, 'type': 'LEVEL_UP'},
#  {'level': 2, 'participantId': 10, 'timestamp': 116042, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 6,
#   'skillSlot': 2,
#   'timestamp': 116408,
#   'type': 'SKILL_LEVEL_UP'},
#  {'level': 2, 'participantId': 7, 'timestamp': 116708, 'type': 'LEVEL_UP'},
#  {'creatorId': 1,
#   'timestamp': 116940,
#   'type': 'WARD_PLACED',
#   'wardType': 'YELLOW_TRINKET'},
#  {'level': 2, 'participantId': 9, 'timestamp': 118173, 'type': 'LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 10,
#   'skillSlot': 3,
#   'timestamp': 118540,
#   'type': 'SKILL_LEVEL_UP'},
#  {'levelUpType': 'NORMAL',
#   'participantId': 7,
#   'skillSlot': 1,
#   'timestamp': 118606,
#   'type': 'SKILL_LEVEL_UP'}]

# %% [markdown]
# 2 minutes in and we have a frist blood, and the position of that kill
#
# {'assistingParticipantIds': [6, 8, 9, 10],
#   'bounty': 270,
#   'killStreakLength': 0,
#   'killerId': 7,
#   'position': {'x': 6906, 'y': 5944},
#   'shutdownBounty': 0,
#   'timestamp': 85594,
#   'type': 'CHAMPION_KILL',
#   'victimDamageDealt': .....
#
# }

# %% [markdown]
# ### Exploration done time for infrastructure
#
# Goal: Create a dataframe of the current locations of each player for a single game shown above

# %%
from get_data import select_player_locations, get_next_puuid

data = select_player_locations(match_ids[0], "ARAM", timeline)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 from get_data import select_player_locations, get_next_puuid
# ----> 3 data = select_player_locations(match_ids[0], "ARAM", timeline)
#       4 data
#
# File c:\Users\seanh\Desktop\DSC 106\project3\LeagueOfLegendsLocationAnaysis-\src\get_data.py:11, in select_player_locations(match_meta, timeline, data, lol_watcher, region)
#      10 def select_player_locations(match_meta,  timeline, data = [], lol_watcher=LolWatcher, region="na1"):
# ---> 11     frames = timeline["info"]["frames"]
#      12     parts = timeline["info"]["participants"]
#      13     match_type = match_meta["info"]["gameMode"]
#
# TypeError: string indices must be integers

# %%
get_next_puuid(player_data["puuid"], timeline)
# Out:
# 'GVTQeUq3T8ClMUNJNTwrekNiL_89wfaUjjlFFQI2HvU5lK5j02X8mHLY8Ar-WzyLosVyaHv8yo5RWA'

# %%
# Out:
# 'NA1_4916623487'

# %%
import random
import time

def get_n_matches_data(lol_watcher, puuid, n, my_region="na1"):
    data = []
    for _ in range(n):
        #try:
            match_ids = lol_watcher.match.matchlist_by_puuid(my_region, puuid)
            match_id = random.choice(match_ids)
            
            match_meta = lol_watcher.match.by_id(my_region, match_id)
            timeline = lol_watcher.match.timeline_by_match(my_region, match_id)
            
            data = select_player_locations(match_meta, timeline, data=data, lol_watcher=lol_watcher)
            puuid = get_next_puuid(puuid, timeline)
            time.sleep(1)
        # except Exception as e:
        #     print(e)
        #     continue
    return data


# So we get high elo players
kumo = lol_watcher.summoner.by_name(my_region, 'Kumo9')

data = get_n_matches_data(lol_watcher, kumo['puuid'], 10_000, my_region="na1")

data
# Out:
# [{'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 554,
#   'y': 581,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 593,
#   'y': 464,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 557,
#   'y': 345,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 458,
#   'y': 271,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 335,
#   'y': 269,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14500,
#   'y': 14511,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14539,
#   'y': 14394,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14503,
#   'y': 14275,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14404,
#   'y': 14201,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 0,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14281,
#   'y': 14199,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7005,
#   'y': 7014,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7990,
#   'y': 3532,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 3514,
#   'y': 10064,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7842,
#   'y': 4989,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11012,
#   'y': 1625,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 3392,
#   'y': 11337,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6617,
#   'y': 8750,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7155,
#   'y': 8822,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11536,
#   'y': 3938,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 1,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11570,
#   'y': 3878,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6264,
#   'y': 6819,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7119,
#   'y': 3685,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 2,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1856,
#   'y': 12242,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 12073,
#   'y': 2458,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 12442,
#   'y': 1987,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2263,
#   'y': 12626,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 8061,
#   'y': 9988,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 2,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7156,
#   'y': 6766,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13286,
#   'y': 2989,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 2,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13310,
#   'y': 2410,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 1,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7285,
#   'y': 7665,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2290,
#   'y': 9471,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1379,
#   'y': 11066,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11878,
#   'y': 2168,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 2,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11920,
#   'y': 1604,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 2,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1034,
#   'y': 10150,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 9179,
#   'y': 5796,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 8244,
#   'y': 7856,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 12936,
#   'y': 2900,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 2,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 3,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13012,
#   'y': 1974,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 2,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6965,
#   'y': 7111,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6171,
#   'y': 8669,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 3304,
#   'y': 11388,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11049,
#   'y': 1254,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11196,
#   'y': 1418,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 3176,
#   'y': 13037,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 10769,
#   'y': 4596,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7984,
#   'y': 7498,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11609,
#   'y': 2969,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 4,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11322,
#   'y': 3203,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7048,
#   'y': 7159,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 9442,
#   'y': 3377,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1289,
#   'y': 11484,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11251,
#   'y': 1540,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11059,
#   'y': 1706,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2915,
#   'y': 11383,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6572,
#   'y': 9735,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7762,
#   'y': 7790,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14290,
#   'y': 14166,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 5,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6282,
#   'y': 9074,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 3,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6200,
#   'y': 6273,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2268,
#   'y': 8354,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1834,
#   'y': 11222,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13554,
#   'y': 2779,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 12297,
#   'y': 3244,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 3827,
#   'y': 13260,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 3261,
#   'y': 11535,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13436,
#   'y': 12880,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13728,
#   'y': 4114,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 6,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13390,
#   'y': 3860,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 4,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6394,
#   'y': 6584,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1739,
#   'y': 13032,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1628,
#   'y': 12191,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13358,
#   'y': 3954,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13088,
#   'y': 3712,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2653,
#   'y': 12073,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 10556,
#   'y': 5031,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7672,
#   'y': 7397,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 7,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13966,
#   'y': 4367,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 7,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 13915,
#   'y': 4849,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6584,
#   'y': 6798,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 7,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7603,
#   'y': 3817,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 1753,
#   'y': 10150,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 7,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 12516,
#   'y': 2382,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 12080,
#   'y': 1988,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2217,
#   'y': 12667,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 7,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 10084,
#   'y': 5098,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7882,
#   'y': 7320,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 7,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14194,
#   'y': 13627,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 8,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 14205,
#   'y': 13749,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 5514,
#   'y': 6287,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 7,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7581,
#   'y': 9991,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2623,
#   'y': 13092,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 8,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11847,
#   'y': 2162,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11621,
#   'y': 1811,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6301,
#   'y': 8902,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 8,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 7,
#   'player_puuid': 'cH43mGr4ZgZqsQXaApinR4xBKNCvTiyxwk8I-1CbeoSB0DEY4cwg3Kwywu6ckrRRuII99_4OxX_m5w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 10175,
#   'y': 6615,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 8,
#   'player_puuid': 'vaaO1hvNwCVYV0bczVlcCikJwxIqLNWyPsFww1CgT8oiwDiTSjChEpNyzmxiAxEwI7JqzWU_HU47Aw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 8724,
#   'y': 7965,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 8,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 9,
#   'player_puuid': 'XeaV7wy0lwMaWgwFN7ttCinETWWDitaEwwHPKcIgQFFb0nGP1Io0J4AiRgAlVdqXUBNe91U6R4m-WQ',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7821,
#   'y': 5874,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 9,
#   'player_part_id': 10,
#   'player_puuid': 'eS7N8wQbTgy1QTK2UwOBkKRzvmKR0Sxkf0U3yyyy_DN1ZrGpn_U6iTWesA7KQtW46F_3Zv5HpTCX3w',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 7701,
#   'y': 7715,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 5,
#   'tier': 'DIAMOND',
#   'rank': 'IV'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 10,
#   'player_part_id': 1,
#   'player_puuid': '7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF_XXcYL3DJ_8E-Kcat_h7bVMF63epjqjA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 6443,
#   'y': 6470,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'NONE',
#   'level': 8,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 10,
#   'player_part_id': 2,
#   'player_puuid': '-lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbilwdKiyAOsQ8ZIfrLWv4few0_Cg7WJUiA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 4886,
#   'y': 10205,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 10,
#   'player_part_id': 3,
#   'player_puuid': 'sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNdvzye8G_Xvfa_SsXfknLe6cAACsifUYCA',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2614,
#   'y': 12025,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 8,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 10,
#   'player_part_id': 4,
#   'player_puuid': 'qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIGZhfd3Gey80y7hbbsQKLHl2TH7hxwOodw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 5592,
#   'y': 891,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'NONE',
#   'level': 6,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 10,
#   'player_part_id': 5,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 11581,
#   'y': 1061,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'NONE',
#   'level': 7,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 10,
#   'player_part_id': 6,
#   'player_puuid': 'IUa1mS4jFYRLFu821ZO_9jmAFqQHVutuGGEY-gwP-WHXkJytMg6MfmaUq1YqUbDvaWLItQQ1Pl6U8A',
#   'player_summoner_id': 'xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI',
#   'x': 2589,
#   'y': 13512,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'NONE',
#   'level': 8,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4916347757',
#   'match_type': 'CLASSIC',
#   'frame': 10,
# ...
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 28,
#   'player_part_id': 6,
#   'player_puuid': 'FFg92Qbo4QMCK17khZ_p6fnQufj5FER6N40ZLV724u5JMiimuLR05xJvmbb2JJumhW3Bd6luxcp2TA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 11439,
#   'y': 3886,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'TOP',
#   'level': 17,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 28,
#   'player_part_id': 7,
#   'player_puuid': 'zNC3SJU75Rl4nVWU9DHrogiJ_cSA6VhimAII7Z2yLn7HfErxGCnFZOXo_ShLCQpZBUZohIOkz4lpTQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 10075,
#   'y': 9016,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'JUNGLE',
#   'level': 15,
#   'tier': 'EMERALD',
#   'rank': 'III'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 28,
#   'player_part_id': 8,
#   'player_puuid': 'mlt4Wh4NKd0tFt6HZs2h4PeroknaOTvAYFuTH1jyGcw32RDP8CMcYh3lBCU4nTn5QzFBZ0TXEtn8ZQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 8264,
#   'y': 7676,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'TOP',
#   'level': 16,
#   'tier': 'DIAMOND',
#   'rank': 'II'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 28,
#   'player_part_id': 9,
#   'player_puuid': 'qng75RPNtaJ5CgcwMpGcx7AfNFmMoeNz2PkFuFnyUIoEAQjyLEHUAPIW8oA7fbUSnXXH9LtIIQKdeA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 10106,
#   'y': 10258,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'BOTTOM',
#   'level': 15,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 28,
#   'player_part_id': 10,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 10434,
#   'y': 6193,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'BOTTOM',
#   'level': 13,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 1,
#   'player_puuid': 'fnJLdakMlJ1FGXZDG_RirYnsoOvuEGSBUuAFXGnHW0Ngo601Dlm88ldgx59cwfqOl5OykpCQKcpDaA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 4125,
#   'y': 14034,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'JUNGLE',
#   'level': 17,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 2,
#   'player_puuid': '_53lLI2Fgpo5AOsxUKJyM0BDlmYeRiYZGAYAMcQGcU0h7f9LXQ8RXTjJE-f7_A8q6imamCtmD9gYfQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 14072,
#   'y': 6673,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'JUNGLE',
#   'level': 15,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 3,
#   'player_puuid': 'nv2vTpk-DCtpytCnSzPYVlZ58Co_Tw0vfBaobZr5VwueQICXvFz4M59jJVW0Q9K0tnvEiWWzMBCcIA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 5479,
#   'y': 5059,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'MIDDLE',
#   'level': 17,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 4,
#   'player_puuid': 'OjM0hUcWxJd7wVh3RLGYfIcqn26sMa6esXe5-cNnASZubEqxaeFmzs80jouVfpCoRsjuw9MTxECD_g',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 5915,
#   'y': 5913,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'BOTTOM',
#   'level': 14,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 5,
#   'player_puuid': 'BK4394bPMl6RsuV4_LR_BFZPS6KEYDqlfjlR3zcvHk6me8eAPiwAxZXN_tiIUCMTK3qFyPRbq73oAQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 8851,
#   'y': 8014,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'BOTTOM',
#   'level': 13,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 6,
#   'player_puuid': 'FFg92Qbo4QMCK17khZ_p6fnQufj5FER6N40ZLV724u5JMiimuLR05xJvmbb2JJumhW3Bd6luxcp2TA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 12507,
#   'y': 6221,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'TOP',
#   'level': 17,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 7,
#   'player_puuid': 'zNC3SJU75Rl4nVWU9DHrogiJ_cSA6VhimAII7Z2yLn7HfErxGCnFZOXo_ShLCQpZBUZohIOkz4lpTQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 13131,
#   'y': 8919,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'JUNGLE',
#   'level': 15,
#   'tier': 'EMERALD',
#   'rank': 'III'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 8,
#   'player_puuid': 'mlt4Wh4NKd0tFt6HZs2h4PeroknaOTvAYFuTH1jyGcw32RDP8CMcYh3lBCU4nTn5QzFBZ0TXEtn8ZQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 13217,
#   'y': 9024,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'TOP',
#   'level': 17,
#   'tier': 'DIAMOND',
#   'rank': 'II'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 9,
#   'player_puuid': 'qng75RPNtaJ5CgcwMpGcx7AfNFmMoeNz2PkFuFnyUIoEAQjyLEHUAPIW8oA7fbUSnXXH9LtIIQKdeA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 10361,
#   'y': 12871,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'BOTTOM',
#   'level': 15,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 29,
#   'player_part_id': 10,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 13859,
#   'y': 7227,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'BOTTOM',
#   'level': 13,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 1,
#   'player_puuid': 'fnJLdakMlJ1FGXZDG_RirYnsoOvuEGSBUuAFXGnHW0Ngo601Dlm88ldgx59cwfqOl5OykpCQKcpDaA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 3026,
#   'y': 10920,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'JUNGLE',
#   'level': 17,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 2,
#   'player_puuid': '_53lLI2Fgpo5AOsxUKJyM0BDlmYeRiYZGAYAMcQGcU0h7f9LXQ8RXTjJE-f7_A8q6imamCtmD9gYfQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 2207,
#   'y': 4037,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'JUNGLE',
#   'level': 15,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 3,
#   'player_puuid': 'nv2vTpk-DCtpytCnSzPYVlZ58Co_Tw0vfBaobZr5VwueQICXvFz4M59jJVW0Q9K0tnvEiWWzMBCcIA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 1557,
#   'y': 10707,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'MIDDLE',
#   'level': 17,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 4,
#   'player_puuid': 'OjM0hUcWxJd7wVh3RLGYfIcqn26sMa6esXe5-cNnASZubEqxaeFmzs80jouVfpCoRsjuw9MTxECD_g',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 2118,
#   'y': 12004,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'BOTTOM',
#   'level': 14,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 5,
#   'player_puuid': 'BK4394bPMl6RsuV4_LR_BFZPS6KEYDqlfjlR3zcvHk6me8eAPiwAxZXN_tiIUCMTK3qFyPRbq73oAQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 3220,
#   'y': 11240,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'BOTTOM',
#   'level': 13,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 6,
#   'player_puuid': 'FFg92Qbo4QMCK17khZ_p6fnQufj5FER6N40ZLV724u5JMiimuLR05xJvmbb2JJumhW3Bd6luxcp2TA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 2471,
#   'y': 11443,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'TOP',
#   'level': 17,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 7,
#   'player_puuid': 'zNC3SJU75Rl4nVWU9DHrogiJ_cSA6VhimAII7Z2yLn7HfErxGCnFZOXo_ShLCQpZBUZohIOkz4lpTQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 2856,
#   'y': 12073,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'JUNGLE',
#   'level': 16,
#   'tier': 'EMERALD',
#   'rank': 'III'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 8,
#   'player_puuid': 'mlt4Wh4NKd0tFt6HZs2h4PeroknaOTvAYFuTH1jyGcw32RDP8CMcYh3lBCU4nTn5QzFBZ0TXEtn8ZQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 7308,
#   'y': 13242,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'TOP',
#   'level': 17,
#   'tier': 'DIAMOND',
#   'rank': 'II'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 9,
#   'player_puuid': 'qng75RPNtaJ5CgcwMpGcx7AfNFmMoeNz2PkFuFnyUIoEAQjyLEHUAPIW8oA7fbUSnXXH9LtIIQKdeA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 2181,
#   'y': 11905,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'BOTTOM',
#   'level': 15,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 30,
#   'player_part_id': 10,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 2874,
#   'y': 12188,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'BOTTOM',
#   'level': 13,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 1,
#   'player_puuid': 'fnJLdakMlJ1FGXZDG_RirYnsoOvuEGSBUuAFXGnHW0Ngo601Dlm88ldgx59cwfqOl5OykpCQKcpDaA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 11979,
#   'y': 12662,
#   'team_id': 100,
#   'win': True,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'JUNGLE',
#   'level': 18,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 2,
#   'player_puuid': '_53lLI2Fgpo5AOsxUKJyM0BDlmYeRiYZGAYAMcQGcU0h7f9LXQ8RXTjJE-f7_A8q6imamCtmD9gYfQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 12872,
#   'y': 13308,
#   'team_id': 100,
#   'win': True,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'JUNGLE',
#   'level': 16,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 3,
#   'player_puuid': 'nv2vTpk-DCtpytCnSzPYVlZ58Co_Tw0vfBaobZr5VwueQICXvFz4M59jJVW0Q9K0tnvEiWWzMBCcIA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 11437,
#   'y': 12208,
#   'team_id': 100,
#   'win': True,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'MIDDLE',
#   'level': 17,
#   'tier': 'CHALLENGER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 4,
#   'player_puuid': 'OjM0hUcWxJd7wVh3RLGYfIcqn26sMa6esXe5-cNnASZubEqxaeFmzs80jouVfpCoRsjuw9MTxECD_g',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 752,
#   'y': 692,
#   'team_id': 100,
#   'win': True,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'BOTTOM',
#   'level': 14,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 5,
#   'player_puuid': 'BK4394bPMl6RsuV4_LR_BFZPS6KEYDqlfjlR3zcvHk6me8eAPiwAxZXN_tiIUCMTK3qFyPRbq73oAQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 12631,
#   'y': 13333,
#   'team_id': 100,
#   'win': True,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'BOTTOM',
#   'level': 14,
#   'tier': 'MASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 6,
#   'player_puuid': 'FFg92Qbo4QMCK17khZ_p6fnQufj5FER6N40ZLV724u5JMiimuLR05xJvmbb2JJumhW3Bd6luxcp2TA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 1566,
#   'y': 12658,
#   'team_id': 200,
#   'win': False,
#   'position': 'TOP',
#   'indiv_pos': 'TOP',
#   'lane': 'TOP',
#   'level': 18,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 7,
#   'player_puuid': 'zNC3SJU75Rl4nVWU9DHrogiJ_cSA6VhimAII7Z2yLn7HfErxGCnFZOXo_ShLCQpZBUZohIOkz4lpTQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 12743,
#   'y': 13985,
#   'team_id': 200,
#   'win': False,
#   'position': 'JUNGLE',
#   'indiv_pos': 'JUNGLE',
#   'lane': 'JUNGLE',
#   'level': 16,
#   'tier': 'EMERALD',
#   'rank': 'III'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 8,
#   'player_puuid': 'mlt4Wh4NKd0tFt6HZs2h4PeroknaOTvAYFuTH1jyGcw32RDP8CMcYh3lBCU4nTn5QzFBZ0TXEtn8ZQ',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 3320,
#   'y': 12436,
#   'team_id': 200,
#   'win': False,
#   'position': 'MIDDLE',
#   'indiv_pos': 'MIDDLE',
#   'lane': 'TOP',
#   'level': 17,
#   'tier': 'DIAMOND',
#   'rank': 'II'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 9,
#   'player_puuid': 'qng75RPNtaJ5CgcwMpGcx7AfNFmMoeNz2PkFuFnyUIoEAQjyLEHUAPIW8oA7fbUSnXXH9LtIIQKdeA',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 1910,
#   'y': 12934,
#   'team_id': 200,
#   'win': False,
#   'position': 'BOTTOM',
#   'indiv_pos': 'BOTTOM',
#   'lane': 'BOTTOM',
#   'level': 15,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'},
#  {'match_ids': 'NA1_4914435754',
#   'match_type': 'CLASSIC',
#   'frame': 31,
#   'player_part_id': 10,
#   'player_puuid': 'vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpAYGYIsg1hNMQX3oHVUYQf2Y3xt7coINKw',
#   'player_summoner_id': 'B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ',
#   'x': 981,
#   'y': 13488,
#   'team_id': 200,
#   'win': False,
#   'position': 'UTILITY',
#   'indiv_pos': 'UTILITY',
#   'lane': 'BOTTOM',
#   'level': 13,
#   'tier': 'GRANDMASTER',
#   'rank': 'I'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df
# Out:
#           match_ids match_type  frame  player_part_id  \
# 0    NA1_4916347757    CLASSIC      0               1
# 1    NA1_4916347757    CLASSIC      0               2
# 2    NA1_4916347757    CLASSIC      0               3
# 3    NA1_4916347757    CLASSIC      0               4
# 4    NA1_4916347757    CLASSIC      0               5
# ..              ...        ...    ...             ...
# 485  NA1_4914435754    CLASSIC     31               6
# 486  NA1_4914435754    CLASSIC     31               7
# 487  NA1_4914435754    CLASSIC     31               8
# 488  NA1_4914435754    CLASSIC     31               9
# 489  NA1_4914435754    CLASSIC     31              10
#
#                                           player_puuid  \
# 0    7vWvjHsx2iqMzQKq3zHibLBmh1S_kwAnNkUBb6R3m-MLZF...
# 1    -lCR4Iousw6OyLrbiFmfP43Uq2LdmrQRCj5_ktiINV8fbi...
# 2    sfdcwQYH0VVE8T2r9Ss9TOd7qZ-OPADj1vjE8Ey-bYDkNd...
# 3    qnVSItvRZX8S1jrUqRF9HAXJinbBVkxNW7IqseZG1x2mIG...
# 4    vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpA...
# ..                                                 ...
# 485  FFg92Qbo4QMCK17khZ_p6fnQufj5FER6N40ZLV724u5JMi...
# 486  zNC3SJU75Rl4nVWU9DHrogiJ_cSA6VhimAII7Z2yLn7HfE...
# 487  mlt4Wh4NKd0tFt6HZs2h4PeroknaOTvAYFuTH1jyGcw32R...
# 488  qng75RPNtaJ5CgcwMpGcx7AfNFmMoeNz2PkFuFnyUIoEAQ...
# 489  vIiJmaW0ydo5rMPmZeup4l_B7rokA35RkkKYUyY-8GdPpA...
#
#                                   player_summoner_id      x      y  team_id  \
# 0    xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI    554    581      100
# 1    xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI    593    464      100
# 2    xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI    557    345      100
# 3    xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI    458    271      100
# 4    xvuVWIwWxLc_Y1SNe-HpovQdrnkmcENV83rYA-vTa5m_duI    335    269      100
# ..                                               ...    ...    ...      ...
# 485  B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ   1566  12658      200
# 486  B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ  12743  13985      200
# 487  B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ   3320  12436      200
# 488  B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ   1910  12934      200
# 489  B9fusPC27b-tr_1_6uXjBo__4e3MTYvAYpVyJc0wN3-ifuQ    981  13488      200
#
#        win position indiv_pos    lane  level         tier rank
# 0     True   MIDDLE    MIDDLE    NONE      1   CHALLENGER    I
# 1     True   JUNGLE    JUNGLE    NONE      1  GRANDMASTER    I
# 2     True      TOP       TOP    NONE      1   CHALLENGER    I
# 3     True   BOTTOM    BOTTOM    NONE      1       MASTER    I
# 4     True  UTILITY   UTILITY    NONE      1  GRANDMASTER    I
# ..     ...      ...       ...     ...    ...          ...  ...
# 485  False      TOP       TOP     TOP     18  GRANDMASTER    I
# 486  False   JUNGLE    JUNGLE  JUNGLE     16      EMERALD  III
# 487  False   MIDDLE    MIDDLE     TOP     17      DIAMOND   II
# 488  False   BOTTOM    BOTTOM  BOTTOM     15  GRANDMASTER    I
# 489  False  UTILITY   UTILITY  BOTTOM     13  GRANDMASTER    I
#
# [490 rows x 16 columns]

# %%
df["player_puuid"].value_counts()
# Out:
# player_puuid
# K2FCH6s02C0n8p8aUqxpGAZBFeYTgsHJ-Wrowg4S2IrdyMk6UpjTxKEVHdgQtuyyritlaJqaVyKDRw    281
# 7YT_7WOj--VM-hOxeDmoqR23aw17Nt9gJcDu8_VkCCw5-i7InktEEO1BoKwwHADM6eKB0KpOedLrsA    281
# DSUPQEjZ_E5tW8rAQ02AiOiw44zBw2lgbFyNBmGU4_6wfp8Lqzye9dUd2pHOOBZpKL8NDm7QXtqyLQ    167
# 58567Yu693KRwzpLFz6-NYhL3lZpKFMcog4h-zVgBJ9qMO8JpxyuH8r1PNCjmrawvtssJOtKKIERTg    145
# jdTqDr0j3DAY41RcS0gJMZIkil8mZQYSYv789TIxZojxqGCV5abSRR6V3hRhY7blRvWka-xpeseOdA    124
#                                                                                  ...
# 25jjH-PbdqrRKaYfOY9M423yrqdhI_vvvA2D00mferXoDt-OZru2BpZUqyThE1iwUVQuchVur26DWg      3
# -AhLouJhxC-vkrERd1d6euuCAlAccVOcTuY56B53gD0AcaozHOTIMRd997qy27yXqJ5VYh_AcYH2XA      3
# G7f1XDpeiY_sn51S5g1nHeWmwGIQ1B0p13V_zQpKKC1JX1-Sv1MVuwNV_gx9BT6sfVWkv55ecjY7EQ      3
# NmdFPuXLz3U99fWtgGBA5qw44QS7w3VNgxswyjy3GZlUVHNwdq9v2607O6wBzcDnPcAMN1YqfPjmew      3
# 6iYYg63rihDnUopHKh5XimNh6yw4RB9GYlwaq-4MimGPTe6D2VIekzTNUmDaBqZ0SKiwTjAop2yMSA      3
# Name: count, Length: 286, dtype: int64

# %%
df["match_ids"].value_counts()
# Out:
# match_ids
# NA1_4912913660    1110
# NA1_4913952739     900
# NA1_4907133965     470
# NA1_4914689599     400
# NA1_4908226910     370
# NA1_4908870510     370
# NA1_4913500381     340
# NA1_4912978472     340
# NA1_4913912584     310
# NA1_4914589650     310
# NA1_4914623258     300
# NA1_4912961720     280
# NA1_4912102736     270
# NA1_4913589399     270
# NA1_4905350000     250
# NA1_4910909165     240
# NA1_4914477445     240
# NA1_4913547916     230
# NA1_4909800130     230
# NA1_4912853003     220
# NA1_4906408509     220
# NA1_4912324242     200
# NA1_4913647041     200
# NA1_4913096250     200
# NA1_4911830299     200
# NA1_4913902543     190
# NA1_4913455426     180
# NA1_4878626249     170
# NA1_4910783748     170
# NA1_4913986371     150
# NA1_4878448614     150
# NA1_4911881634     150
# NA1_4914677064     140
# NA1_4913505349     140
# NA1_4906497820      30
# Name: count, dtype: int64

# %%
df["match_type"].value_counts()
# Out:
# match_type
# ARAM       6570
# CLASSIC    3370
# Name: count, dtype: int64

# %%
df["match_ids"].nunique()
# Out:
# 35
